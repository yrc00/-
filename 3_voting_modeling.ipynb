# %% [markdown]
# ## Basic Data

# %% [markdown]
# ### Voting

# %%
import pandas as pd

# 데이터 로드
train = pd.read_csv('./train.csv')

train.drop('yymm', axis=1, inplace=True)

# 결과 출력
train.head(10)
# Out:
#       V1      V2     V3     V4     V5      V6      V7    V8     V9    V10  \
# 0 -5.327  12.250 -3.294 -7.855 -1.196  13.824 -10.249 -3.04 -5.170  8.077
# 1 -5.267  12.916 -3.220 -7.788 -1.196  14.424 -10.249 -3.04 -4.970  8.027
# 2 -5.127  13.583 -3.130 -7.658 -1.196  15.081 -10.359 -3.04 -4.830  7.977
# 3 -5.060  14.250 -3.130 -7.532 -1.196  14.961 -10.359 -3.04 -4.830  7.927
# 4 -4.967  14.916 -3.094 -7.462 -1.196  15.454 -10.359 -3.04 -4.970  7.877
# 5 -4.967  15.583 -3.020 -7.388 -1.196  15.284 -10.419 -3.04 -4.860  7.827
# 6 -4.827  16.250 -2.920 -7.288 -1.196  15.351 -10.449 -3.04 -4.933  7.777
# 7 -4.797  16.250 -2.920 -7.222 -1.196  14.188 -10.516 -3.04 -4.860  7.727
# 8 -4.737  16.250 -2.830 -7.188 -1.196  14.048 -10.659 -3.04 -4.933  7.677
# 9 -4.900  16.250 -2.890 -7.188 -1.196  14.014 -10.659 -3.04 -4.430  7.627
#
#    ...    V18    V19    V20     V21     V22    V23    V24    V25    V26  \
# 0  ...  0.103  1.001 -5.861 -27.695  -9.978 -2.689 -0.951 -3.873  0.471
# 1  ...  0.073  0.935 -5.881 -37.695 -10.038 -2.652 -1.018 -3.503  0.361
# 2  ...  0.013  0.905 -5.891 -37.695 -10.001 -2.652 -1.051 -3.436  0.361
# 3  ... -0.020  0.845 -5.911 -37.695 -10.028 -2.552 -1.111 -3.346  0.261
# 4  ... -0.087  0.811 -5.931 -37.695 -10.111 -2.619 -1.141 -3.346  0.261
# 5  ... -0.087  0.745 -5.941 -37.695 -10.111 -2.689 -1.208 -3.346  0.171
# 6  ... -0.153  0.695 -5.961 -47.695 -10.171 -2.762 -1.275 -3.346  0.171
# 7  ... -0.187  0.645 -6.111 -37.695 -10.478 -2.689 -1.341 -3.206  0.071
# 8  ... -0.260  0.645 -6.261 -37.695 -10.744 -2.689 -1.451 -3.073  0.004
# 9  ... -0.297  0.535 -6.411 -37.695 -10.941 -2.792 -1.551 -2.706  0.038
#
#    Target
# 0  44.521
# 1  35.027
# 2  13.920
# 3  28.410
# 4   1.647
# 5   6.360
# 6  34.535
# 7  21.335
# 8  34.687
# 9  34.136
#
# [10 rows x 27 columns]

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
lr = LinearRegression()
ridge = Ridge(random_state=42)
lasso = Lasso(random_state=42)
elastic = ElasticNet(random_state=42)
svr = SVR()
gb = GradientBoostingRegressor(random_state=42)
rf = RandomForestRegressor(random_state=42)
xgb = XGBRegressor(random_state=42)
lgbm = LGBMRegressor(random_state=42)
dt = DecisionTreeRegressor(random_state=42)

voting1 = VotingRegressor([
    ('lasso', lasso),
    ('svr', svr),
    ('random_forest', rf)
])

voting2 = VotingRegressor([
    ('lasso', lasso),
    ('elastic', elastic),
    ('svr', svr),
])

voting3 = VotingRegressor([
    ('svr', svr),
    ('random_forest', rf),
    ('xgb', xgb),
])

models = {
    'Voting1': voting1,
    'Voting2': voting2,
    'Voiting3': voting3
}

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
for model_name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5, scoring=mae_scorer)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    train_score = mean_absolute_error(y_train, model.predict(X_train))
    test_score = mean_absolute_error(y_test, y_pred)

    print(f'{model_name}: {scores.mean()} / {train_score} / {test_score}')
# Out:
# Voting1: 12.539424804561312 / 9.889203428498147 / 12.506113838706884
# Voting2: 12.537481846367452 / 12.514234348019821 / 12.457180035475115
# Voiting3: 12.653674805670764 / 7.291876288187345 / 12.763322403492216

# %%
import optuna
from sklearn.ensemble import VotingRegressor, RandomForestRegressor
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
from optuna.samplers import TPESampler

# 데이터 분할
X = train.drop('Target', axis=1)  # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']               # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# Optuna 목적 함수 정의
def objective(trial):
    # 하이퍼파라미터 선택
    lasso_alpha = trial.suggest_float('lasso_alpha', 0.001, 1.0)
    elastic_alpha = trial.suggest_float('elastic_alpha', 0.001, 1.0)
    elastic_l1_ratio = trial.suggest_float('elastic_l1_ratio', 0.1, 0.9)
    
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 300)
    rf_max_depth = trial.suggest_int('rf_max_depth', 3, 20)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 10)
    rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', None])
    rf_random_state = trial.suggest_int('rf_random_state', 1, 100)

    # 모델 정의
    lasso = Lasso(alpha=lasso_alpha, random_state=rf_random_state)
    elastic = ElasticNet(alpha=elastic_alpha, l1_ratio=elastic_l1_ratio, random_state=rf_random_state)
    rf = RandomForestRegressor(
        n_estimators=rf_n_estimators,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        max_features=rf_max_features,
        random_state=rf_random_state
    )
    
    # VotingRegressor 정의
    voting = VotingRegressor([('lasso', lasso), ('elastic', elastic), ('rf', rf)])
    
    # 5-fold 교차 검증으로 평가
    scores = cross_val_score(voting, X_train, y_train, cv=5, scoring=mae_scorer)
    return scores.mean()

# Optuna 최적화 실행
study = optuna.create_study(direction='minimize', sampler=TPESampler())
study.optimize(objective, n_trials=500)

# 최적 하이퍼파라미터 출력
print("Best parameters:", study.best_params)

# 최적 하이퍼파라미터로 VotingRegressor 학습
best_lasso = Lasso(alpha=study.best_params['lasso_alpha'], random_state=study.best_params['rf_random_state'])
best_elastic = ElasticNet(alpha=study.best_params['elastic_alpha'], l1_ratio=study.best_params['elastic_l1_ratio'], random_state=study.best_params['rf_random_state'])
best_rf = RandomForestRegressor(
    n_estimators=study.best_params['rf_n_estimators'],
    max_depth=study.best_params['rf_max_depth'],
    min_samples_split=study.best_params['rf_min_samples_split'],
    min_samples_leaf=study.best_params['rf_min_samples_leaf'],
    max_features=study.best_params['rf_max_features'],
    random_state=study.best_params['rf_random_state']
)

voting_best = VotingRegressor([('lasso', best_lasso), ('elastic', best_elastic), ('rf', best_rf)])

# 최적화된 모델 학습 및 평가
voting_best.fit(X_train, y_train)
y_pred = voting_best.predict(X_test)

train_score = mean_absolute_error(y_train, voting_best.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'Optimized Voting Regressor - Train MAE: {train_score}, Test MAE: {test_score}')
# Out:
# [I 2024-10-28 15:17:44,101] A new study created in memory with name: no-name-5d7855ea-bb0b-482d-bb2d-3f3cbc34c7a9
# [I 2024-10-28 15:17:51,776] Trial 0 finished with value: 12.61063206598244 and parameters: {'lasso_alpha': 0.05359203960529344, 'elastic_alpha': 0.9663744177171892, 'elastic_l1_ratio': 0.1771469623971088, 'rf_n_estimators': 230, 'rf_max_depth': 20, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 56}. Best is trial 0 with value: 12.61063206598244.
# [I 2024-10-28 15:17:53,310] Trial 1 finished with value: 12.583079694426269 and parameters: {'lasso_alpha': 0.14864221436540087, 'elastic_alpha': 0.3609806544260413, 'elastic_l1_ratio': 0.13384186420595334, 'rf_n_estimators': 135, 'rf_max_depth': 4, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 38}. Best is trial 1 with value: 12.583079694426269.
# [I 2024-10-28 15:17:55,278] Trial 2 finished with value: 12.59021023262496 and parameters: {'lasso_alpha': 0.3788951102287714, 'elastic_alpha': 0.5022343376284019, 'elastic_l1_ratio': 0.33014713408797314, 'rf_n_estimators': 74, 'rf_max_depth': 17, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 65}. Best is trial 1 with value: 12.583079694426269.
# [I 2024-10-28 15:17:58,004] Trial 3 finished with value: 12.572498331694739 and parameters: {'lasso_alpha': 0.6760227534780664, 'elastic_alpha': 0.5831629425902475, 'elastic_l1_ratio': 0.471271681414151, 'rf_n_estimators': 287, 'rf_max_depth': 4, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_random_state': 88}. Best is trial 3 with value: 12.572498331694739.
# [I 2024-10-28 15:18:02,809] Trial 4 finished with value: 12.565800097471081 and parameters: {'lasso_alpha': 0.8918131234063904, 'elastic_alpha': 0.9885301137827451, 'elastic_l1_ratio': 0.4913628480272022, 'rf_n_estimators': 243, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_random_state': 63}. Best is trial 4 with value: 12.565800097471081.
# [I 2024-10-28 15:18:03,855] Trial 5 finished with value: 12.577090915380904 and parameters: {'lasso_alpha': 0.8972831696254328, 'elastic_alpha': 0.47758453148849567, 'elastic_l1_ratio': 0.49231892492933416, 'rf_n_estimators': 113, 'rf_max_depth': 3, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 76}. Best is trial 4 with value: 12.565800097471081.
# [I 2024-10-28 15:18:06,260] Trial 6 finished with value: 12.594296425556957 and parameters: {'lasso_alpha': 0.9675032201827968, 'elastic_alpha': 0.5464562714692548, 'elastic_l1_ratio': 0.13696769756098437, 'rf_n_estimators': 96, 'rf_max_depth': 16, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 57}. Best is trial 4 with value: 12.565800097471081.
# [I 2024-10-28 15:18:07,725] Trial 7 finished with value: 12.59777337195425 and parameters: {'lasso_alpha': 0.20426995808395734, 'elastic_alpha': 0.5770970760045253, 'elastic_l1_ratio': 0.25542795452044675, 'rf_n_estimators': 53, 'rf_max_depth': 17, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 89}. Best is trial 4 with value: 12.565800097471081.
# [I 2024-10-28 15:18:09,981] Trial 8 finished with value: 12.585437454557953 and parameters: {'lasso_alpha': 0.677113425183109, 'elastic_alpha': 0.9870320299177039, 'elastic_l1_ratio': 0.8248179512221743, 'rf_n_estimators': 89, 'rf_max_depth': 20, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_random_state': 80}. Best is trial 4 with value: 12.565800097471081.
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.605e+04, tolerance: 5.203e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.553e+04, tolerance: 5.242e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.618e+04, tolerance: 5.323e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.218e+02, tolerance: 5.272e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.129e+03, tolerance: 5.276e+01
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-10-28 15:18:45,794] Trial 9 finished with value: 12.61004823049814 and parameters: {'lasso_alpha': 0.8602362925314836, 'elastic_alpha': 0.012907321048719583, 'elastic_l1_ratio': 0.1070114421302919, 'rf_n_estimators': 291, 'rf_max_depth': 19, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 48}. Best is trial 4 with value: 12.565800097471081.
# [I 2024-10-28 15:19:04,018] Trial 10 finished with value: 12.564280383946922 and parameters: {'lasso_alpha': 0.5164281762141413, 'elastic_alpha': 0.7760158031362678, 'elastic_l1_ratio': 0.7548199535986729, 'rf_n_estimators': 207, 'rf_max_depth': 9, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 5}. Best is trial 10 with value: 12.564280383946922.
# [I 2024-10-28 15:19:23,996] Trial 11 finished with value: 12.564988750601065 and parameters: {'lasso_alpha': 0.5090700582157333, 'elastic_alpha': 0.8070967125439388, 'elastic_l1_ratio': 0.7212067493474219, 'rf_n_estimators': 208, 'rf_max_depth': 10, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 6}. Best is trial 10 with value: 12.564280383946922.
# [I 2024-10-28 15:19:40,850] Trial 12 finished with value: 12.567178765582478 and parameters: {'lasso_alpha': 0.46959630195956137, 'elastic_alpha': 0.7659068929581327, 'elastic_l1_ratio': 0.798696960338334, 'rf_n_estimators': 174, 'rf_max_depth': 10, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 1}. Best is trial 10 with value: 12.564280383946922.
# [I 2024-10-28 15:20:03,835] Trial 13 finished with value: 12.577662961214655 and parameters: {'lasso_alpha': 0.6108574425865486, 'elastic_alpha': 0.7567084489364226, 'elastic_l1_ratio': 0.6891801935607922, 'rf_n_estimators': 201, 'rf_max_depth': 13, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 1}. Best is trial 10 with value: 12.564280383946922.
# [I 2024-10-28 15:20:15,430] Trial 14 finished with value: 12.563925886263396 and parameters: {'lasso_alpha': 0.345345889591399, 'elastic_alpha': 0.783876736787215, 'elastic_l1_ratio': 0.6471160962665489, 'rf_n_estimators': 162, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 22}. Best is trial 14 with value: 12.563925886263396.
# [I 2024-10-28 15:20:26,725] Trial 15 finished with value: 12.561085906187063 and parameters: {'lasso_alpha': 0.3108993968779444, 'elastic_alpha': 0.7175964764547006, 'elastic_l1_ratio': 0.6302007950063913, 'rf_n_estimators': 153, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 21}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:20:36,361] Trial 16 finished with value: 12.566267095897846 and parameters: {'lasso_alpha': 0.29148164854995784, 'elastic_alpha': 0.2503815781946749, 'elastic_l1_ratio': 0.6164054793806089, 'rf_n_estimators': 150, 'rf_max_depth': 6, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 24}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:20:48,805] Trial 17 finished with value: 12.56305572164192 and parameters: {'lasso_alpha': 0.3288347444797874, 'elastic_alpha': 0.6753624993542158, 'elastic_l1_ratio': 0.8989774628094244, 'rf_n_estimators': 171, 'rf_max_depth': 7, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 23}. Best is trial 15 with value: 12.561085906187063.
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.287e+04, tolerance: 5.203e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.097e+04, tolerance: 5.242e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.421e+04, tolerance: 5.323e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.278e+01, tolerance: 5.272e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.686e+03, tolerance: 5.276e+01
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-10-28 15:21:04,800] Trial 18 finished with value: 12.592299971775871 and parameters: {'lasso_alpha': 0.009541178331175681, 'elastic_alpha': 0.6469703283738832, 'elastic_l1_ratio': 0.8910009243702147, 'rf_n_estimators': 122, 'rf_max_depth': 13, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 25}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:21:07,323] Trial 19 finished with value: 12.572124842080635 and parameters: {'lasso_alpha': 0.2300139336248801, 'elastic_alpha': 0.3828433291050465, 'elastic_l1_ratio': 0.591548977430046, 'rf_n_estimators': 185, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 38}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:21:25,482] Trial 20 finished with value: 12.564970608086266 and parameters: {'lasso_alpha': 0.4105392537435534, 'elastic_alpha': 0.6630226408996471, 'elastic_l1_ratio': 0.3806701673430966, 'rf_n_estimators': 249, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 15}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:21:36,953] Trial 21 finished with value: 12.563046278091614 and parameters: {'lasso_alpha': 0.3264339356890321, 'elastic_alpha': 0.8472559467053155, 'elastic_l1_ratio': 0.6139112437207241, 'rf_n_estimators': 157, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 23}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:21:49,572] Trial 22 finished with value: 12.5662879296683 and parameters: {'lasso_alpha': 0.2887147513533773, 'elastic_alpha': 0.8822239481917366, 'elastic_l1_ratio': 0.5560526720904027, 'rf_n_estimators': 154, 'rf_max_depth': 8, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 36}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:21:56,822] Trial 23 finished with value: 12.567374544675117 and parameters: {'lasso_alpha': 0.1504159923680371, 'elastic_alpha': 0.6730986092284253, 'elastic_l1_ratio': 0.8669722255281773, 'rf_n_estimators': 135, 'rf_max_depth': 5, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 15}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:22:20,610] Trial 24 finished with value: 12.581560559560913 and parameters: {'lasso_alpha': 0.4270568469223906, 'elastic_alpha': 0.89804684677673, 'elastic_l1_ratio': 0.3834179732694056, 'rf_n_estimators': 192, 'rf_max_depth': 12, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 15}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:22:38,643] Trial 25 finished with value: 12.580786429912271 and parameters: {'lasso_alpha': 0.309722802397281, 'elastic_alpha': 0.8939599234239937, 'elastic_l1_ratio': 0.67503283566032, 'rf_n_estimators': 170, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 29}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:22:40,972] Trial 26 finished with value: 12.573356218251206 and parameters: {'lasso_alpha': 0.1052467150316315, 'elastic_alpha': 0.6894740184421264, 'elastic_l1_ratio': 0.5540362678448383, 'rf_n_estimators': 138, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 44}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:22:53,036] Trial 27 finished with value: 12.564032085442637 and parameters: {'lasso_alpha': 0.2344455706527296, 'elastic_alpha': 0.8465680468601757, 'elastic_l1_ratio': 0.7956447292205766, 'rf_n_estimators': 225, 'rf_max_depth': 5, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 31}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:23:01,827] Trial 28 finished with value: 12.561089611647606 and parameters: {'lasso_alpha': 0.5863245830645326, 'elastic_alpha': 0.4009476023057572, 'elastic_l1_ratio': 0.7522341163535564, 'rf_n_estimators': 117, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 12}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:23:05,602] Trial 29 finished with value: 12.574219918120935 and parameters: {'lasso_alpha': 0.576669646955738, 'elastic_alpha': 0.21533884749501947, 'elastic_l1_ratio': 0.7483752371238591, 'rf_n_estimators': 111, 'rf_max_depth': 3, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 13}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:23:07,292] Trial 30 finished with value: 12.567153361022289 and parameters: {'lasso_alpha': 0.674768727541742, 'elastic_alpha': 0.39373755620954815, 'elastic_l1_ratio': 0.5544766602739827, 'rf_n_estimators': 90, 'rf_max_depth': 9, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 9}. Best is trial 15 with value: 12.561085906187063.
# [I 2024-10-28 15:23:18,058] Trial 31 finished with value: 12.560027988399801 and parameters: {'lasso_alpha': 0.7542512848213636, 'elastic_alpha': 0.711290383250602, 'elastic_l1_ratio': 0.859428696830333, 'rf_n_estimators': 145, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 21}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:23:25,571] Trial 32 finished with value: 12.565774510052623 and parameters: {'lasso_alpha': 0.7550695228410934, 'elastic_alpha': 0.29489889428352883, 'elastic_l1_ratio': 0.7117523972568671, 'rf_n_estimators': 140, 'rf_max_depth': 5, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 21}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:23:33,495] Trial 33 finished with value: 12.5638488089271 and parameters: {'lasso_alpha': 0.774621110293618, 'elastic_alpha': 0.45649286667700717, 'elastic_l1_ratio': 0.6360052886855814, 'rf_n_estimators': 124, 'rf_max_depth': 6, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 33}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:23:46,083] Trial 34 finished with value: 12.57091189795093 and parameters: {'lasso_alpha': 0.574554405211211, 'elastic_alpha': 0.12781646048951772, 'elastic_l1_ratio': 0.844724054886956, 'rf_n_estimators': 151, 'rf_max_depth': 8, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 44}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:23:50,684] Trial 35 finished with value: 12.56787828402801 and parameters: {'lasso_alpha': 0.4690292884369169, 'elastic_alpha': 0.7210613336860521, 'elastic_l1_ratio': 0.77202367581284, 'rf_n_estimators': 105, 'rf_max_depth': 4, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 11}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:04,833] Trial 36 finished with value: 12.57402120384476 and parameters: {'lasso_alpha': 0.7847085779211749, 'elastic_alpha': 0.6092578941478405, 'elastic_l1_ratio': 0.6757032510284174, 'rf_n_estimators': 128, 'rf_max_depth': 11, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 18}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:05,614] Trial 37 finished with value: 12.577304766596432 and parameters: {'lasso_alpha': 0.7154319106814288, 'elastic_alpha': 0.439370894337766, 'elastic_l1_ratio': 0.4663112789021065, 'rf_n_estimators': 62, 'rf_max_depth': 4, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 31}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:09,447] Trial 38 finished with value: 12.58153766374011 and parameters: {'lasso_alpha': 0.3806121612406085, 'elastic_alpha': 0.5330587588957816, 'elastic_l1_ratio': 0.8134060025478043, 'rf_n_estimators': 156, 'rf_max_depth': 15, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 54}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:11,086] Trial 39 finished with value: 12.570961747539457 and parameters: {'lasso_alpha': 0.8469023035719156, 'elastic_alpha': 0.9194664904864015, 'elastic_l1_ratio': 0.5883312952755796, 'rf_n_estimators': 72, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 41}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:18,557] Trial 40 finished with value: 12.56299396044015 and parameters: {'lasso_alpha': 0.6294976935750974, 'elastic_alpha': 0.8328620229446896, 'elastic_l1_ratio': 0.43394424810566595, 'rf_n_estimators': 102, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 66}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:25,904] Trial 41 finished with value: 12.566261387452565 and parameters: {'lasso_alpha': 0.6159948207025623, 'elastic_alpha': 0.8379942679363773, 'elastic_l1_ratio': 0.4334554735920568, 'rf_n_estimators': 100, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 68}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:32,909] Trial 42 finished with value: 12.56289032377263 and parameters: {'lasso_alpha': 0.9791079043268889, 'elastic_alpha': 0.9475160007601674, 'elastic_l1_ratio': 0.2752819195581186, 'rf_n_estimators': 83, 'rf_max_depth': 8, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 99}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:40,333] Trial 43 finished with value: 12.570968408353258 and parameters: {'lasso_alpha': 0.8260614344486253, 'elastic_alpha': 0.9335857617323526, 'elastic_l1_ratio': 0.2187700438842216, 'rf_n_estimators': 80, 'rf_max_depth': 9, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 94}. Best is trial 31 with value: 12.560027988399801.
# [I 2024-10-28 15:24:49,915] Trial 44 finished with value: 12.55906184125134 and parameters: {'lasso_alpha': 0.974349617275116, 'elastic_alpha': 0.9662255963525347, 'elastic_l1_ratio': 0.3214780202285017, 'rf_n_estimators': 115, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 79}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:24:52,303] Trial 45 finished with value: 12.562973784914567 and parameters: {'lasso_alpha': 0.9920663335922714, 'elastic_alpha': 0.965641763258655, 'elastic_l1_ratio': 0.3136835846139635, 'rf_n_estimators': 118, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 78}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:24:57,534] Trial 46 finished with value: 12.561292809914733 and parameters: {'lasso_alpha': 0.9305762115531349, 'elastic_alpha': 0.9917165729227132, 'elastic_l1_ratio': 0.22817067478565195, 'rf_n_estimators': 82, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 100}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:25:00,634] Trial 47 finished with value: 12.565457006687497 and parameters: {'lasso_alpha': 0.9287740725137262, 'elastic_alpha': 0.9906083683386755, 'elastic_l1_ratio': 0.1734855557385888, 'rf_n_estimators': 58, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 86}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:25:05,216] Trial 48 finished with value: 12.567171544024621 and parameters: {'lasso_alpha': 0.9225260767011043, 'elastic_alpha': 0.3261697400567859, 'elastic_l1_ratio': 0.2101974908100723, 'rf_n_estimators': 71, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 73}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:25:18,291] Trial 49 finished with value: 12.573603100713333 and parameters: {'lasso_alpha': 0.8852626449897429, 'elastic_alpha': 0.5198608076117035, 'elastic_l1_ratio': 0.2894388344662822, 'rf_n_estimators': 142, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 87}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:25:19,289] Trial 50 finished with value: 12.576560048234661 and parameters: {'lasso_alpha': 0.9405432821986851, 'elastic_alpha': 0.6110679551960847, 'elastic_l1_ratio': 0.14181812334912963, 'rf_n_estimators': 113, 'rf_max_depth': 3, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 100}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:25:24,643] Trial 51 finished with value: 12.562345186507955 and parameters: {'lasso_alpha': 0.9998075493002518, 'elastic_alpha': 0.9516647347069986, 'elastic_l1_ratio': 0.2524994698319051, 'rf_n_estimators': 84, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 100}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:25:32,771] Trial 52 finished with value: 12.55922733776492 and parameters: {'lasso_alpha': 0.9959298040059362, 'elastic_alpha': 0.9984815657877525, 'elastic_l1_ratio': 0.34902578227975034, 'rf_n_estimators': 127, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 94}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:25:39,859] Trial 53 finished with value: 12.56454180092507 and parameters: {'lasso_alpha': 0.8765627900994915, 'elastic_alpha': 0.7191014270151583, 'elastic_l1_ratio': 0.35251362085778476, 'rf_n_estimators': 130, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 93}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:25:45,986] Trial 54 finished with value: 12.561247483522164 and parameters: {'lasso_alpha': 0.8073365620457362, 'elastic_alpha': 0.9984407810782113, 'elastic_l1_ratio': 0.34149030272800174, 'rf_n_estimators': 95, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 91}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:26:03,084] Trial 55 finished with value: 12.570676841942312 and parameters: {'lasso_alpha': 0.8050521127263087, 'elastic_alpha': 0.5699362154135856, 'elastic_l1_ratio': 0.33456710623710784, 'rf_n_estimators': 166, 'rf_max_depth': 10, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 83}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:26:06,375] Trial 56 finished with value: 12.572200206654832 and parameters: {'lasso_alpha': 0.7095621925444539, 'elastic_alpha': 0.4216419153383319, 'elastic_l1_ratio': 0.39097779696058577, 'rf_n_estimators': 185, 'rf_max_depth': 7, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 92}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:26:13,753] Trial 57 finished with value: 12.56954514298894 and parameters: {'lasso_alpha': 0.5380667194031833, 'elastic_alpha': 0.8054685614877998, 'elastic_l1_ratio': 0.4173904691127244, 'rf_n_estimators': 94, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 59}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:26:23,905] Trial 58 finished with value: 12.566220374663631 and parameters: {'lasso_alpha': 0.8381929572009391, 'elastic_alpha': 0.8764689011831129, 'elastic_l1_ratio': 0.8493958235035055, 'rf_n_estimators': 109, 'rf_max_depth': 9, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 74}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:26:38,555] Trial 59 finished with value: 12.565213680328714 and parameters: {'lasso_alpha': 0.95443560908909, 'elastic_alpha': 0.48461535333834777, 'elastic_l1_ratio': 0.48296356100965476, 'rf_n_estimators': 274, 'rf_max_depth': 5, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 82}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:26:47,766] Trial 60 finished with value: 12.560276405312816 and parameters: {'lasso_alpha': 0.7197762628647526, 'elastic_alpha': 0.9158466873455569, 'elastic_l1_ratio': 0.5267990421480885, 'rf_n_estimators': 144, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 26}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:26:56,920] Trial 61 finished with value: 12.561137183210644 and parameters: {'lasso_alpha': 0.7494906579502556, 'elastic_alpha': 0.9151779993548659, 'elastic_l1_ratio': 0.30218837070811777, 'rf_n_estimators': 144, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 96}. Best is trial 44 with value: 12.55906184125134.
# [I 2024-10-28 15:27:07,676] Trial 62 finished with value: 12.558405694071352 and parameters: {'lasso_alpha': 0.6536095388076557, 'elastic_alpha': 0.9127548757213432, 'elastic_l1_ratio': 0.5176598346319768, 'rf_n_estimators': 146, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 27}. Best is trial 62 with value: 12.558405694071352.
# [I 2024-10-28 15:27:17,300] Trial 63 finished with value: 12.558511863753653 and parameters: {'lasso_alpha': 0.6664583945434861, 'elastic_alpha': 0.8017773530603658, 'elastic_l1_ratio': 0.5468467185313901, 'rf_n_estimators': 131, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 6}. Best is trial 62 with value: 12.558405694071352.
# [I 2024-10-28 15:27:29,307] Trial 64 finished with value: 12.557055303269225 and parameters: {'lasso_alpha': 0.6606939147398639, 'elastic_alpha': 0.8696434359544282, 'elastic_l1_ratio': 0.5111917958018279, 'rf_n_estimators': 147, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 27}. Best is trial 64 with value: 12.557055303269225.
# [I 2024-10-28 15:27:40,060] Trial 65 finished with value: 12.5567114837206 and parameters: {'lasso_alpha': 0.6416997776152064, 'elastic_alpha': 0.7515258671755575, 'elastic_l1_ratio': 0.5203646724757048, 'rf_n_estimators': 131, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 27}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:27:51,958] Trial 66 finished with value: 12.568249762390106 and parameters: {'lasso_alpha': 0.6531857015357184, 'elastic_alpha': 0.7897202983448196, 'elastic_l1_ratio': 0.5108695058399354, 'rf_n_estimators': 132, 'rf_max_depth': 9, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 5}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:28:06,704] Trial 67 finished with value: 12.566776425021446 and parameters: {'lasso_alpha': 0.6646731655302676, 'elastic_alpha': 0.749820261175034, 'elastic_l1_ratio': 0.4595253209523857, 'rf_n_estimators': 180, 'rf_max_depth': 8, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 18}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:28:10,794] Trial 68 finished with value: 12.588458296565973 and parameters: {'lasso_alpha': 0.6902103585881816, 'elastic_alpha': 0.8669490086521525, 'elastic_l1_ratio': 0.5300767767794422, 'rf_n_estimators': 163, 'rf_max_depth': 18, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5, 'rf_max_features': 'log2', 'rf_random_state': 27}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:28:19,983] Trial 69 finished with value: 12.563436111903531 and parameters: {'lasso_alpha': 0.5332787882076019, 'elastic_alpha': 0.8171665928195305, 'elastic_l1_ratio': 0.5859449537047293, 'rf_n_estimators': 126, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 35}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:28:34,347] Trial 70 finished with value: 12.566387365073485 and parameters: {'lasso_alpha': 0.635064960463613, 'elastic_alpha': 0.7381738339960539, 'elastic_l1_ratio': 0.40502707629088375, 'rf_n_estimators': 146, 'rf_max_depth': 10, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 7}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:28:44,150] Trial 71 finished with value: 12.558261518595248 and parameters: {'lasso_alpha': 0.7404693577576664, 'elastic_alpha': 0.9053204573972486, 'elastic_l1_ratio': 0.5194761164706876, 'rf_n_estimators': 134, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 27}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:28:52,954] Trial 72 finished with value: 12.560038267469897 and parameters: {'lasso_alpha': 0.7397885041574715, 'elastic_alpha': 0.9628421203959907, 'elastic_l1_ratio': 0.5073574400765075, 'rf_n_estimators': 121, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 19}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:29:04,189] Trial 73 finished with value: 12.566484707154668 and parameters: {'lasso_alpha': 0.5785758978534881, 'elastic_alpha': 0.8800295135542995, 'elastic_l1_ratio': 0.4540121423378007, 'rf_n_estimators': 136, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 39}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:29:17,913] Trial 74 finished with value: 12.569898350981315 and parameters: {'lasso_alpha': 0.7742760352301806, 'elastic_alpha': 0.7779899117414038, 'elastic_l1_ratio': 0.5648173658702772, 'rf_n_estimators': 151, 'rf_max_depth': 9, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 29}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:29:27,611] Trial 75 finished with value: 12.560754775521366 and parameters: {'lasso_alpha': 0.6858550274025748, 'elastic_alpha': 0.8568509500649218, 'elastic_l1_ratio': 0.366980232691373, 'rf_n_estimators': 134, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 28}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:29:44,254] Trial 76 finished with value: 12.56728787412138 and parameters: {'lasso_alpha': 0.4787384956443983, 'elastic_alpha': 0.9313843020498953, 'elastic_l1_ratio': 0.5307708316521287, 'rf_n_estimators': 157, 'rf_max_depth': 11, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 49}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:29:46,681] Trial 77 finished with value: 12.568827887315871 and parameters: {'lasso_alpha': 0.6031323949370401, 'elastic_alpha': 0.9074620938474665, 'elastic_l1_ratio': 0.5022185757576177, 'rf_n_estimators': 118, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 33}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:29:54,604] Trial 78 finished with value: 12.5637785133715 and parameters: {'lasso_alpha': 0.6503109660326972, 'elastic_alpha': 0.8144604686402807, 'elastic_l1_ratio': 0.4819125879934752, 'rf_n_estimators': 176, 'rf_max_depth': 4, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 2}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:30:01,599] Trial 79 finished with value: 12.56435741157339 and parameters: {'lasso_alpha': 0.5490330736288287, 'elastic_alpha': 0.9683668797240866, 'elastic_l1_ratio': 0.6103049463451083, 'rf_n_estimators': 128, 'rf_max_depth': 5, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 24}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:30:05,663] Trial 80 finished with value: 12.577558792160772 and parameters: {'lasso_alpha': 0.9117692961730473, 'elastic_alpha': 0.8931047455998292, 'elastic_l1_ratio': 0.6607784976462283, 'rf_n_estimators': 161, 'rf_max_depth': 14, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 43}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:30:14,706] Trial 81 finished with value: 12.563355487829373 and parameters: {'lasso_alpha': 0.7427022447763514, 'elastic_alpha': 0.9785443930633899, 'elastic_l1_ratio': 0.5102384954944189, 'rf_n_estimators': 122, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 18}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:30:23,177] Trial 82 finished with value: 12.560131329304562 and parameters: {'lasso_alpha': 0.7278074038523901, 'elastic_alpha': 0.9404379898911402, 'elastic_l1_ratio': 0.5762665904121188, 'rf_n_estimators': 110, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 19}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:30:35,315] Trial 83 finished with value: 12.560675833920374 and parameters: {'lasso_alpha': 0.6877166042461147, 'elastic_alpha': 0.9594109305054833, 'elastic_l1_ratio': 0.5526745060093062, 'rf_n_estimators': 137, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 14}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:30:46,142] Trial 84 finished with value: 12.56550331095912 and parameters: {'lasso_alpha': 0.8629483899670211, 'elastic_alpha': 0.8410248869147915, 'elastic_l1_ratio': 0.4389722796468201, 'rf_n_estimators': 120, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 21}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:30:56,613] Trial 85 finished with value: 12.56367446226748 and parameters: {'lasso_alpha': 0.7971568178659928, 'elastic_alpha': 0.8794239064730145, 'elastic_l1_ratio': 0.6056592056420931, 'rf_n_estimators': 146, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 33}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:31:07,266] Trial 86 finished with value: 12.573284440885619 and parameters: {'lasso_alpha': 0.7636773177846707, 'elastic_alpha': 0.7909086748638731, 'elastic_l1_ratio': 0.540266580792763, 'rf_n_estimators': 105, 'rf_max_depth': 10, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 9}. Best is trial 65 with value: 12.5567114837206.
# [I 2024-10-28 15:31:15,291] Trial 87 finished with value: 12.55546726813766 and parameters: {'lasso_alpha': 0.6317854679276357, 'elastic_alpha': 0.6900423857297935, 'elastic_l1_ratio': 0.49129103752121, 'rf_n_estimators': 126, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 30}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:31:24,114] Trial 88 finished with value: 12.565880264669316 and parameters: {'lasso_alpha': 0.6035501948033368, 'elastic_alpha': 0.6630000278573932, 'elastic_l1_ratio': 0.41554376783529406, 'rf_n_estimators': 139, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 31}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:31:32,492] Trial 89 finished with value: 12.560946154297962 and parameters: {'lasso_alpha': 0.6272590894149541, 'elastic_alpha': 0.6928145938145177, 'elastic_l1_ratio': 0.7267382481675588, 'rf_n_estimators': 131, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 37}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:31:34,578] Trial 90 finished with value: 12.569734279671657 and parameters: {'lasso_alpha': 0.5571232180792529, 'elastic_alpha': 0.7628282174651234, 'elastic_l1_ratio': 0.4828842689309509, 'rf_n_estimators': 150, 'rf_max_depth': 5, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 23}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:31:44,031] Trial 91 finished with value: 12.565585607002802 and parameters: {'lasso_alpha': 0.7008948287839302, 'elastic_alpha': 0.9480541069077406, 'elastic_l1_ratio': 0.5046121147493526, 'rf_n_estimators': 115, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 16}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:31:53,003] Trial 92 finished with value: 12.556939967420524 and parameters: {'lasso_alpha': 0.7358789879636194, 'elastic_alpha': 0.6226474194198259, 'elastic_l1_ratio': 0.45013673730016374, 'rf_n_estimators': 123, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 25}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:00,905] Trial 93 finished with value: 12.559458263766723 and parameters: {'lasso_alpha': 0.6564973554140715, 'elastic_alpha': 0.6431498188669613, 'elastic_l1_ratio': 0.4439368466509484, 'rf_n_estimators': 124, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 25}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:08,888] Trial 94 finished with value: 12.559093482165096 and parameters: {'lasso_alpha': 0.659660755133844, 'elastic_alpha': 0.5999755470840272, 'elastic_l1_ratio': 0.4727126130922081, 'rf_n_estimators': 125, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 25}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:13,519] Trial 95 finished with value: 12.56814217462625 and parameters: {'lasso_alpha': 0.5949611492688399, 'elastic_alpha': 0.6031526400103561, 'elastic_l1_ratio': 0.4774963839130579, 'rf_n_estimators': 106, 'rf_max_depth': 4, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 46}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:19,628] Trial 96 finished with value: 12.570032118802356 and parameters: {'lasso_alpha': 0.5095096864612915, 'elastic_alpha': 0.5644341386450609, 'elastic_l1_ratio': 0.5713587207334552, 'rf_n_estimators': 114, 'rf_max_depth': 5, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 52}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:27,768] Trial 97 finished with value: 12.571058841032173 and parameters: {'lasso_alpha': 0.9648701829162853, 'elastic_alpha': 0.6287712969090498, 'elastic_l1_ratio': 0.544600751095166, 'rf_n_estimators': 99, 'rf_max_depth': 8, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 29}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:35,974] Trial 98 finished with value: 12.56397192132935 and parameters: {'lasso_alpha': 0.6721893242130512, 'elastic_alpha': 0.5956027659925005, 'elastic_l1_ratio': 0.5196109560568609, 'rf_n_estimators': 128, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 32}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:45,791] Trial 99 finished with value: 12.562989764020319 and parameters: {'lasso_alpha': 0.7127179444689269, 'elastic_alpha': 0.6975254683901116, 'elastic_l1_ratio': 0.4620723506150781, 'rf_n_estimators': 134, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 35}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:47,907] Trial 100 finished with value: 12.566327300497536 and parameters: {'lasso_alpha': 0.6390374399957702, 'elastic_alpha': 0.737884882211947, 'elastic_l1_ratio': 0.3599035825894571, 'rf_n_estimators': 125, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 27}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:32:55,879] Trial 101 finished with value: 12.558716639373541 and parameters: {'lasso_alpha': 0.6586930382111821, 'elastic_alpha': 0.6544097017353823, 'elastic_l1_ratio': 0.49162618660512836, 'rf_n_estimators': 125, 'rf_max_depth': 6, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 25}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:33:03,426] Trial 102 finished with value: 12.561656918750801 and parameters: {'lasso_alpha': 0.6202125014861524, 'elastic_alpha': 0.8234403286012534, 'elastic_l1_ratio': 0.49430999142827337, 'rf_n_estimators': 141, 'rf_max_depth': 5, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 40}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:33:11,827] Trial 103 finished with value: 12.556486703391645 and parameters: {'lasso_alpha': 0.56953335762752, 'elastic_alpha': 0.6374066507865719, 'elastic_l1_ratio': 0.4924594875235595, 'rf_n_estimators': 116, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 60}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:33:19,854] Trial 104 finished with value: 12.561579123498472 and parameters: {'lasso_alpha': 0.5801973481805478, 'elastic_alpha': 0.6490234269994042, 'elastic_l1_ratio': 0.4921586739214603, 'rf_n_estimators': 111, 'rf_max_depth': 7, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 61}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:33:30,579] Trial 105 finished with value: 12.564881524369548 and parameters: {'lasso_alpha': 0.5626956293309844, 'elastic_alpha': 0.6240295001997032, 'elastic_l1_ratio': 0.5384997177848999, 'rf_n_estimators': 120, 'rf_max_depth': 9, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 25}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:33:37,922] Trial 106 finished with value: 12.56763011948976 and parameters: {'lasso_alpha': 0.665263620010942, 'elastic_alpha': 0.6699879165910299, 'elastic_l1_ratio': 0.47148743728347636, 'rf_n_estimators': 102, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 22}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:33:45,120] Trial 107 finished with value: 12.557026784678254 and parameters: {'lasso_alpha': 0.6125342444913812, 'elastic_alpha': 0.5810978774108174, 'elastic_l1_ratio': 0.42156014044608325, 'rf_n_estimators': 115, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 30}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:33:52,425] Trial 108 finished with value: 12.563632716218788 and parameters: {'lasso_alpha': 0.5278887932427396, 'elastic_alpha': 0.5444793031297209, 'elastic_l1_ratio': 0.5196559555536959, 'rf_n_estimators': 90, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 69}. Best is trial 87 with value: 12.55546726813766.
# [I 2024-10-28 15:34:00,822] Trial 109 finished with value: 12.565809865837002 and parameters: {'lasso_alpha': 0.493127622701227, 'elastic_alpha': 0.515530397695553, 'elastic_l1_ratio': 0.41972574889058845, 'rf_n_estimators': 133, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 56}. Best is trial 87 with value: 12.55546726813766.
# ...
# [I 2024-10-28 16:59:43,943] Trial 462 finished with value: 12.559956893358107 and parameters: {'lasso_alpha': 0.5851263009851932, 'elastic_alpha': 0.8916711333435765, 'elastic_l1_ratio': 0.4042430028680353, 'rf_n_estimators': 77, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 60}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:00:05,104] Trial 463 finished with value: 12.600249374909847 and parameters: {'lasso_alpha': 0.5382231529868182, 'elastic_alpha': 0.8635509505378081, 'elastic_l1_ratio': 0.322837101919723, 'rf_n_estimators': 87, 'rf_max_depth': 15, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 54}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:00:20,284] Trial 464 finished with value: 12.560286984972288 and parameters: {'lasso_alpha': 0.6044454581435829, 'elastic_alpha': 0.730103767104005, 'elastic_l1_ratio': 0.38113173078592316, 'rf_n_estimators': 96, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 63}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:00:22,981] Trial 465 finished with value: 12.566395538642741 and parameters: {'lasso_alpha': 0.5686685051382028, 'elastic_alpha': 0.8102170562098975, 'elastic_l1_ratio': 0.44863814606331515, 'rf_n_estimators': 80, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_random_state': 69}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:00:38,414] Trial 466 finished with value: 12.571513666328885 and parameters: {'lasso_alpha': 0.5151888563221623, 'elastic_alpha': 0.7464253909992629, 'elastic_l1_ratio': 0.4799670641302005, 'rf_n_estimators': 90, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 57}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:00:52,136] Trial 467 finished with value: 12.57072428642094 and parameters: {'lasso_alpha': 0.6311024250785153, 'elastic_alpha': 0.7896744519467522, 'elastic_l1_ratio': 0.514737856931305, 'rf_n_estimators': 85, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 66}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:01:26,433] Trial 468 finished with value: 12.567391387897601 and parameters: {'lasso_alpha': 0.6804693648733734, 'elastic_alpha': 0.8361447111431622, 'elastic_l1_ratio': 0.5546080334961622, 'rf_n_estimators': 198, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 59}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:01:40,541] Trial 469 finished with value: 12.561757900421124 and parameters: {'lasso_alpha': 0.5522555054975422, 'elastic_alpha': 0.7123798699277896, 'elastic_l1_ratio': 0.46205167927965934, 'rf_n_estimators': 99, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 62}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:01:53,963] Trial 470 finished with value: 12.564696824717641 and parameters: {'lasso_alpha': 0.5846437752279319, 'elastic_alpha': 0.22519578722033767, 'elastic_l1_ratio': 0.49196876428903036, 'rf_n_estimators': 76, 'rf_max_depth': 9, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 61}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:02:13,460] Trial 471 finished with value: 12.579152026712439 and parameters: {'lasso_alpha': 0.6069565865553233, 'elastic_alpha': 0.7718695189076726, 'elastic_l1_ratio': 0.43001953287537953, 'rf_n_estimators': 91, 'rf_max_depth': 12, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 56}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:02:26,971] Trial 472 finished with value: 12.559431103040453 and parameters: {'lasso_alpha': 0.5705205341192092, 'elastic_alpha': 0.8759107732016799, 'elastic_l1_ratio': 0.5312951858126889, 'rf_n_estimators': 82, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 59}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:02:42,018] Trial 473 finished with value: 12.5681887454793 and parameters: {'lasso_alpha': 0.6561682208424806, 'elastic_alpha': 0.7974320026094737, 'elastic_l1_ratio': 0.3902196107914578, 'rf_n_estimators': 94, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 64}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:02:58,468] Trial 474 finished with value: 12.563668677173128 and parameters: {'lasso_alpha': 0.5254594618900131, 'elastic_alpha': 0.8251983878866865, 'elastic_l1_ratio': 0.44512169447629135, 'rf_n_estimators': 87, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 58}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:03:09,283] Trial 475 finished with value: 12.561945553158477 and parameters: {'lasso_alpha': 0.47956640315529264, 'elastic_alpha': 0.7499849564838837, 'elastic_l1_ratio': 0.42126506879082004, 'rf_n_estimators': 76, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 13}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:03:27,346] Trial 476 finished with value: 12.56350658529775 and parameters: {'lasso_alpha': 0.6220415820109513, 'elastic_alpha': 0.7200380631771385, 'elastic_l1_ratio': 0.481347960183054, 'rf_n_estimators': 101, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 61}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:03:37,010] Trial 477 finished with value: 12.5685186400334 and parameters: {'lasso_alpha': 0.589672526645738, 'elastic_alpha': 0.7010922745755825, 'elastic_l1_ratio': 0.5110492334728344, 'rf_n_estimators': 257, 'rf_max_depth': 8, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 48}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:03:51,702] Trial 478 finished with value: 12.555000261360192 and parameters: {'lasso_alpha': 0.5590595264199205, 'elastic_alpha': 0.7741376593541056, 'elastic_l1_ratio': 0.46589841853494923, 'rf_n_estimators': 82, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 60}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:04:04,290] Trial 479 finished with value: 12.576377648245895 and parameters: {'lasso_alpha': 0.5413821682081524, 'elastic_alpha': 0.7586654511572383, 'elastic_l1_ratio': 0.46204007855091744, 'rf_n_estimators': 72, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 56}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:04:19,787] Trial 480 finished with value: 12.557696123875889 and parameters: {'lasso_alpha': 0.554964944037469, 'elastic_alpha': 0.7341669429197442, 'elastic_l1_ratio': 0.47185677657371705, 'rf_n_estimators': 90, 'rf_max_depth': 9, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 63}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:04:32,307] Trial 481 finished with value: 12.56178655530147 and parameters: {'lasso_alpha': 0.19226665215076616, 'elastic_alpha': 0.8084328023764631, 'elastic_l1_ratio': 0.49180299477429673, 'rf_n_estimators': 80, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 58}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:04:45,893] Trial 482 finished with value: 12.564021694943417 and parameters: {'lasso_alpha': 0.521245410408119, 'elastic_alpha': 0.8559090128820801, 'elastic_l1_ratio': 0.4595963681796539, 'rf_n_estimators': 95, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 54}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:04:59,443] Trial 483 finished with value: 12.558759837924196 and parameters: {'lasso_alpha': 0.5030744640890434, 'elastic_alpha': 0.8916179712617438, 'elastic_l1_ratio': 0.5043785578466533, 'rf_n_estimators': 85, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 61}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:05:11,509] Trial 484 finished with value: 12.576598994610913 and parameters: {'lasso_alpha': 0.5457331372822084, 'elastic_alpha': 0.7823965017406764, 'elastic_l1_ratio': 0.4445791205338782, 'rf_n_estimators': 69, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 66}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:05:28,361] Trial 485 finished with value: 12.558632407000033 and parameters: {'lasso_alpha': 0.5602921519129035, 'elastic_alpha': 0.8290337806981585, 'elastic_l1_ratio': 0.478533525531268, 'rf_n_estimators': 78, 'rf_max_depth': 9, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 60}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:06:10,237] Trial 486 finished with value: 12.557149978012884 and parameters: {'lasso_alpha': 0.5333944575726248, 'elastic_alpha': 0.7645485990440725, 'elastic_l1_ratio': 0.45270721146261855, 'rf_n_estimators': 90, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 63}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:06:18,439] Trial 487 finished with value: 12.56374708398938 and parameters: {'lasso_alpha': 0.5766579336873703, 'elastic_alpha': 0.6925513943499593, 'elastic_l1_ratio': 0.6381717012377045, 'rf_n_estimators': 99, 'rf_max_depth': 8, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_random_state': 58}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:06:47,397] Trial 488 finished with value: 12.557663471555202 and parameters: {'lasso_alpha': 0.5684899806827368, 'elastic_alpha': 0.7245706546299288, 'elastic_l1_ratio': 0.48800888881966104, 'rf_n_estimators': 84, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 6}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:07:52,496] Trial 489 finished with value: 12.561379087602353 and parameters: {'lasso_alpha': 0.6344461454453711, 'elastic_alpha': 0.8595979599252801, 'elastic_l1_ratio': 0.5215996146114158, 'rf_n_estimators': 155, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 62}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:08:27,685] Trial 490 finished with value: 12.56293695411587 and parameters: {'lasso_alpha': 0.6060589424965638, 'elastic_alpha': 0.7487770165329943, 'elastic_l1_ratio': 0.46665459724758446, 'rf_n_estimators': 92, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 56}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:08:55,587] Trial 491 finished with value: 12.559637392108952 and parameters: {'lasso_alpha': 0.512905515814196, 'elastic_alpha': 0.9039583673833368, 'elastic_l1_ratio': 0.5021177611462145, 'rf_n_estimators': 74, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 59}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:09:28,952] Trial 492 finished with value: 12.56320098355459 and parameters: {'lasso_alpha': 0.4881661356848888, 'elastic_alpha': 0.8366576257113965, 'elastic_l1_ratio': 0.4358345109674056, 'rf_n_estimators': 87, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 65}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:10:45,281] Trial 493 finished with value: 12.561760921733107 and parameters: {'lasso_alpha': 0.5451154603816587, 'elastic_alpha': 0.7954527081817103, 'elastic_l1_ratio': 0.4809116169175628, 'rf_n_estimators': 173, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 60}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:11:28,906] Trial 494 finished with value: 12.568067980526688 and parameters: {'lasso_alpha': 0.9014500219074404, 'elastic_alpha': 0.7077395615760753, 'elastic_l1_ratio': 0.5691017254973008, 'rf_n_estimators': 102, 'rf_max_depth': 9, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 57}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:11:42,236] Trial 495 finished with value: 12.565325623950395 and parameters: {'lasso_alpha': 0.583705713808742, 'elastic_alpha': 0.8770430177020029, 'elastic_l1_ratio': 0.5301866296520504, 'rf_n_estimators': 63, 'rf_max_depth': 4, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 62}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:12:15,103] Trial 496 finished with value: 12.569949693713182 and parameters: {'lasso_alpha': 0.5585592024114702, 'elastic_alpha': 0.1541722908415718, 'elastic_l1_ratio': 0.501837006509945, 'rf_n_estimators': 96, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 68}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:13:56,864] Trial 497 finished with value: 12.570392526485275 and parameters: {'lasso_alpha': 0.6641162063241113, 'elastic_alpha': 0.7684668982350432, 'elastic_l1_ratio': 0.4580378044007651, 'rf_n_estimators': 284, 'rf_max_depth': 10, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 52}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:14:09,991] Trial 498 finished with value: 12.554684738603607 and parameters: {'lasso_alpha': 0.6118998511433832, 'elastic_alpha': 0.9301564408601251, 'elastic_l1_ratio': 0.4208653120385109, 'rf_n_estimators': 81, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 60}. Best is trial 381 with value: 12.552146540305982.
# [I 2024-10-28 17:14:22,866] Trial 499 finished with value: 12.562210831540458 and parameters: {'lasso_alpha': 0.6415512306343529, 'elastic_alpha': 0.9597313279499445, 'elastic_l1_ratio': 0.4869992739074537, 'rf_n_estimators': 78, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 64}. Best is trial 381 with value: 12.552146540305982.
# Best parameters: {'lasso_alpha': 0.6326730218311353, 'elastic_alpha': 0.8613078453165357, 'elastic_l1_ratio': 0.8888224759362712, 'rf_n_estimators': 88, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 60}
# Optimized Voting Regressor - Train MAE: 12.072384525863281, Test MAE: 12.488797325007173

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
# {'lasso_alpha': 0.6326730218311353, 'elastic_alpha': 0.8613078453165357, 'elastic_l1_ratio': 0.8888224759362712, 'rf_n_estimators': 88, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 60}

lasso = Lasso(alpha=0.6326730218311353, random_state=60)
elastic = ElasticNet(alpha=0.8613078453165357, l1_ratio=0.8888224759362712, random_state=60)
rf = RandomForestRegressor(
    n_estimators=88,
    max_depth=9,
    min_samples_split=10,
    min_samples_leaf=6,
    max_features=None,
    random_state=60
)

voting = VotingRegressor([('lasso', lasso), ('elastic', elastic), ('rf', rf)])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

voting.fit(X_train, y_train)
y_pred = voting.predict(X_test)

train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'{scores.mean()} / {train_score} / {test_score}')
# Out:
# 12.549272939789832 / 12.072384525863281 / 12.488797325007173

# %% [markdown]
# ## Basic Time Data

# %%
import pandas as pd

# 데이터 로드
train = pd.read_csv('./train.csv')

# yymm 컬럼을 날짜 형식으로 변환 (연도는 임의로 설정)
train['yymm'] = pd.to_datetime('2024' + train['yymm'], format='%Y%m%d %H:%M')

# day, hour, minute 컬럼 생성
train['day'] = train['yymm'].dt.day         # 일
train['hour'] = train['yymm'].dt.hour       # 시
train['minute'] = train['yymm'].dt.minute   # 분

# weekday 컬럼 생성
train['weekday'] = train['day'] % 7         # 요일 (0: 월요일, 1: 화요일, ..., 6: 일요일)

# yymm 컬럼 삭제
train.drop('yymm', axis=1, inplace=True)

# 결과 출력
train.head(10)
# Out:
#       V1      V2     V3     V4     V5  ...  Target  day  hour  minute  weekday
# 0 -5.327  12.250 -3.294 -7.855 -1.196  ...  44.521    1     0       0        1
# 1 -5.267  12.916 -3.220 -7.788 -1.196  ...  35.027    1     0      10        1
# 2 -5.127  13.583 -3.130 -7.658 -1.196  ...  13.920    1     0      20        1
# 3 -5.060  14.250 -3.130 -7.532 -1.196  ...  28.410    1     0      30        1
# 4 -4.967  14.916 -3.094 -7.462 -1.196  ...   1.647    1     0      40        1
# 5 -4.967  15.583 -3.020 -7.388 -1.196  ...   6.360    1     0      50        1
# 6 -4.827  16.250 -2.920 -7.288 -1.196  ...  34.535    1     1       0        1
# 7 -4.797  16.250 -2.920 -7.222 -1.196  ...  21.335    1     1      10        1
# 8 -4.737  16.250 -2.830 -7.188 -1.196  ...  34.687    1     1      20        1
# 9 -4.900  16.250 -2.890 -7.188 -1.196  ...  34.136    1     1      30        1
#
# [10 rows x 31 columns]

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
import optuna
from sklearn.ensemble import VotingRegressor, RandomForestRegressor
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
from optuna.samplers import TPESampler
# 데이터 로드
train = pd.read_csv('./train.csv')

# yymm 컬럼을 날짜 형식으로 변환 (연도는 임의로 설정)
train['yymm'] = pd.to_datetime('2024' + train['yymm'], format='%Y%m%d %H:%M')

# day, hour, minute 컬럼 생성
train['day'] = train['yymm'].dt.day         # 일
train['hour'] = train['yymm'].dt.hour       # 시
train['minute'] = train['yymm'].dt.minute   # 분

# weekday 컬럼 생성
train['weekday'] = train['day'] % 7         # 요일 (0: 월요일, 1: 화요일, ..., 6: 일요일)

# yymm 컬럼 삭제
train.drop('yymm', axis=1, inplace=True)

# 데이터 분할
X = train.drop('Target', axis=1)  # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']               # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# Optuna 목적 함수 수정
def objective(trial):
    # 하이퍼파라미터 선택
    lasso_alpha = trial.suggest_float('lasso_alpha', 0.001, 1.0)
    elastic_alpha = trial.suggest_float('elastic_alpha', 0.001, 1.0)
    elastic_l1_ratio = trial.suggest_float('elastic_l1_ratio', 0.1, 0.9)

    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 300)
    rf_max_depth = trial.suggest_int('rf_max_depth', 3, 20)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 10)
    rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', None])
    rf_random_state = trial.suggest_int('rf_random_state', 1, 100)
    
    gbr_n_estimators = trial.suggest_int('gbr_n_estimators', 50, 300)
    gbr_max_depth = trial.suggest_int('gbr_max_depth', 3, 20)
    gbr_learning_rate = trial.suggest_float('gbr_learning_rate', 0.01, 0.3)
    
    svr_C = trial.suggest_float('svr_C', 0.1, 10)
    svr_epsilon = trial.suggest_float('svr_epsilon', 0.01, 1.0)

    # 모델 정의
    lasso = Lasso(alpha=lasso_alpha, random_state=rf_random_state)
    elastic = ElasticNet(alpha=elastic_alpha, l1_ratio=elastic_l1_ratio, random_state=rf_random_state)
    rf = RandomForestRegressor(
        n_estimators=rf_n_estimators,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        max_features=rf_max_features,
        random_state=rf_random_state
    )
    gbr = GradientBoostingRegressor(
        n_estimators=gbr_n_estimators,
        max_depth=gbr_max_depth,
        learning_rate=gbr_learning_rate,
        random_state=rf_random_state
    )
    svr = SVR(C=svr_C, epsilon=svr_epsilon)

    # VotingRegressor 정의
    voting = VotingRegressor([
        ('lasso', lasso), 
        ('elastic', elastic), 
        ('rf', rf), 
        ('gbr', gbr), 
        ('svr', svr)
    ])
    
    # 5-fold 교차 검증으로 평가
    scores = cross_val_score(voting, X_train, y_train, cv=5, scoring=mae_scorer)
    return scores.mean()

# Optuna 최적화 실행
study = optuna.create_study(direction='minimize', sampler=TPESampler())
study.optimize(objective, n_trials=50)

# 최적 하이퍼파라미터로 VotingRegressor 학습
best_lasso = Lasso(alpha=study.best_params['lasso_alpha'], random_state=study.best_params['rf_random_state'])
best_elastic = ElasticNet(alpha=study.best_params['elastic_alpha'], l1_ratio=study.best_params['elastic_l1_ratio'], random_state=study.best_params['rf_random_state'])
best_rf = RandomForestRegressor(
    n_estimators=study.best_params['rf_n_estimators'],
    max_depth=study.best_params['rf_max_depth'],
    min_samples_split=study.best_params['rf_min_samples_split'],
    min_samples_leaf=study.best_params['rf_min_samples_leaf'],
    max_features=study.best_params['rf_max_features'],
    random_state=study.best_params['rf_random_state']
)
best_gbr = GradientBoostingRegressor(
    n_estimators=study.best_params['gbr_n_estimators'],
    max_depth=study.best_params['gbr_max_depth'],
    learning_rate=study.best_params['gbr_learning_rate'],
    random_state=study.best_params['rf_random_state']
)
best_svr = SVR(C=study.best_params['svr_C'], epsilon=study.best_params['svr_epsilon'])

voting_best = VotingRegressor([
    ('lasso', best_lasso), 
    ('elastic', best_elastic), 
    ('rf', best_rf), 
    ('gbr', best_gbr), 
    ('svr', best_svr)
])

# 최적화된 모델 학습 및 평가
voting_best.fit(X_train, y_train)
y_pred = voting_best.predict(X_test)

train_score = mean_absolute_error(y_train, voting_best.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'Optimized Voting Regressor - Train MAE: {train_score}, Test MAE: {test_score}')
# Out:
# [I 2024-10-28 21:22:48,959] A new study created in memory with name: no-name-26e42622-7d57-4acf-9c8a-9b52c9db0fa4
# [I 2024-10-28 21:23:52,751] Trial 0 finished with value: 12.668818421658505 and parameters: {'lasso_alpha': 0.7508557547922238, 'elastic_alpha': 0.18176404786409991, 'elastic_l1_ratio': 0.7085931887315663, 'rf_n_estimators': 140, 'rf_max_depth': 16, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 42, 'gbr_n_estimators': 115, 'gbr_max_depth': 16, 'gbr_learning_rate': 0.22951752749049986, 'svr_C': 3.77296433262724, 'svr_epsilon': 0.1567026538180402}. Best is trial 0 with value: 12.668818421658505.
# [I 2024-10-28 21:25:15,906] Trial 1 finished with value: 12.640724457439282 and parameters: {'lasso_alpha': 0.2818801638962993, 'elastic_alpha': 0.08222816071645095, 'elastic_l1_ratio': 0.21768531184775386, 'rf_n_estimators': 237, 'rf_max_depth': 9, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 96, 'gbr_n_estimators': 286, 'gbr_max_depth': 14, 'gbr_learning_rate': 0.24221112761314764, 'svr_C': 4.921461653210333, 'svr_epsilon': 0.5490282557492884}. Best is trial 1 with value: 12.640724457439282.
# [I 2024-10-28 21:26:16,805] Trial 2 finished with value: 12.66503114316519 and parameters: {'lasso_alpha': 0.3218135042593554, 'elastic_alpha': 0.7616549261164728, 'elastic_l1_ratio': 0.7728915727586413, 'rf_n_estimators': 264, 'rf_max_depth': 9, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 100, 'gbr_n_estimators': 285, 'gbr_max_depth': 9, 'gbr_learning_rate': 0.21836974562459793, 'svr_C': 4.8287400414636945, 'svr_epsilon': 0.5629573104287359}. Best is trial 1 with value: 12.640724457439282.
# [I 2024-10-28 21:27:14,726] Trial 3 finished with value: 12.6758891506454 and parameters: {'lasso_alpha': 0.03349658337016236, 'elastic_alpha': 0.5964650266987959, 'elastic_l1_ratio': 0.5341582238456497, 'rf_n_estimators': 127, 'rf_max_depth': 18, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 79, 'gbr_n_estimators': 68, 'gbr_max_depth': 17, 'gbr_learning_rate': 0.08421591259044812, 'svr_C': 5.47887309172148, 'svr_epsilon': 0.3233462404061947}. Best is trial 1 with value: 12.640724457439282.
# [I 2024-10-28 21:27:47,208] Trial 4 finished with value: 12.594609705910441 and parameters: {'lasso_alpha': 0.559603425639925, 'elastic_alpha': 0.9023676781539391, 'elastic_l1_ratio': 0.8170156420224141, 'rf_n_estimators': 280, 'rf_max_depth': 13, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_random_state': 94, 'gbr_n_estimators': 150, 'gbr_max_depth': 6, 'gbr_learning_rate': 0.0831746335971023, 'svr_C': 9.315373826146585, 'svr_epsilon': 0.21199941136943665}. Best is trial 4 with value: 12.594609705910441.
# [I 2024-10-28 21:29:03,152] Trial 5 finished with value: 12.650671223140957 and parameters: {'lasso_alpha': 0.9819203976020161, 'elastic_alpha': 0.26685416503853204, 'elastic_l1_ratio': 0.47346613621833755, 'rf_n_estimators': 295, 'rf_max_depth': 8, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 18, 'gbr_n_estimators': 135, 'gbr_max_depth': 16, 'gbr_learning_rate': 0.22185078961011936, 'svr_C': 2.6932467395530253, 'svr_epsilon': 0.47798543589990744}. Best is trial 4 with value: 12.594609705910441.
# [I 2024-10-28 21:30:02,169] Trial 6 finished with value: 12.66798665403526 and parameters: {'lasso_alpha': 0.0330207266918854, 'elastic_alpha': 0.3548921670176246, 'elastic_l1_ratio': 0.13131009898595716, 'rf_n_estimators': 192, 'rf_max_depth': 4, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_random_state': 70, 'gbr_n_estimators': 164, 'gbr_max_depth': 14, 'gbr_learning_rate': 0.2220296857616398, 'svr_C': 1.5602206620061798, 'svr_epsilon': 0.8468485101461768}. Best is trial 4 with value: 12.594609705910441.
# [I 2024-10-28 21:30:51,258] Trial 7 finished with value: 12.6731137333406 and parameters: {'lasso_alpha': 0.9488890843854478, 'elastic_alpha': 0.41622319707267064, 'elastic_l1_ratio': 0.6687294837099784, 'rf_n_estimators': 162, 'rf_max_depth': 19, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 97, 'gbr_n_estimators': 192, 'gbr_max_depth': 10, 'gbr_learning_rate': 0.19789368177079103, 'svr_C': 4.538217776795466, 'svr_epsilon': 0.10263134680385018}. Best is trial 4 with value: 12.594609705910441.
# [I 2024-10-28 21:31:14,050] Trial 8 finished with value: 12.664301900033497 and parameters: {'lasso_alpha': 0.8202806271328418, 'elastic_alpha': 0.9771296115756416, 'elastic_l1_ratio': 0.5013045589756583, 'rf_n_estimators': 173, 'rf_max_depth': 19, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_random_state': 27, 'gbr_n_estimators': 65, 'gbr_max_depth': 14, 'gbr_learning_rate': 0.2301557922222327, 'svr_C': 9.074270163426457, 'svr_epsilon': 0.17663606933761486}. Best is trial 4 with value: 12.594609705910441.
# [I 2024-10-28 21:32:33,438] Trial 9 finished with value: 12.653647466717956 and parameters: {'lasso_alpha': 0.8202913570430987, 'elastic_alpha': 0.6273250280317204, 'elastic_l1_ratio': 0.5200356156009391, 'rf_n_estimators': 149, 'rf_max_depth': 19, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 4, 'gbr_n_estimators': 211, 'gbr_max_depth': 13, 'gbr_learning_rate': 0.13922768972684646, 'svr_C': 2.0756289119700897, 'svr_epsilon': 0.7478961548867615}. Best is trial 4 with value: 12.594609705910441.
# [I 2024-10-28 21:32:52,907] Trial 10 finished with value: 12.560739519745926 and parameters: {'lasso_alpha': 0.5249690021054446, 'elastic_alpha': 0.9234114418603476, 'elastic_l1_ratio': 0.8974951022923324, 'rf_n_estimators': 62, 'rf_max_depth': 14, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 69, 'gbr_n_estimators': 221, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.010398646806793851, 'svr_C': 9.603374965239084, 'svr_epsilon': 0.32593551631246276}. Best is trial 10 with value: 12.560739519745926.
# [I 2024-10-28 21:33:13,688] Trial 11 finished with value: 12.565188871979782 and parameters: {'lasso_alpha': 0.5687821466865521, 'elastic_alpha': 0.9968033605320055, 'elastic_l1_ratio': 0.8982783208434193, 'rf_n_estimators': 51, 'rf_max_depth': 14, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 67, 'gbr_n_estimators': 233, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.019334785453528788, 'svr_C': 9.332094268502997, 'svr_epsilon': 0.357806121246248}. Best is trial 10 with value: 12.560739519745926.
# [I 2024-10-28 21:33:33,452] Trial 12 finished with value: 12.549755792344298 and parameters: {'lasso_alpha': 0.5766799274859804, 'elastic_alpha': 0.8221525283117354, 'elastic_l1_ratio': 0.874529953459651, 'rf_n_estimators': 50, 'rf_max_depth': 14, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 64, 'gbr_n_estimators': 238, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.010172253051238662, 'svr_C': 7.195062927565365, 'svr_epsilon': 0.3590899010236214}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:33:52,212] Trial 13 finished with value: 12.574012749204726 and parameters: {'lasso_alpha': 0.33102955898427455, 'elastic_alpha': 0.7779456995245796, 'elastic_l1_ratio': 0.8985311935267574, 'rf_n_estimators': 54, 'rf_max_depth': 15, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 51, 'gbr_n_estimators': 247, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.025647358152358423, 'svr_C': 7.259277135493889, 'svr_epsilon': 0.4068657307967989}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:34:23,029] Trial 14 finished with value: 12.603475744916977 and parameters: {'lasso_alpha': 0.4538635099061087, 'elastic_alpha': 0.813136817971742, 'elastic_l1_ratio': 0.6323168727701299, 'rf_n_estimators': 90, 'rf_max_depth': 12, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 54, 'gbr_n_estimators': 239, 'gbr_max_depth': 6, 'gbr_learning_rate': 0.06204433259507759, 'svr_C': 7.481095334171393, 'svr_epsilon': 0.6413198157391216}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:34:51,740] Trial 15 finished with value: 12.619732398858996 and parameters: {'lasso_alpha': 0.6606315531307705, 'elastic_alpha': 0.6372724116661087, 'elastic_l1_ratio': 0.3305612727110585, 'rf_n_estimators': 93, 'rf_max_depth': 11, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 78, 'gbr_n_estimators': 198, 'gbr_max_depth': 6, 'gbr_learning_rate': 0.15912154590103178, 'svr_C': 7.638633772207494, 'svr_epsilon': 0.026010902834850136}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:36:42,135] Trial 16 finished with value: 12.642482949877541 and parameters: {'lasso_alpha': 0.4326426929320828, 'elastic_alpha': 0.871635583652583, 'elastic_l1_ratio': 0.7888373493894282, 'rf_n_estimators': 83, 'rf_max_depth': 16, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 61, 'gbr_n_estimators': 264, 'gbr_max_depth': 20, 'gbr_learning_rate': 0.010402472709692164, 'svr_C': 6.383474649541358, 'svr_epsilon': 0.2931233082500935}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:37:17,009] Trial 17 finished with value: 12.6384658052805 and parameters: {'lasso_alpha': 0.2180091294983958, 'elastic_alpha': 0.6793007186742609, 'elastic_l1_ratio': 0.38611762417234824, 'rf_n_estimators': 113, 'rf_max_depth': 5, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_random_state': 38, 'gbr_n_estimators': 208, 'gbr_max_depth': 8, 'gbr_learning_rate': 0.29965834483880394, 'svr_C': 8.30326572210843, 'svr_epsilon': 0.453189946413804}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:37:44,760] Trial 18 finished with value: 12.575620229181444 and parameters: {'lasso_alpha': 0.6408926647853785, 'elastic_alpha': 0.4715625802967438, 'elastic_l1_ratio': 0.6121797548572694, 'rf_n_estimators': 208, 'rf_max_depth': 11, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 6, 'rf_max_features': 'log2', 'rf_random_state': 83, 'gbr_n_estimators': 258, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.05668979789705415, 'svr_C': 6.762626379932859, 'svr_epsilon': 0.9500697635145847}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:38:08,541] Trial 19 finished with value: 12.618656266742176 and parameters: {'lasso_alpha': 0.45115095672046995, 'elastic_alpha': 0.5387089127172741, 'elastic_l1_ratio': 0.8331879042368029, 'rf_n_estimators': 72, 'rf_max_depth': 17, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 41, 'gbr_n_estimators': 179, 'gbr_max_depth': 5, 'gbr_learning_rate': 0.12262906179969035, 'svr_C': 9.965712300125622, 'svr_epsilon': 0.25846817262602856}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:38:53,135] Trial 20 finished with value: 12.593026613874983 and parameters: {'lasso_alpha': 0.7097295429757632, 'elastic_alpha': 0.7297332103663818, 'elastic_l1_ratio': 0.697278712002015, 'rf_n_estimators': 114, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 5, 'rf_max_features': 'log2', 'rf_random_state': 58, 'gbr_n_estimators': 223, 'gbr_max_depth': 8, 'gbr_learning_rate': 0.04710493564818481, 'svr_C': 6.096705974944798, 'svr_epsilon': 0.6293582649593361}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:39:09,890] Trial 21 finished with value: 12.570119508757443 and parameters: {'lasso_alpha': 0.5654001601648665, 'elastic_alpha': 0.9892932377077954, 'elastic_l1_ratio': 0.8750301640431788, 'rf_n_estimators': 50, 'rf_max_depth': 14, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 68, 'gbr_n_estimators': 223, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.028527841590003926, 'svr_C': 0.31034757979656824, 'svr_epsilon': 0.37377705813190415}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:39:27,269] Trial 22 finished with value: 12.564330308610156 and parameters: {'lasso_alpha': 0.5648637544312118, 'elastic_alpha': 0.8980441858215699, 'elastic_l1_ratio': 0.7620174377842733, 'rf_n_estimators': 68, 'rf_max_depth': 13, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 68, 'gbr_n_estimators': 240, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.011161805933599212, 'svr_C': 8.491018573841385, 'svr_epsilon': 0.3635450211442413}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:39:57,645] Trial 23 finished with value: 12.626038016827422 and parameters: {'lasso_alpha': 0.39248916156259767, 'elastic_alpha': 0.8945856643457583, 'elastic_l1_ratio': 0.7401156210476776, 'rf_n_estimators': 68, 'rf_max_depth': 12, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 84, 'gbr_n_estimators': 266, 'gbr_max_depth': 5, 'gbr_learning_rate': 0.09736450263206557, 'svr_C': 8.411342648444272, 'svr_epsilon': 0.2780187856327577}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:40:42,372] Trial 24 finished with value: 12.611937814018708 and parameters: {'lasso_alpha': 0.5124576779432942, 'elastic_alpha': 0.8251312304459933, 'elastic_l1_ratio': 0.8454416276315886, 'rf_n_estimators': 106, 'rf_max_depth': 14, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_random_state': 72, 'gbr_n_estimators': 279, 'gbr_max_depth': 7, 'gbr_learning_rate': 0.0440980896248828, 'svr_C': 8.296340275108681, 'svr_epsilon': 0.4518829364089707}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:41:02,605] Trial 25 finished with value: 12.557878069686149 and parameters: {'lasso_alpha': 0.17189159989681063, 'elastic_alpha': 0.9148325793230095, 'elastic_l1_ratio': 0.776758836081533, 'rf_n_estimators': 73, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 61, 'gbr_n_estimators': 181, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.01083466967032884, 'svr_C': 8.481228947587736, 'svr_epsilon': 0.10040884365920366}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:41:50,166] Trial 26 finished with value: 12.624182003036145 and parameters: {'lasso_alpha': 0.1496319703833917, 'elastic_alpha': 0.7049717831485495, 'elastic_l1_ratio': 0.8118411321126777, 'rf_n_estimators': 95, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 47, 'gbr_n_estimators': 182, 'gbr_max_depth': 10, 'gbr_learning_rate': 0.06794101913452254, 'svr_C': 9.860973194873331, 'svr_epsilon': 0.028259693243818454}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:42:03,569] Trial 27 finished with value: 12.577117610404068 and parameters: {'lasso_alpha': 0.17101817857682988, 'elastic_alpha': 0.8320235455446375, 'elastic_l1_ratio': 0.6112560254530476, 'rf_n_estimators': 74, 'rf_max_depth': 6, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_random_state': 61, 'gbr_n_estimators': 101, 'gbr_max_depth': 5, 'gbr_learning_rate': 0.10230755113655467, 'svr_C': 7.753023725566478, 'svr_epsilon': 0.11110138864278021}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:42:23,467] Trial 28 finished with value: 12.557454185189561 and parameters: {'lasso_alpha': 0.38564747839228697, 'elastic_alpha': 0.9069804442536833, 'elastic_l1_ratio': 0.7390001414494753, 'rf_n_estimators': 128, 'rf_max_depth': 3, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 87, 'gbr_n_estimators': 162, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.04098913468068734, 'svr_C': 5.916028431368667, 'svr_epsilon': 0.213673188346642}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:42:51,793] Trial 29 finished with value: 12.595271943300055 and parameters: {'lasso_alpha': 0.23574015989792907, 'elastic_alpha': 0.04756693902577325, 'elastic_l1_ratio': 0.7229125472671775, 'rf_n_estimators': 133, 'rf_max_depth': 3, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 87, 'gbr_n_estimators': 98, 'gbr_max_depth': 11, 'gbr_learning_rate': 0.039953483211069146, 'svr_C': 3.856463693740362, 'svr_epsilon': 0.12680354263726915}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:43:18,474] Trial 30 finished with value: 12.57828328653981 and parameters: {'lasso_alpha': 0.12225495266499133, 'elastic_alpha': 0.5458563211102602, 'elastic_l1_ratio': 0.6588250358028032, 'rf_n_estimators': 145, 'rf_max_depth': 3, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 31, 'gbr_n_estimators': 129, 'gbr_max_depth': 7, 'gbr_learning_rate': 0.07064067070210522, 'svr_C': 6.793285343701568, 'svr_epsilon': 0.20926451597123072}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:43:47,107] Trial 31 finished with value: 12.578199965387473 and parameters: {'lasso_alpha': 0.34731742778120067, 'elastic_alpha': 0.9336050879541147, 'elastic_l1_ratio': 0.8494432817356669, 'rf_n_estimators': 63, 'rf_max_depth': 16, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 75, 'gbr_n_estimators': 159, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.034816870102090336, 'svr_C': 5.621918524934962, 'svr_epsilon': 0.21278126133159714}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:44:29,816] Trial 32 finished with value: 12.579444134036896 and parameters: {'lasso_alpha': 0.5023366805280169, 'elastic_alpha': 0.8412041222955361, 'elastic_l1_ratio': 0.7202333571441364, 'rf_n_estimators': 108, 'rf_max_depth': 15, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 90, 'gbr_n_estimators': 172, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.03144031828749631, 'svr_C': 8.856210801887865, 'svr_epsilon': 0.09397436885493081}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:44:50,696] Trial 33 finished with value: 12.550577123481371 and parameters: {'lasso_alpha': 0.6300802346845054, 'elastic_alpha': 0.9602205021560546, 'elastic_l1_ratio': 0.7776092464806984, 'rf_n_estimators': 85, 'rf_max_depth': 9, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 63, 'gbr_n_estimators': 196, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.011150734970622645, 'svr_C': 7.068139569532237, 'svr_epsilon': 0.25028009002954715}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:45:13,651] Trial 34 finished with value: 12.576864860936933 and parameters: {'lasso_alpha': 0.6257747398696983, 'elastic_alpha': 0.7681669928782116, 'elastic_l1_ratio': 0.5596923402836866, 'rf_n_estimators': 83, 'rf_max_depth': 9, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 56, 'gbr_n_estimators': 198, 'gbr_max_depth': 5, 'gbr_learning_rate': 0.052775245949578414, 'svr_C': 5.598097145581868, 'svr_epsilon': 0.17127108501049926}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:45:37,453] Trial 35 finished with value: 12.60427395183237 and parameters: {'lasso_alpha': 0.7647665982218127, 'elastic_alpha': 0.9498700286217389, 'elastic_l1_ratio': 0.7779200346725882, 'rf_n_estimators': 125, 'rf_max_depth': 7, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 50, 'gbr_n_estimators': 144, 'gbr_max_depth': 7, 'gbr_learning_rate': 0.1679840147597997, 'svr_C': 6.882988161690602, 'svr_epsilon': 0.2506033961694194}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:45:56,869] Trial 36 finished with value: 12.595476732285244 and parameters: {'lasso_alpha': 0.09361489493742764, 'elastic_alpha': 0.1765818684344203, 'elastic_l1_ratio': 0.7986184114505908, 'rf_n_estimators': 101, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 63, 'gbr_n_estimators': 186, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.08102685988494224, 'svr_C': 4.863143493265057, 'svr_epsilon': 0.5397669933650892}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:46:23,961] Trial 37 finished with value: 12.599048543916119 and parameters: {'lasso_alpha': 0.28480813116579284, 'elastic_alpha': 0.8724201464509191, 'elastic_l1_ratio': 0.6872880274751532, 'rf_n_estimators': 222, 'rf_max_depth': 8, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 45, 'gbr_n_estimators': 160, 'gbr_max_depth': 6, 'gbr_learning_rate': 0.11044600399882946, 'svr_C': 6.2574988674520595, 'svr_epsilon': 0.061511894348116616}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:46:57,756] Trial 38 finished with value: 12.651660899617942 and parameters: {'lasso_alpha': 0.7568919804290987, 'elastic_alpha': 0.7885043056194776, 'elastic_l1_ratio': 0.40368478253464923, 'rf_n_estimators': 127, 'rf_max_depth': 5, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 79, 'gbr_n_estimators': 121, 'gbr_max_depth': 8, 'gbr_learning_rate': 0.29527313912208425, 'svr_C': 3.6776524382308358, 'svr_epsilon': 0.15662014922470502}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:48:57,404] Trial 39 finished with value: 12.658990476896005 and parameters: {'lasso_alpha': 0.39264778000204337, 'elastic_alpha': 0.7387596755647478, 'elastic_l1_ratio': 0.7615260205694925, 'rf_n_estimators': 250, 'rf_max_depth': 10, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 94, 'gbr_n_estimators': 297, 'gbr_max_depth': 19, 'gbr_learning_rate': 0.188468472617492, 'svr_C': 7.883584017364871, 'svr_epsilon': 0.2978317461344805}. Best is trial 12 with value: 12.549755792344298.
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.738e+04, tolerance: 5.203e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.580e+04, tolerance: 5.242e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.200e+04, tolerance: 5.323e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.833e+04, tolerance: 5.276e+01
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-10-28 21:49:48,040] Trial 40 finished with value: 12.676490149493228 and parameters: {'lasso_alpha': 0.005039864764188273, 'elastic_alpha': 0.961707207328119, 'elastic_l1_ratio': 0.10906113951947183, 'rf_n_estimators': 157, 'rf_max_depth': 8, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 64, 'gbr_n_estimators': 151, 'gbr_max_depth': 9, 'gbr_learning_rate': 0.27650641394098946, 'svr_C': 4.329158230582223, 'svr_epsilon': 0.4025691399699166}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:50:08,158] Trial 41 finished with value: 12.554005425527816 and parameters: {'lasso_alpha': 0.6094700235775052, 'elastic_alpha': 0.9258227364619439, 'elastic_l1_ratio': 0.8574475534612735, 'rf_n_estimators': 82, 'rf_max_depth': 12, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 73, 'gbr_n_estimators': 212, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.011678980684726968, 'svr_C': 9.27016500087885, 'svr_epsilon': 0.23453124169160086}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:50:31,167] Trial 42 finished with value: 12.561080188411449 and parameters: {'lasso_alpha': 0.6130536723710948, 'elastic_alpha': 0.8713006853989097, 'elastic_l1_ratio': 0.8526089175128811, 'rf_n_estimators': 82, 'rf_max_depth': 13, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 73, 'gbr_n_estimators': 202, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.023713165378603053, 'svr_C': 8.816510598587852, 'svr_epsilon': 0.23076093263634462}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:50:51,249] Trial 43 finished with value: 12.562577227758238 and parameters: {'lasso_alpha': 0.7029289051954277, 'elastic_alpha': 0.9320777865157792, 'elastic_l1_ratio': 0.8166021442223639, 'rf_n_estimators': 80, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 82, 'gbr_n_estimators': 168, 'gbr_max_depth': 5, 'gbr_learning_rate': 0.0360685886811582, 'svr_C': 7.050186196591319, 'svr_epsilon': 0.17357284265498096}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:51:07,992] Trial 44 finished with value: 12.558249597294603 and parameters: {'lasso_alpha': 0.6846213196720177, 'elastic_alpha': 0.9815083668273286, 'elastic_l1_ratio': 0.7580828549788137, 'rf_n_estimators': 95, 'rf_max_depth': 12, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 89, 'gbr_n_estimators': 211, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.01999013124808325, 'svr_C': 7.927444007897153, 'svr_epsilon': 0.33110952864041976}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:51:30,096] Trial 45 finished with value: 12.563407271677933 and parameters: {'lasso_alpha': 0.8756853516160641, 'elastic_alpha': 0.9326918990964344, 'elastic_l1_ratio': 0.5682054439257559, 'rf_n_estimators': 192, 'rf_max_depth': 11, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 76, 'gbr_n_estimators': 187, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.049458796691283814, 'svr_C': 6.089701163061916, 'svr_epsilon': 0.06746091511031993}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:52:51,180] Trial 46 finished with value: 12.656736857852849 and parameters: {'lasso_alpha': 0.589509821537096, 'elastic_alpha': 0.2967516303501868, 'elastic_l1_ratio': 0.24886175860212523, 'rf_n_estimators': 61, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 98, 'gbr_n_estimators': 216, 'gbr_max_depth': 16, 'gbr_learning_rate': 0.07811382011849742, 'svr_C': 5.228566385819083, 'svr_epsilon': 0.20745972816756378}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:53:27,230] Trial 47 finished with value: 12.559053809090443 and parameters: {'lasso_alpha': 0.4719637990180596, 'elastic_alpha': 0.8494505757145999, 'elastic_l1_ratio': 0.8677781352533576, 'rf_n_estimators': 174, 'rf_max_depth': 13, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 53, 'gbr_n_estimators': 52, 'gbr_max_depth': 3, 'gbr_learning_rate': 0.012259841066757, 'svr_C': 9.309112247350285, 'svr_epsilon': 0.13832028770270186}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:53:59,242] Trial 48 finished with value: 12.605960762526763 and parameters: {'lasso_alpha': 0.8187148421628918, 'elastic_alpha': 0.6673542859073941, 'elastic_l1_ratio': 0.8137291942583775, 'rf_n_estimators': 118, 'rf_max_depth': 18, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 59, 'gbr_n_estimators': 229, 'gbr_max_depth': 6, 'gbr_learning_rate': 0.03272819659679121, 'svr_C': 8.850926652282192, 'svr_epsilon': 0.4118193523114304}. Best is trial 12 with value: 12.549755792344298.
# [I 2024-10-28 21:54:47,048] Trial 49 finished with value: 12.626692787463458 and parameters: {'lasso_alpha': 0.38492939906978085, 'elastic_alpha': 0.7950452899193221, 'elastic_l1_ratio': 0.6674127801274707, 'rf_n_estimators': 59, 'rf_max_depth': 15, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 65, 'gbr_n_estimators': 141, 'gbr_max_depth': 13, 'gbr_learning_rate': 0.022029173260507916, 'svr_C': 7.468846413915176, 'svr_epsilon': 0.293029039631317}. Best is trial 12 with value: 12.549755792344298.
# Optimized Voting Regressor - Train MAE: 11.779678761381117, Test MAE: 12.448669792907314

# %%
study.best_params
# Out:
# {'lasso_alpha': 0.5766799274859804,
#  'elastic_alpha': 0.8221525283117354,
#  'elastic_l1_ratio': 0.874529953459651,
#  'rf_n_estimators': 50,
#  'rf_max_depth': 14,
#  'rf_min_samples_split': 5,
#  'rf_min_samples_leaf': 1,
#  'rf_max_features': 'log2',
#  'rf_random_state': 64,
#  'gbr_n_estimators': 238,
#  'gbr_max_depth': 3,
#  'gbr_learning_rate': 0.010172253051238662,
#  'svr_C': 7.195062927565365,
#  'svr_epsilon': 0.3590899010236214}

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 로드
train = pd.read_csv('./train.csv')

# yymm 컬럼을 날짜 형식으로 변환 (연도는 임의로 설정)
train['yymm'] = pd.to_datetime('2024' + train['yymm'], format='%Y%m%d %H:%M')

# day, hour, minute 컬럼 생성
train['day'] = train['yymm'].dt.day         # 일
train['hour'] = train['yymm'].dt.hour       # 시
train['minute'] = train['yymm'].dt.minute

# weekday 컬럼 생성
train['weekday'] = train['day'] % 7         # 요일 (0: 월요일, 1: 화요일, ..., 6: 일요일)

# yymm 컬럼 삭제
train.drop('yymm', axis=1, inplace=True)


# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
# {'lasso_alpha': 0.8422730237975117, 'elastic_alpha': 0.9491303377885107, 'elastic_l1_ratio': 0.7173804553247742, 'rf_n_estimators': 158, 'rf_max_depth': 9, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 45, 'gbr_n_estimators': 102, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.018268910533320307, 'svr_C': 5.906266623527182, 'svr_epsilon': 0.6564267398355691}
lasso = Lasso(alpha=0.5766799274859804, random_state=64)
elastic = ElasticNet(alpha=0.8221525283117354, l1_ratio=0.874529953459651, random_state=64)
rf = RandomForestRegressor(
    n_estimators=50,
    max_depth=14,
    min_samples_split=5,
    min_samples_leaf=1,
    max_features='log2',
    random_state=64
)
gbr = GradientBoostingRegressor(
    n_estimators=238,
    max_depth=3,
    learning_rate=0.010172253051238662,
    random_state=64
)
svr = SVR(C=7.195062927565365, epsilon=0.3590899010236214)

voting = VotingRegressor([
    ('lasso', lasso), 
    ('elastic', elastic), 
    ('rf', rf), 
    ('gbr', gbr), 
    ('svr', svr)
])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

voting.fit(X_train, y_train)
y_pred = voting.predict(X_test)

train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'{scores.mean()} / {train_score} / {test_score}')
# Out:
# 12.543629280213713 / 11.779678761381117 / 12.448669792907314

# %%
study.best_params
# Out:
# {'lasso_alpha': 0.8422730237975117,
#  'elastic_alpha': 0.9491303377885107,
#  'elastic_l1_ratio': 0.7173804553247742,
#  'rf_n_estimators': 158,
#  'rf_max_depth': 9,
#  'rf_min_samples_split': 8,
#  'rf_min_samples_leaf': 4,
#  'rf_max_features': 'sqrt',
#  'rf_random_state': 45,
#  'gbr_n_estimators': 102,
#  'gbr_max_depth': 4,
#  'gbr_learning_rate': 0.018268910533320307,
#  'svr_C': 5.906266623527182,
#  'svr_epsilon': 0.6564267398355691}

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 로드
train = pd.read_csv('./train.csv')

# yymm 컬럼을 날짜 형식으로 변환 (연도는 임의로 설정)
train['yymm'] = pd.to_datetime('2024' + train['yymm'], format='%Y%m%d %H:%M')

# day, hour, minute 컬럼 생성
train['day'] = train['yymm'].dt.day         # 일
train['hour'] = train['yymm'].dt.hour       # 시
train['minute'] = train['yymm'].dt.minute

# weekday 컬럼 생성
train['weekday'] = train['day'] % 7         # 요일 (0: 월요일, 1: 화요일, ..., 6: 일요일)

# yymm 컬럼 삭제
train.drop('yymm', axis=1, inplace=True)


# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
# {'lasso_alpha': 0.8422730237975117, 'elastic_alpha': 0.9491303377885107, 'elastic_l1_ratio': 0.7173804553247742, 'rf_n_estimators': 158, 'rf_max_depth': 9, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 45, 'gbr_n_estimators': 102, 'gbr_max_depth': 4, 'gbr_learning_rate': 0.018268910533320307, 'svr_C': 5.906266623527182, 'svr_epsilon': 0.6564267398355691}

lasso = Lasso(alpha=0.8422730237975117, random_state=45)
elastic = ElasticNet(alpha=0.9491303377885107, l1_ratio=0.7173804553247742, random_state=45)
rf = RandomForestRegressor(
    n_estimators=158,
    max_depth=9,
    min_samples_split=8,
    min_samples_leaf=4,
    max_features='sqrt',
    random_state=45
)
gbr = GradientBoostingRegressor(
    n_estimators=102,
    max_depth=4,
    learning_rate=0.018268910533320307,
    random_state=45
)
svr = SVR(C=5.906266623527182, epsilon=0.6564267398355691)

voting = VotingRegressor([
    ('lasso', lasso), 
    ('elastic', elastic), 
    ('rf', rf), 
    ('gbr', gbr), 
    ('svr', svr)
])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

voting.fit(X_train, y_train)
y_pred = voting.predict(X_test)

train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'{scores.mean()} / {train_score} / {test_score}')
# Out:
# 12.54172378378728 / 12.12218583237527 / 12.458393952008992

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
lr = LinearRegression()
ridge = Ridge(random_state=42)
lasso = Lasso(random_state=42)
elastic = ElasticNet(random_state=42)
svr = SVR()
gb = GradientBoostingRegressor(random_state=42)
rf = RandomForestRegressor(random_state=42)
xgb = XGBRegressor(random_state=42)
lgbm = LGBMRegressor(random_state=42)
dt = DecisionTreeRegressor(random_state=42)

voting1 = VotingRegressor([
    ('lr', lr),
    ('lasso', lasso),
    ('elastic', elastic),
    ('random_forest', rf),
    ('xgb', xgb),
    ('lgbm', lgbm)
])

voting2 = VotingRegressor([
    ('lasso', lasso),
    ('random_forest', rf),
    ('xgb', xgb),
    ('lgbm', lgbm)
])

voting3 = VotingRegressor([
    ('svr', svr),
    ('random_forest', rf),
    ('xgb', xgb),
])

models = {
    'Voting1': voting1,
    'Voting2': voting2,
}

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
for model_name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5, scoring=mae_scorer)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    train_score = mean_absolute_error(y_train, model.predict(X_train))
    test_score = mean_absolute_error(y_test, y_pred)

    print(f'{model_name}: {scores.mean()} / {train_score} / {test_score}')
# Out:
# Voting1: 12.60688779355655 / 9.123350168815875 / 12.59916436989187
# Voting2: 12.671473568583895 / 7.484227059334714 / 12.807629368722674

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
lr = LinearRegression()
ridge = Ridge(random_state=42)
lasso = Lasso(random_state=42)
elastic = ElasticNet(random_state=42)
svr = SVR()
gb = GradientBoostingRegressor(random_state=42)
rf = RandomForestRegressor(random_state=42)
xgb = XGBRegressor(random_state=42)
lgbm = LGBMRegressor(random_state=42)
dt = DecisionTreeRegressor(random_state=42)

voting1 = VotingRegressor([
    ('linear', lr),
    ('ridge', ridge),
    ('lasso', lasso)
])

voting2 = VotingRegressor([
    ('linear', lr),
    ('lasso', lasso),
    ('elastic', elastic)
])

voting3 = VotingRegressor([
    ('ridge', ridge),
    ('lasso', lasso),
    ('elastic', elastic)
])

models = {
    'Voting1': voting1,
    'Voting2': voting2,
    'Voiting3': voting3
}

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
for model_name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5, scoring=mae_scorer)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    train_score = mean_absolute_error(y_train, model.predict(X_train))
    test_score = mean_absolute_error(y_test, y_pred)

    print(f'{model_name}: {scores.mean()} / {train_score} / {test_score}')
# Out:
# Voting1: 12.577860675814023 / 12.520992571007 / 12.46450337287879
# Voting2: 12.556600719190508 / 12.531942285375514 / 12.466188836570359
# Voiting3: 12.556628895007307 / 12.531972435513197 / 12.466226516010302

# %%
import optuna
from sklearn.ensemble import VotingRegressor, RandomForestRegressor
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
from optuna.samplers import TPESampler

# 데이터 분할
X = train.drop('Target', axis=1)  # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']               # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# Optuna 목적 함수 정의
def objective(trial):
    # 하이퍼파라미터 선택
    lasso_alpha = trial.suggest_float('lasso_alpha', 0.001, 1.0)
    elastic_alpha = trial.suggest_float('elastic_alpha', 0.001, 1.0)
    elastic_l1_ratio = trial.suggest_float('elastic_l1_ratio', 0.1, 0.9)
    
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 300)
    rf_max_depth = trial.suggest_int('rf_max_depth', 3, 20)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 10)
    rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', None])
    rf_random_state = trial.suggest_int('rf_random_state', 1, 100)

    # 모델 정의
    lasso = Lasso(alpha=lasso_alpha, random_state=rf_random_state)
    elastic = ElasticNet(alpha=elastic_alpha, l1_ratio=elastic_l1_ratio, random_state=rf_random_state)
    rf = RandomForestRegressor(
        n_estimators=rf_n_estimators,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        max_features=rf_max_features,
        random_state=rf_random_state
    )
    
    # VotingRegressor 정의
    voting = VotingRegressor([('lasso', lasso), ('elastic', elastic), ('rf', rf)])
    
    # 5-fold 교차 검증으로 평가
    scores = cross_val_score(voting, X_train, y_train, cv=5, scoring=mae_scorer)
    return scores.mean()

# Optuna 최적화 실행
study = optuna.create_study(direction='minimize', sampler=TPESampler())
study.optimize(objective, n_trials=50)

# 최적 하이퍼파라미터 출력
print("Best parameters:", study.best_params)

# 최적 하이퍼파라미터로 VotingRegressor 학습
best_lasso = Lasso(alpha=study.best_params['lasso_alpha'], random_state=study.best_params['rf_random_state'])
best_elastic = ElasticNet(alpha=study.best_params['elastic_alpha'], l1_ratio=study.best_params['elastic_l1_ratio'], random_state=study.best_params['rf_random_state'])
best_rf = RandomForestRegressor(
    n_estimators=study.best_params['rf_n_estimators'],
    max_depth=study.best_params['rf_max_depth'],
    min_samples_split=study.best_params['rf_min_samples_split'],
    min_samples_leaf=study.best_params['rf_min_samples_leaf'],
    max_features=study.best_params['rf_max_features'],
    random_state=study.best_params['rf_random_state']
)

voting_best = VotingRegressor([('lasso', best_lasso), ('elastic', best_elastic), ('rf', best_rf)])

# 최적화된 모델 학습 및 평가
voting_best.fit(X_train, y_train)
y_pred = voting_best.predict(X_test)

train_score = mean_absolute_error(y_train, voting_best.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'Optimized Voting Regressor - Train MAE: {train_score}, Test MAE: {test_score}')
# Out:
# [I 2024-10-28 13:23:35,227] A new study created in memory with name: no-name-55bbf7b2-8107-4134-a95d-4407507fe174
# [I 2024-10-28 13:23:39,012] Trial 0 finished with value: 12.586220220865986 and parameters: {'lasso_alpha': 0.04951247206224487, 'elastic_alpha': 0.6863197688524071, 'elastic_l1_ratio': 0.7362861256359688, 'rf_n_estimators': 288, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 5, 'rf_max_features': 'log2', 'rf_random_state': 81}. Best is trial 0 with value: 12.586220220865986.
# [I 2024-10-28 13:23:50,850] Trial 1 finished with value: 12.617340948074608 and parameters: {'lasso_alpha': 0.17673415289192013, 'elastic_alpha': 0.05975465535802682, 'elastic_l1_ratio': 0.3249854222921561, 'rf_n_estimators': 100, 'rf_max_depth': 12, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 54}. Best is trial 0 with value: 12.586220220865986.
# [I 2024-10-28 13:23:53,483] Trial 2 finished with value: 12.617915116161118 and parameters: {'lasso_alpha': 0.04911217807693493, 'elastic_alpha': 0.7560098494981207, 'elastic_l1_ratio': 0.7447397449894712, 'rf_n_estimators': 90, 'rf_max_depth': 16, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 2}. Best is trial 0 with value: 12.586220220865986.
# [I 2024-10-28 13:23:59,704] Trial 3 finished with value: 12.59236575540296 and parameters: {'lasso_alpha': 0.49414213492844394, 'elastic_alpha': 0.3895873687519778, 'elastic_l1_ratio': 0.4236495721459934, 'rf_n_estimators': 253, 'rf_max_depth': 13, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 85}. Best is trial 0 with value: 12.586220220865986.
# [I 2024-10-28 13:24:00,998] Trial 4 finished with value: 12.591877216879308 and parameters: {'lasso_alpha': 0.2821445556814791, 'elastic_alpha': 0.2641906932261661, 'elastic_l1_ratio': 0.45638254940553835, 'rf_n_estimators': 145, 'rf_max_depth': 3, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 7}. Best is trial 0 with value: 12.586220220865986.
# [I 2024-10-28 13:24:04,831] Trial 5 finished with value: 12.599881737489643 and parameters: {'lasso_alpha': 0.6891629601846584, 'elastic_alpha': 0.20854443399070874, 'elastic_l1_ratio': 0.11440899688463678, 'rf_n_estimators': 167, 'rf_max_depth': 16, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 60}. Best is trial 0 with value: 12.586220220865986.
# [I 2024-10-28 13:24:15,707] Trial 6 finished with value: 12.571429419720054 and parameters: {'lasso_alpha': 0.5792052367809013, 'elastic_alpha': 0.49717146618445657, 'elastic_l1_ratio': 0.7230880726682766, 'rf_n_estimators': 114, 'rf_max_depth': 9, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 58}. Best is trial 6 with value: 12.571429419720054.
# [I 2024-10-28 13:24:59,202] Trial 7 finished with value: 12.61728402961606 and parameters: {'lasso_alpha': 0.8924609384927258, 'elastic_alpha': 0.7860743185780836, 'elastic_l1_ratio': 0.6600773448458596, 'rf_n_estimators': 291, 'rf_max_depth': 20, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 65}. Best is trial 6 with value: 12.571429419720054.
# [I 2024-10-28 13:25:02,588] Trial 8 finished with value: 12.592391317722484 and parameters: {'lasso_alpha': 0.3639465032339963, 'elastic_alpha': 0.45874782903668365, 'elastic_l1_ratio': 0.2685483548537607, 'rf_n_estimators': 132, 'rf_max_depth': 16, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 97}. Best is trial 6 with value: 12.571429419720054.
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.639e+02, tolerance: 5.203e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.715e+02, tolerance: 5.242e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.719e+02, tolerance: 5.323e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.854e+01, tolerance: 5.276e+01
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-10-28 13:25:10,768] Trial 9 finished with value: 12.593176197529964 and parameters: {'lasso_alpha': 0.1214236469117632, 'elastic_alpha': 0.023667246850837584, 'elastic_l1_ratio': 0.1324568343093394, 'rf_n_estimators': 120, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 28}. Best is trial 6 with value: 12.571429419720054.
# [I 2024-10-28 13:25:15,187] Trial 10 finished with value: 12.56132019616258 and parameters: {'lasso_alpha': 0.7000364112801918, 'elastic_alpha': 0.9737082848325345, 'elastic_l1_ratio': 0.8968219831995436, 'rf_n_estimators': 50, 'rf_max_depth': 8, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 31}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:25:20,063] Trial 11 finished with value: 12.57593654009271 and parameters: {'lasso_alpha': 0.704217439874103, 'elastic_alpha': 0.942264642097027, 'elastic_l1_ratio': 0.8876691075706584, 'rf_n_estimators': 59, 'rf_max_depth': 8, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 33}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:25:25,126] Trial 12 finished with value: 12.574974426017693 and parameters: {'lasso_alpha': 0.6924270197403982, 'elastic_alpha': 0.6028582833842584, 'elastic_l1_ratio': 0.8736039550528796, 'rf_n_estimators': 56, 'rf_max_depth': 9, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 38}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:25:41,316] Trial 13 finished with value: 12.573886438543674 and parameters: {'lasso_alpha': 0.9494721701902717, 'elastic_alpha': 0.9028308638930037, 'elastic_l1_ratio': 0.6125324456730346, 'rf_n_estimators': 184, 'rf_max_depth': 9, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 21}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:25:48,188] Trial 14 finished with value: 12.57341925824516 and parameters: {'lasso_alpha': 0.5345592228590202, 'elastic_alpha': 0.6257593817113379, 'elastic_l1_ratio': 0.7886596403194893, 'rf_n_estimators': 206, 'rf_max_depth': 3, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 43}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:25:53,532] Trial 15 finished with value: 12.570431600181221 and parameters: {'lasso_alpha': 0.8098361069603103, 'elastic_alpha': 0.5344516171898702, 'elastic_l1_ratio': 0.5594904233070721, 'rf_n_estimators': 82, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 71}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:25:54,437] Trial 16 finished with value: 12.576595961304776 and parameters: {'lasso_alpha': 0.8329739163008505, 'elastic_alpha': 0.9963673096665372, 'elastic_l1_ratio': 0.5680672172390839, 'rf_n_estimators': 75, 'rf_max_depth': 6, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_random_state': 73}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:25:57,291] Trial 17 finished with value: 12.569155697470809 and parameters: {'lasso_alpha': 0.8191185677327859, 'elastic_alpha': 0.3264538319277619, 'elastic_l1_ratio': 0.5047565277920324, 'rf_n_estimators': 52, 'rf_max_depth': 5, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 20}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:06,921] Trial 18 finished with value: 12.577003286371072 and parameters: {'lasso_alpha': 0.9704035666468201, 'elastic_alpha': 0.33509019548478336, 'elastic_l1_ratio': 0.3579212376891142, 'rf_n_estimators': 220, 'rf_max_depth': 4, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 16}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:07,870] Trial 19 finished with value: 12.587462800677011 and parameters: {'lasso_alpha': 0.789383736926064, 'elastic_alpha': 0.14501760401707, 'elastic_l1_ratio': 0.22075004837636525, 'rf_n_estimators': 55, 'rf_max_depth': 10, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_random_state': 45}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:26,331] Trial 20 finished with value: 12.591524269476734 and parameters: {'lasso_alpha': 0.4203355161074174, 'elastic_alpha': 0.8303128894601564, 'elastic_l1_ratio': 0.514562365097018, 'rf_n_estimators': 159, 'rf_max_depth': 14, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 17}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:30,891] Trial 21 finished with value: 12.566263316115995 and parameters: {'lasso_alpha': 0.7784237876479552, 'elastic_alpha': 0.562119005837368, 'elastic_l1_ratio': 0.5025619435971932, 'rf_n_estimators': 83, 'rf_max_depth': 5, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 27}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:35,143] Trial 22 finished with value: 12.57210472396684 and parameters: {'lasso_alpha': 0.6373499950130244, 'elastic_alpha': 0.3558612137560947, 'elastic_l1_ratio': 0.42593166945625865, 'rf_n_estimators': 77, 'rf_max_depth': 5, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 26}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:42,510] Trial 23 finished with value: 12.582395999914024 and parameters: {'lasso_alpha': 0.7587909080577562, 'elastic_alpha': 0.26195561748971624, 'elastic_l1_ratio': 0.6710970301794201, 'rf_n_estimators': 102, 'rf_max_depth': 7, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 11}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:44,902] Trial 24 finished with value: 12.565930691890358 and parameters: {'lasso_alpha': 0.8661226321837872, 'elastic_alpha': 0.6754166171709849, 'elastic_l1_ratio': 0.8320205365221095, 'rf_n_estimators': 51, 'rf_max_depth': 4, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 30}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:48,289] Trial 25 finished with value: 12.566430623363058 and parameters: {'lasso_alpha': 0.9198148740018135, 'elastic_alpha': 0.8560335594365309, 'elastic_l1_ratio': 0.8262925340637497, 'rf_n_estimators': 75, 'rf_max_depth': 4, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 35}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:26:58,104] Trial 26 finished with value: 12.570898202380373 and parameters: {'lasso_alpha': 0.6002287666678723, 'elastic_alpha': 0.6790335021835394, 'elastic_l1_ratio': 0.8178135274773206, 'rf_n_estimators': 116, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 48}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:05,218] Trial 27 finished with value: 12.587421129903234 and parameters: {'lasso_alpha': 0.8798077745624333, 'elastic_alpha': 0.7101607060429169, 'elastic_l1_ratio': 0.8794747889122828, 'rf_n_estimators': 67, 'rf_max_depth': 10, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 28}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:06,246] Trial 28 finished with value: 12.580212645756394 and parameters: {'lasso_alpha': 0.7291983939688389, 'elastic_alpha': 0.5447266872079773, 'elastic_l1_ratio': 0.656587980409166, 'rf_n_estimators': 92, 'rf_max_depth': 4, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 41}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:09,713] Trial 29 finished with value: 12.574101789322736 and parameters: {'lasso_alpha': 0.649205074551296, 'elastic_alpha': 0.6255097409089724, 'elastic_l1_ratio': 0.7634794014276238, 'rf_n_estimators': 257, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 30}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:12,269] Trial 30 finished with value: 12.578389247601407 and parameters: {'lasso_alpha': 0.8683155453022597, 'elastic_alpha': 0.43623236624423656, 'elastic_l1_ratio': 0.7058493192995672, 'rf_n_estimators': 140, 'rf_max_depth': 11, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 5, 'rf_max_features': 'log2', 'rf_random_state': 50}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:15,632] Trial 31 finished with value: 12.566149324970374 and parameters: {'lasso_alpha': 0.9930942419764339, 'elastic_alpha': 0.8821856383832662, 'elastic_l1_ratio': 0.8129516335574808, 'rf_n_estimators': 75, 'rf_max_depth': 4, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 35}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:21,211] Trial 32 finished with value: 12.567702695353619 and parameters: {'lasso_alpha': 0.9960001748855054, 'elastic_alpha': 0.9888273596349182, 'elastic_l1_ratio': 0.8344485450210489, 'rf_n_estimators': 102, 'rf_max_depth': 5, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 35}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:22,986] Trial 33 finished with value: 12.56881299247647 and parameters: {'lasso_alpha': 0.9234124051017442, 'elastic_alpha': 0.8869371795370316, 'elastic_l1_ratio': 0.7953493794650917, 'rf_n_estimators': 51, 'rf_max_depth': 3, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 22}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:29,682] Trial 34 finished with value: 12.573182019082745 and parameters: {'lasso_alpha': 0.7677200238689301, 'elastic_alpha': 0.7728911407329531, 'elastic_l1_ratio': 0.8987166054368818, 'rf_n_estimators': 89, 'rf_max_depth': 7, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 11}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:30,589] Trial 35 finished with value: 12.575915886750963 and parameters: {'lasso_alpha': 0.8425391792917654, 'elastic_alpha': 0.7064897084340336, 'elastic_l1_ratio': 0.7416155206104206, 'rf_n_estimators': 70, 'rf_max_depth': 5, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 2}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:34,006] Trial 36 finished with value: 12.575471611803122 and parameters: {'lasso_alpha': 0.999987365193178, 'elastic_alpha': 0.8115581017856057, 'elastic_l1_ratio': 0.3545669578938617, 'rf_n_estimators': 98, 'rf_max_depth': 3, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 38}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:36,948] Trial 37 finished with value: 12.570573630774334 and parameters: {'lasso_alpha': 0.9105027155737352, 'elastic_alpha': 0.9246943410158341, 'elastic_l1_ratio': 0.846326487469524, 'rf_n_estimators': 66, 'rf_max_depth': 4, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 55}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:39,217] Trial 38 finished with value: 12.568669207915637 and parameters: {'lasso_alpha': 0.7467138347898438, 'elastic_alpha': 0.7212756727936672, 'elastic_l1_ratio': 0.7722675305086648, 'rf_n_estimators': 126, 'rf_max_depth': 8, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 25}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:27:49,481] Trial 39 finished with value: 12.58871963450532 and parameters: {'lasso_alpha': 0.4429753505473359, 'elastic_alpha': 0.9384521359065154, 'elastic_l1_ratio': 0.7046606592968099, 'rf_n_estimators': 85, 'rf_max_depth': 12, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 32}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:18,028] Trial 40 finished with value: 12.640759374365281 and parameters: {'lasso_alpha': 0.24219280635051804, 'elastic_alpha': 0.5787842504599658, 'elastic_l1_ratio': 0.18109154315798354, 'rf_n_estimators': 151, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 46}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:21,288] Trial 41 finished with value: 12.568889557314417 and parameters: {'lasso_alpha': 0.9372390574474585, 'elastic_alpha': 0.859776583416763, 'elastic_l1_ratio': 0.8380114306612494, 'rf_n_estimators': 68, 'rf_max_depth': 4, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 39}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:27,361] Trial 42 finished with value: 12.563531268493872 and parameters: {'lasso_alpha': 0.8779011136097088, 'elastic_alpha': 0.6620270982814063, 'elastic_l1_ratio': 0.8509136724385958, 'rf_n_estimators': 107, 'rf_max_depth': 5, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 34}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:34,583] Trial 43 finished with value: 12.570123225950672 and parameters: {'lasso_alpha': 0.8589369069133839, 'elastic_alpha': 0.47035816929066565, 'elastic_l1_ratio': 0.8468802036256546, 'rf_n_estimators': 109, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 15}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:40,352] Trial 44 finished with value: 12.571307500618797 and parameters: {'lasso_alpha': 0.6728849053968684, 'elastic_alpha': 0.6477783630889999, 'elastic_l1_ratio': 0.899054298681673, 'rf_n_estimators': 86, 'rf_max_depth': 6, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 24}. Best is trial 10 with value: 12.56132019616258.
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.187e+03, tolerance: 5.203e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.065e+04, tolerance: 5.242e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.734e+03, tolerance: 5.323e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.148e+02, tolerance: 5.276e+01
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-10-28 13:28:42,584] Trial 45 finished with value: 12.589507463350316 and parameters: {'lasso_alpha': 0.011939213689065031, 'elastic_alpha': 0.762179074392608, 'elastic_l1_ratio': 0.7360361434060868, 'rf_n_estimators': 61, 'rf_max_depth': 3, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 32}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:45,624] Trial 46 finished with value: 12.575178637336212 and parameters: {'lasso_alpha': 0.5553302987910642, 'elastic_alpha': 0.5683019759372648, 'elastic_l1_ratio': 0.8050581683533392, 'rf_n_estimators': 186, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 54}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:51,470] Trial 47 finished with value: 12.573435920147947 and parameters: {'lasso_alpha': 0.7915995942336614, 'elastic_alpha': 0.40166290713720093, 'elastic_l1_ratio': 0.6283648542596578, 'rf_n_estimators': 105, 'rf_max_depth': 5, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 36}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:53,580] Trial 48 finished with value: 12.57308806552262 and parameters: {'lasso_alpha': 0.7184070401480943, 'elastic_alpha': 0.6511549625361893, 'elastic_l1_ratio': 0.8603737051649137, 'rf_n_estimators': 133, 'rf_max_depth': 8, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 94}. Best is trial 10 with value: 12.56132019616258.
# [I 2024-10-28 13:28:56,432] Trial 49 finished with value: 12.563743206800215 and parameters: {'lasso_alpha': 0.9623703635497005, 'elastic_alpha': 0.5150745006448028, 'elastic_l1_ratio': 0.7748786143438091, 'rf_n_estimators': 50, 'rf_max_depth': 5, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 20}. Best is trial 10 with value: 12.56132019616258.
# Best parameters: {'lasso_alpha': 0.7000364112801918, 'elastic_alpha': 0.9737082848325345, 'elastic_l1_ratio': 0.8968219831995436, 'rf_n_estimators': 50, 'rf_max_depth': 8, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 31}
# Optimized Voting Regressor - Train MAE: 12.19373132878114, Test MAE: 12.494546429601435

# %%
import optuna
from sklearn.ensemble import VotingRegressor, RandomForestRegressor
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
from optuna.samplers import TPESampler

# 데이터 분할
X = train.drop('Target', axis=1)  # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']               # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# Optuna 목적 함수 정의
def objective(trial):
    # 하이퍼파라미터 선택
    lasso_alpha = trial.suggest_float('lasso_alpha', 0.001, 1.0)
    elastic_alpha = trial.suggest_float('elastic_alpha', 0.001, 1.0)
    elastic_l1_ratio = trial.suggest_float('elastic_l1_ratio', 0.1, 0.9)
    
    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 300)
    rf_max_depth = trial.suggest_int('rf_max_depth', 3, 20)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 10)
    rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', None])
    rf_random_state = trial.suggest_int('rf_random_state', 1, 100)

    # 모델 정의
    lasso = Lasso(alpha=lasso_alpha, random_state=rf_random_state)
    elastic = ElasticNet(alpha=elastic_alpha, l1_ratio=elastic_l1_ratio, random_state=rf_random_state)
    rf = RandomForestRegressor(
        n_estimators=rf_n_estimators,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        max_features=rf_max_features,
        random_state=rf_random_state
    )
    
    # VotingRegressor 정의
    voting = VotingRegressor([('lasso', lasso), ('elastic', elastic), ('rf', rf)])
    
    # 5-fold 교차 검증으로 평가
    scores = cross_val_score(voting, X_train, y_train, cv=5, scoring=mae_scorer)
    return scores.mean()

# Optuna 최적화 실행
study = optuna.create_study(direction='minimize', sampler=TPESampler())
study.optimize(objective, n_trials=100)

# 최적 하이퍼파라미터 출력
print("Best parameters:", study.best_params)

# 최적 하이퍼파라미터로 VotingRegressor 학습
best_lasso = Lasso(alpha=study.best_params['lasso_alpha'], random_state=study.best_params['rf_random_state'])
best_elastic = ElasticNet(alpha=study.best_params['elastic_alpha'], l1_ratio=study.best_params['elastic_l1_ratio'], random_state=study.best_params['rf_random_state'])
best_rf = RandomForestRegressor(
    n_estimators=study.best_params['rf_n_estimators'],
    max_depth=study.best_params['rf_max_depth'],
    min_samples_split=study.best_params['rf_min_samples_split'],
    min_samples_leaf=study.best_params['rf_min_samples_leaf'],
    max_features=study.best_params['rf_max_features'],
    random_state=study.best_params['rf_random_state']
)

voting_best = VotingRegressor([('lasso', best_lasso), ('elastic', best_elastic), ('rf', best_rf)])

# 최적화된 모델 학습 및 평가
voting_best.fit(X_train, y_train)
y_pred = voting_best.predict(X_test)

train_score = mean_absolute_error(y_train, voting_best.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'Optimized Voting Regressor - Train MAE: {train_score}, Test MAE: {test_score}')
# Out:
# [I 2024-10-28 22:21:53,611] A new study created in memory with name: no-name-2990cbde-0f07-43ff-b785-99d17b876074
# [I 2024-10-28 22:22:13,997] Trial 0 finished with value: 12.590844731075222 and parameters: {'lasso_alpha': 0.8757630761685458, 'elastic_alpha': 0.12894514214567518, 'elastic_l1_ratio': 0.38016502778259376, 'rf_n_estimators': 160, 'rf_max_depth': 12, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 17}. Best is trial 0 with value: 12.590844731075222.
# [I 2024-10-28 22:22:17,664] Trial 1 finished with value: 12.60707082642242 and parameters: {'lasso_alpha': 0.510540943071692, 'elastic_alpha': 0.251619491346435, 'elastic_l1_ratio': 0.464051899651561, 'rf_n_estimators': 139, 'rf_max_depth': 19, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 5, 'rf_max_features': 'log2', 'rf_random_state': 6}. Best is trial 0 with value: 12.590844731075222.
# [I 2024-10-28 22:22:34,206] Trial 2 finished with value: 12.58499047145801 and parameters: {'lasso_alpha': 0.15427442865664945, 'elastic_alpha': 0.4936638220756078, 'elastic_l1_ratio': 0.4740236528354512, 'rf_n_estimators': 170, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 16}. Best is trial 2 with value: 12.58499047145801.
# [I 2024-10-28 22:22:43,481] Trial 3 finished with value: 12.599636042984608 and parameters: {'lasso_alpha': 0.4546968488196813, 'elastic_alpha': 0.5745628204718536, 'elastic_l1_ratio': 0.5002161454360142, 'rf_n_estimators': 220, 'rf_max_depth': 16, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 1}. Best is trial 2 with value: 12.58499047145801.
# [I 2024-10-28 22:22:45,328] Trial 4 finished with value: 12.572174120844428 and parameters: {'lasso_alpha': 0.8313178800940385, 'elastic_alpha': 0.9549486343816408, 'elastic_l1_ratio': 0.8520676027980011, 'rf_n_estimators': 61, 'rf_max_depth': 12, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 5, 'rf_max_features': 'log2', 'rf_random_state': 93}. Best is trial 4 with value: 12.572174120844428.
# [I 2024-10-28 22:23:34,554] Trial 5 finished with value: 12.605644227647 and parameters: {'lasso_alpha': 0.9106966475324706, 'elastic_alpha': 0.2735437212967684, 'elastic_l1_ratio': 0.8594081910276578, 'rf_n_estimators': 272, 'rf_max_depth': 15, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 9}. Best is trial 4 with value: 12.572174120844428.
# [I 2024-10-28 22:23:41,346] Trial 6 finished with value: 12.583784338376514 and parameters: {'lasso_alpha': 0.3437656157052767, 'elastic_alpha': 0.5710566494885303, 'elastic_l1_ratio': 0.2934164133052932, 'rf_n_estimators': 300, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_random_state': 19}. Best is trial 4 with value: 12.572174120844428.
# [I 2024-10-28 22:23:48,088] Trial 7 finished with value: 12.598834201613311 and parameters: {'lasso_alpha': 0.4802939367653845, 'elastic_alpha': 0.1277937473179133, 'elastic_l1_ratio': 0.7110679995510806, 'rf_n_estimators': 260, 'rf_max_depth': 14, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 6, 'rf_max_features': 'log2', 'rf_random_state': 77}. Best is trial 4 with value: 12.572174120844428.
# [I 2024-10-28 22:23:50,312] Trial 8 finished with value: 12.591465431480936 and parameters: {'lasso_alpha': 0.09366224201009223, 'elastic_alpha': 0.6820179995915621, 'elastic_l1_ratio': 0.21976578004343833, 'rf_n_estimators': 92, 'rf_max_depth': 8, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 52}. Best is trial 4 with value: 12.572174120844428.
# [I 2024-10-28 22:23:55,011] Trial 9 finished with value: 12.57005330435548 and parameters: {'lasso_alpha': 0.9171981591090179, 'elastic_alpha': 0.9088985308097491, 'elastic_l1_ratio': 0.7243390185225699, 'rf_n_estimators': 176, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 4}. Best is trial 9 with value: 12.57005330435548.
# [I 2024-10-28 22:23:57,625] Trial 10 finished with value: 12.578105543294473 and parameters: {'lasso_alpha': 0.6953393672785393, 'elastic_alpha': 0.9979618888645845, 'elastic_l1_ratio': 0.6768194251369007, 'rf_n_estimators': 216, 'rf_max_depth': 3, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_random_state': 40}. Best is trial 9 with value: 12.57005330435548.
# [I 2024-10-28 22:23:58,708] Trial 11 finished with value: 12.567824716203301 and parameters: {'lasso_alpha': 0.9886284729353019, 'elastic_alpha': 0.9748145856425203, 'elastic_l1_ratio': 0.8970652828210942, 'rf_n_estimators': 57, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 100}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:01,117] Trial 12 finished with value: 12.577278697884521 and parameters: {'lasso_alpha': 0.9614387868679989, 'elastic_alpha': 0.816613300962071, 'elastic_l1_ratio': 0.7082491872668816, 'rf_n_estimators': 121, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 61}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:02,164] Trial 13 finished with value: 12.569708318557124 and parameters: {'lasso_alpha': 0.6869964081557063, 'elastic_alpha': 0.8303299286965613, 'elastic_l1_ratio': 0.8956332660729937, 'rf_n_estimators': 52, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 97}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:03,013] Trial 14 finished with value: 12.57080454127456 and parameters: {'lasso_alpha': 0.7033679911541533, 'elastic_alpha': 0.8063509625548377, 'elastic_l1_ratio': 0.8567498872578724, 'rf_n_estimators': 51, 'rf_max_depth': 5, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 99}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:04,336] Trial 15 finished with value: 12.579788655046531 and parameters: {'lasso_alpha': 0.6780787452451676, 'elastic_alpha': 0.7494085115782295, 'elastic_l1_ratio': 0.6038847286369746, 'rf_n_estimators': 88, 'rf_max_depth': 3, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 82}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:06,110] Trial 16 finished with value: 12.568855741925292 and parameters: {'lasso_alpha': 0.7335343559406421, 'elastic_alpha': 0.875580701000489, 'elastic_l1_ratio': 0.8980640216554949, 'rf_n_estimators': 94, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 78}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:08,561] Trial 17 finished with value: 12.583196271522597 and parameters: {'lasso_alpha': 0.7925441629080641, 'elastic_alpha': 0.40133224336854867, 'elastic_l1_ratio': 0.11158736089822874, 'rf_n_estimators': 98, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_random_state': 74}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:10,729] Trial 18 finished with value: 12.573778849626265 and parameters: {'lasso_alpha': 0.9958585968263782, 'elastic_alpha': 0.6586443447470691, 'elastic_l1_ratio': 0.7797823017852816, 'rf_n_estimators': 114, 'rf_max_depth': 6, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 87}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:14,027] Trial 19 finished with value: 12.575152212941237 and parameters: {'lasso_alpha': 0.6072826221058767, 'elastic_alpha': 0.9375647723826799, 'elastic_l1_ratio': 0.6034957900868689, 'rf_n_estimators': 74, 'rf_max_depth': 3, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 67}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:17,605] Trial 20 finished with value: 12.579831619534199 and parameters: {'lasso_alpha': 0.7865945317789353, 'elastic_alpha': 0.8844667736565883, 'elastic_l1_ratio': 0.7863200651364951, 'rf_n_estimators': 138, 'rf_max_depth': 10, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 37}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:18,848] Trial 21 finished with value: 12.573286105441133 and parameters: {'lasso_alpha': 0.5801209871725385, 'elastic_alpha': 0.8132042834632605, 'elastic_l1_ratio': 0.8943739742977127, 'rf_n_estimators': 57, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 100}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:20,458] Trial 22 finished with value: 12.57809067961512 and parameters: {'lasso_alpha': 0.3204221472684335, 'elastic_alpha': 0.7196387481147715, 'elastic_l1_ratio': 0.7893134785498884, 'rf_n_estimators': 76, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 88}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:21,378] Trial 23 finished with value: 12.575229077483616 and parameters: {'lasso_alpha': 0.7625452225824288, 'elastic_alpha': 0.8706375845186118, 'elastic_l1_ratio': 0.8942768033303412, 'rf_n_estimators': 50, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 92}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:23,142] Trial 24 finished with value: 12.575545707697566 and parameters: {'lasso_alpha': 0.6383219838712588, 'elastic_alpha': 0.9966551090035753, 'elastic_l1_ratio': 0.8030144921824542, 'rf_n_estimators': 108, 'rf_max_depth': 4, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 73}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:24,824] Trial 25 finished with value: 12.576954579289033 and parameters: {'lasso_alpha': 0.5523008897528826, 'elastic_alpha': 0.8429976826623142, 'elastic_l1_ratio': 0.6385037057966051, 'rf_n_estimators': 77, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 82}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:28,365] Trial 26 finished with value: 12.580240529036994 and parameters: {'lasso_alpha': 0.757222430016663, 'elastic_alpha': 0.7504157816995727, 'elastic_l1_ratio': 0.8138523168519451, 'rf_n_estimators': 131, 'rf_max_depth': 9, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 100}. Best is trial 11 with value: 12.567824716203301.
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.092e+05, tolerance: 5.203e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+05, tolerance: 5.242e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.154e+05, tolerance: 5.323e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.964e+04, tolerance: 5.276e+01
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-10-28 22:24:30,001] Trial 27 finished with value: 12.58780650461771 and parameters: {'lasso_alpha': 0.39307824252157153, 'elastic_alpha': 0.0032408780867301257, 'elastic_l1_ratio': 0.5475589408368164, 'rf_n_estimators': 72, 'rf_max_depth': 6, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 61}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:24:31,273] Trial 28 finished with value: 12.575140995077929 and parameters: {'lasso_alpha': 0.8553664747929717, 'elastic_alpha': 0.606073789960626, 'elastic_l1_ratio': 0.8848680648265653, 'rf_n_estimators': 99, 'rf_max_depth': 4, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 6, 'rf_max_features': 'log2', 'rf_random_state': 94}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:25:09,724] Trial 29 finished with value: 12.624424833294016 and parameters: {'lasso_alpha': 0.23139808865572548, 'elastic_alpha': 0.47525138232720726, 'elastic_l1_ratio': 0.37512049409354503, 'rf_n_estimators': 193, 'rf_max_depth': 20, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 81}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:25:33,932] Trial 30 finished with value: 12.583854380329672 and parameters: {'lasso_alpha': 0.8752842430145141, 'elastic_alpha': 0.9267346495948825, 'elastic_l1_ratio': 0.7349161067767755, 'rf_n_estimators': 151, 'rf_max_depth': 12, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 67}. Best is trial 11 with value: 12.567824716203301.
# [I 2024-10-28 22:25:38,157] Trial 31 finished with value: 12.566255164013267 and parameters: {'lasso_alpha': 0.9597602692401198, 'elastic_alpha': 0.9102480021453707, 'elastic_l1_ratio': 0.7494692035687717, 'rf_n_estimators': 190, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 33}. Best is trial 31 with value: 12.566255164013267.
# [I 2024-10-28 22:25:44,672] Trial 32 finished with value: 12.580421775270498 and parameters: {'lasso_alpha': 0.9485704258007238, 'elastic_alpha': 0.7621266544991441, 'elastic_l1_ratio': 0.8206694213009248, 'rf_n_estimators': 204, 'rf_max_depth': 13, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 37}. Best is trial 31 with value: 12.566255164013267.
# [I 2024-10-28 22:25:48,221] Trial 33 finished with value: 12.567407611987244 and parameters: {'lasso_alpha': 0.9989688205412112, 'elastic_alpha': 0.8677421401538891, 'elastic_l1_ratio': 0.745834087688419, 'rf_n_estimators': 159, 'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 30}. Best is trial 31 with value: 12.566255164013267.
# [I 2024-10-28 22:25:51,999] Trial 34 finished with value: 12.564409257678665 and parameters: {'lasso_alpha': 0.9983271700191506, 'elastic_alpha': 0.9646970621071718, 'elastic_l1_ratio': 0.7642107025058694, 'rf_n_estimators': 166, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 28}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:25:56,591] Trial 35 finished with value: 12.570436616513621 and parameters: {'lasso_alpha': 0.9972120032228196, 'elastic_alpha': 0.9680979479544497, 'elastic_l1_ratio': 0.6559067361227446, 'rf_n_estimators': 169, 'rf_max_depth': 11, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 25}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:26:01,280] Trial 36 finished with value: 12.577074804781663 and parameters: {'lasso_alpha': 0.9130635991024746, 'elastic_alpha': 0.9094444008044467, 'elastic_l1_ratio': 0.541227631198351, 'rf_n_estimators': 237, 'rf_max_depth': 9, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_random_state': 29}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:26:33,049] Trial 37 finished with value: 12.601466385184597 and parameters: {'lasso_alpha': 0.8580940758193876, 'elastic_alpha': 0.9425454572018943, 'elastic_l1_ratio': 0.7501663705806403, 'rf_n_estimators': 187, 'rf_max_depth': 18, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 46}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:26:37,015] Trial 38 finished with value: 12.583663127738987 and parameters: {'lasso_alpha': 0.8188381919724033, 'elastic_alpha': 0.3156525911895307, 'elastic_l1_ratio': 0.8296187052357689, 'rf_n_estimators': 154, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_random_state': 13}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:26:41,652] Trial 39 finished with value: 12.576054735060485 and parameters: {'lasso_alpha': 0.9350114974928525, 'elastic_alpha': 0.65963069610076, 'elastic_l1_ratio': 0.4271639566614199, 'rf_n_estimators': 240, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 3, 'rf_max_features': 'log2', 'rf_random_state': 24}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:26:45,694] Trial 40 finished with value: 12.572350002240377 and parameters: {'lasso_alpha': 0.9980190001317986, 'elastic_alpha': 0.9602940681362809, 'elastic_l1_ratio': 0.6807628628805573, 'rf_n_estimators': 183, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 32}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:26:49,149] Trial 41 finished with value: 12.566707137499249 and parameters: {'lasso_alpha': 0.865423622500259, 'elastic_alpha': 0.8820105899230101, 'elastic_l1_ratio': 0.7689503995654374, 'rf_n_estimators': 158, 'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 49}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:26:52,617] Trial 42 finished with value: 12.571669543457835 and parameters: {'lasso_alpha': 0.8914006917640291, 'elastic_alpha': 0.8701565778649247, 'elastic_l1_ratio': 0.7439080288437794, 'rf_n_estimators': 165, 'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 48}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:26:57,467] Trial 43 finished with value: 12.569274709746727 and parameters: {'lasso_alpha': 0.9536364982290747, 'elastic_alpha': 0.9824860928674873, 'elastic_l1_ratio': 0.7632684040188197, 'rf_n_estimators': 206, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 54}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:27:01,543] Trial 44 finished with value: 12.566553241504621 and parameters: {'lasso_alpha': 0.842773330496555, 'elastic_alpha': 0.7975892148394597, 'elastic_l1_ratio': 0.698462954510416, 'rf_n_estimators': 149, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 42}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:27:05,772] Trial 45 finished with value: 12.57471663594219 and parameters: {'lasso_alpha': 0.8321830799562975, 'elastic_alpha': 0.7894440771331681, 'elastic_l1_ratio': 0.6972345332869874, 'rf_n_estimators': 148, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 42}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:27:09,820] Trial 46 finished with value: 12.574768542478855 and parameters: {'lasso_alpha': 0.8786076297310895, 'elastic_alpha': 0.6919681789699462, 'elastic_l1_ratio': 0.6247722787514567, 'rf_n_estimators': 129, 'rf_max_depth': 13, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 20}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:27:13,814] Trial 47 finished with value: 12.573940269792521 and parameters: {'lasso_alpha': 0.9183468920322584, 'elastic_alpha': 0.8436591044796562, 'elastic_l1_ratio': 0.5700630445810819, 'rf_n_estimators': 179, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 30}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:27:18,983] Trial 48 finished with value: 12.579463347207707 and parameters: {'lasso_alpha': 0.8200259635799954, 'elastic_alpha': 0.5709905363327246, 'elastic_l1_ratio': 0.7077111768402891, 'rf_n_estimators': 161, 'rf_max_depth': 13, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 35}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:27:23,680] Trial 49 finished with value: 12.569089508510203 and parameters: {'lasso_alpha': 0.9495541778391303, 'elastic_alpha': 0.897318448482145, 'elastic_l1_ratio': 0.6631366630695247, 'rf_n_estimators': 196, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 43}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:27:58,040] Trial 50 finished with value: 12.582769922365134 and parameters: {'lasso_alpha': 0.9011396052539972, 'elastic_alpha': 0.7754853484076512, 'elastic_l1_ratio': 0.8460972044335779, 'rf_n_estimators': 221, 'rf_max_depth': 12, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 55}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:01,675] Trial 51 finished with value: 12.569824886783474 and parameters: {'lasso_alpha': 0.9711614541360692, 'elastic_alpha': 0.9272489703609796, 'elastic_l1_ratio': 0.7564621757847797, 'rf_n_estimators': 145, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 23}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:05,871] Trial 52 finished with value: 12.571589049461744 and parameters: {'lasso_alpha': 0.975441475295805, 'elastic_alpha': 0.8519257560049727, 'elastic_l1_ratio': 0.8612279884942452, 'rf_n_estimators': 167, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 50}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:09,602] Trial 53 finished with value: 12.574207359283537 and parameters: {'lasso_alpha': 0.9277146378021978, 'elastic_alpha': 0.8992624062118539, 'elastic_l1_ratio': 0.7265947829092653, 'rf_n_estimators': 121, 'rf_max_depth': 10, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 16}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:12,151] Trial 54 finished with value: 12.576048502763204 and parameters: {'lasso_alpha': 0.9993679301724167, 'elastic_alpha': 0.9957708713736009, 'elastic_l1_ratio': 0.8058957788629297, 'rf_n_estimators': 174, 'rf_max_depth': 4, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 45}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:19,763] Trial 55 finished with value: 12.57187746754031 and parameters: {'lasso_alpha': 0.8609510611699547, 'elastic_alpha': 0.9507015531293258, 'elastic_l1_ratio': 0.7687375076433934, 'rf_n_estimators': 296, 'rf_max_depth': 9, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 40}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:22,693] Trial 56 finished with value: 12.56842622900577 and parameters: {'lasso_alpha': 0.7989153264935431, 'elastic_alpha': 0.8141931752498277, 'elastic_l1_ratio': 0.8458022186167841, 'rf_n_estimators': 140, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 11}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:25,220] Trial 57 finished with value: 12.574416222978995 and parameters: {'lasso_alpha': 0.7330747087318259, 'elastic_alpha': 0.8945591428002405, 'elastic_l1_ratio': 0.6992758800214773, 'rf_n_estimators': 156, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 27}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:32,973] Trial 58 finished with value: 12.608769053966634 and parameters: {'lasso_alpha': 0.02820820642272054, 'elastic_alpha': 0.8418074609431233, 'elastic_l1_ratio': 0.490472894868793, 'rf_n_estimators': 213, 'rf_max_depth': 16, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 32}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:39,306] Trial 59 finished with value: 12.57352482732787 and parameters: {'lasso_alpha': 0.9591161797750659, 'elastic_alpha': 0.9648462864131728, 'elastic_l1_ratio': 0.5998193167146444, 'rf_n_estimators': 228, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 57}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:42,565] Trial 60 finished with value: 12.573807913115271 and parameters: {'lasso_alpha': 0.8902627337497526, 'elastic_alpha': 0.7989877742707285, 'elastic_l1_ratio': 0.3126737092647234, 'rf_n_estimators': 190, 'rf_max_depth': 6, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 35}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:45,191] Trial 61 finished with value: 12.57463980833845 and parameters: {'lasso_alpha': 0.8182149692589465, 'elastic_alpha': 0.7225362134770391, 'elastic_l1_ratio': 0.8592525712621102, 'rf_n_estimators': 139, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 13}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:47,793] Trial 62 finished with value: 12.57313637845208 and parameters: {'lasso_alpha': 0.7724780922996884, 'elastic_alpha': 0.816627335323674, 'elastic_l1_ratio': 0.8308376506034376, 'rf_n_estimators': 135, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 1}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:52,083] Trial 63 finished with value: 12.569212769997126 and parameters: {'lasso_alpha': 0.9221027674752486, 'elastic_alpha': 0.8702261037840164, 'elastic_l1_ratio': 0.7843749585688683, 'rf_n_estimators': 176, 'rf_max_depth': 10, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 10}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:54,015] Trial 64 finished with value: 12.572363842028446 and parameters: {'lasso_alpha': 0.8387615608686199, 'elastic_alpha': 0.9291889628067762, 'elastic_l1_ratio': 0.8716090470901727, 'rf_n_estimators': 125, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 20}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:57,167] Trial 65 finished with value: 12.571434384840103 and parameters: {'lasso_alpha': 0.8009042566066005, 'elastic_alpha': 0.7481235885309528, 'elastic_l1_ratio': 0.8405808565004785, 'rf_n_estimators': 143, 'rf_max_depth': 8, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 39}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:28:58,718] Trial 66 finished with value: 12.573024541074869 and parameters: {'lasso_alpha': 0.9745505381265513, 'elastic_alpha': 0.8190444951419475, 'elastic_l1_ratio': 0.7989666074643486, 'rf_n_estimators': 114, 'rf_max_depth': 6, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'log2', 'rf_random_state': 35}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:29:02,493] Trial 67 finished with value: 12.574855899115288 and parameters: {'lasso_alpha': 0.6433998020209888, 'elastic_alpha': 0.9109218073153228, 'elastic_l1_ratio': 0.7219605348030126, 'rf_n_estimators': 158, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 7}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:29:07,962] Trial 68 finished with value: 12.581184355194022 and parameters: {'lasso_alpha': 0.5132891936891086, 'elastic_alpha': 0.18910762598735448, 'elastic_l1_ratio': 0.16909193385827076, 'rf_n_estimators': 105, 'rf_max_depth': 4, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 59}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:29:11,160] Trial 69 finished with value: 12.570864264607806 and parameters: {'lasso_alpha': 0.7218187612226221, 'elastic_alpha': 0.715723526751916, 'elastic_l1_ratio': 0.8167012745668136, 'rf_n_estimators': 165, 'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 66}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:29:16,152] Trial 70 finished with value: 12.567404958796002 and parameters: {'lasso_alpha': 0.891145908754195, 'elastic_alpha': 0.9978404599278425, 'elastic_l1_ratio': 0.7852313241128951, 'rf_n_estimators': 201, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 28}. Best is trial 34 with value: 12.564409257678665.
# [I 2024-10-28 22:29:20,394] Trial 71 finished with value: 12.563368705202555 and parameters: {'lasso_alpha': 0.8972848387122385, 'elastic_alpha': 0.9927458081241716, 'elastic_l1_ratio': 0.7864933943439321, 'rf_n_estimators': 201, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 28}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:29:25,620] Trial 72 finished with value: 12.569478401709018 and parameters: {'lasso_alpha': 0.8986244060211467, 'elastic_alpha': 0.9797967199481199, 'elastic_l1_ratio': 0.7426299121282102, 'rf_n_estimators': 200, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 27}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:29:30,155] Trial 73 finished with value: 12.564055809841069 and parameters: {'lasso_alpha': 0.9294850766069837, 'elastic_alpha': 0.9564498524066204, 'elastic_l1_ratio': 0.7727456257757034, 'rf_n_estimators': 211, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 31}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:29:34,631] Trial 74 finished with value: 12.571934060908287 and parameters: {'lasso_alpha': 0.8644128359972405, 'elastic_alpha': 0.9481799276453917, 'elastic_l1_ratio': 0.6809186244479835, 'rf_n_estimators': 208, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 32}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:29:40,690] Trial 75 finished with value: 12.572891928321695 and parameters: {'lasso_alpha': 0.9259395816750018, 'elastic_alpha': 0.9947441607278299, 'elastic_l1_ratio': 0.7877570953999062, 'rf_n_estimators': 228, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 22}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:29:45,442] Trial 76 finished with value: 12.565668361746713 and parameters: {'lasso_alpha': 0.9464412769577988, 'elastic_alpha': 0.8671574138152873, 'elastic_l1_ratio': 0.75864856051346, 'rf_n_estimators': 186, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 27}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:29:50,043] Trial 77 finished with value: 12.57178872704318 and parameters: {'lasso_alpha': 0.9442967656884457, 'elastic_alpha': 0.923119583400798, 'elastic_l1_ratio': 0.7218627783392839, 'rf_n_estimators': 185, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 26}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:29:55,566] Trial 78 finished with value: 12.576222716329251 and parameters: {'lasso_alpha': 0.8527593470302924, 'elastic_alpha': 0.9580431903419954, 'elastic_l1_ratio': 0.7728296372185015, 'rf_n_estimators': 197, 'rf_max_depth': 11, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 18}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:00,105] Trial 79 finished with value: 12.577794820093475 and parameters: {'lasso_alpha': 0.8802455797461505, 'elastic_alpha': 0.4223123395570663, 'elastic_l1_ratio': 0.7651733483094468, 'rf_n_estimators': 219, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_random_state': 28}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:07,642] Trial 80 finished with value: 12.58462807623754 and parameters: {'lasso_alpha': 0.279685683715309, 'elastic_alpha': 0.8852099826385973, 'elastic_l1_ratio': 0.6497396254015365, 'rf_n_estimators': 253, 'rf_max_depth': 12, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 33}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:11,749] Trial 81 finished with value: 12.573436184637602 and parameters: {'lasso_alpha': 0.9661499306184927, 'elastic_alpha': 0.8638171434133569, 'elastic_l1_ratio': 0.7449376225398116, 'rf_n_estimators': 179, 'rf_max_depth': 8, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 38}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:16,741] Trial 82 finished with value: 12.572026978974284 and parameters: {'lasso_alpha': 0.9041273809419732, 'elastic_alpha': 0.9378315313578455, 'elastic_l1_ratio': 0.8022382340677015, 'rf_n_estimators': 211, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 44}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:20,807] Trial 83 finished with value: 12.568018688655199 and parameters: {'lasso_alpha': 0.9340600204166822, 'elastic_alpha': 0.9098172509784603, 'elastic_l1_ratio': 0.7054313135899207, 'rf_n_estimators': 172, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 30}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:25,823] Trial 84 finished with value: 12.57115061183005 and parameters: {'lasso_alpha': 0.9815855443060177, 'elastic_alpha': 0.965167956201097, 'elastic_l1_ratio': 0.6825432047902948, 'rf_n_estimators': 188, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 24}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:47,332] Trial 85 finished with value: 12.579836548552347 and parameters: {'lasso_alpha': 0.9460119065429958, 'elastic_alpha': 0.9992718107614912, 'elastic_l1_ratio': 0.7790036955205933, 'rf_n_estimators': 149, 'rf_max_depth': 11, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 47}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:52,366] Trial 86 finished with value: 12.569326002264976 and parameters: {'lasso_alpha': 0.8404936921401036, 'elastic_alpha': 0.881651741648352, 'elastic_l1_ratio': 0.75536481475637, 'rf_n_estimators': 203, 'rf_max_depth': 8, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 42}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:30:57,652] Trial 87 finished with value: 12.572367665399247 and parameters: {'lasso_alpha': 0.9063086897251222, 'elastic_alpha': 0.8488650106492964, 'elastic_l1_ratio': 0.728002937091676, 'rf_n_estimators': 181, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 50}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:03,351] Trial 88 finished with value: 12.567726548427842 and parameters: {'lasso_alpha': 0.8749423104025881, 'elastic_alpha': 0.7876963468225519, 'elastic_l1_ratio': 0.8210812769431955, 'rf_n_estimators': 193, 'rf_max_depth': 9, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 30}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:07,348] Trial 89 finished with value: 12.568036087545044 and parameters: {'lasso_alpha': 0.9999826984041634, 'elastic_alpha': 0.6121083536139146, 'elastic_l1_ratio': 0.6674262590115834, 'rf_n_estimators': 158, 'rf_max_depth': 8, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 21}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:11,522] Trial 90 finished with value: 12.570246308635713 and parameters: {'lasso_alpha': 0.9634302179429051, 'elastic_alpha': 0.975156467595528, 'elastic_l1_ratio': 0.6213212872558755, 'rf_n_estimators': 163, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_random_state': 36}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:16,443] Trial 91 finished with value: 12.566939900120127 and parameters: {'lasso_alpha': 0.884323131559029, 'elastic_alpha': 0.7845422303618093, 'elastic_l1_ratio': 0.8188912332354612, 'rf_n_estimators': 195, 'rf_max_depth': 9, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 32}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:21,354] Trial 92 finished with value: 12.57070802474006 and parameters: {'lasso_alpha': 0.39434381679957475, 'elastic_alpha': 0.8337082441467145, 'elastic_l1_ratio': 0.7957770719961385, 'rf_n_estimators': 171, 'rf_max_depth': 10, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 33}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:25,400] Trial 93 finished with value: 12.567183948763903 and parameters: {'lasso_alpha': 0.9306412252904193, 'elastic_alpha': 0.9126006537267153, 'elastic_l1_ratio': 0.7377095023158646, 'rf_n_estimators': 200, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 25}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:31,019] Trial 94 finished with value: 12.57794864649083 and parameters: {'lasso_alpha': 0.15322178570131795, 'elastic_alpha': 0.9175100527402308, 'elastic_l1_ratio': 0.7658502703970038, 'rf_n_estimators': 228, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 26}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:35,105] Trial 95 finished with value: 12.571906521444143 and parameters: {'lasso_alpha': 0.9198843559531629, 'elastic_alpha': 0.9475025640101997, 'elastic_l1_ratio': 0.8783504197254924, 'rf_n_estimators': 199, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 18}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:40,808] Trial 96 finished with value: 12.576239711022852 and parameters: {'lasso_alpha': 0.8868315208329907, 'elastic_alpha': 0.9040000095872193, 'elastic_l1_ratio': 0.8302837927341836, 'rf_n_estimators': 217, 'rf_max_depth': 10, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 40}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:44,914] Trial 97 finished with value: 12.572470332927264 and parameters: {'lasso_alpha': 0.8120656147012372, 'elastic_alpha': 0.934871999842125, 'elastic_l1_ratio': 0.7347737164741471, 'rf_n_estimators': 194, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 23}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:49,435] Trial 98 finished with value: 12.577457391915672 and parameters: {'lasso_alpha': 0.769882972115377, 'elastic_alpha': 0.7657337516971561, 'elastic_l1_ratio': 0.6933022241712076, 'rf_n_estimators': 207, 'rf_max_depth': 11, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 28}. Best is trial 71 with value: 12.563368705202555.
# [I 2024-10-28 22:31:52,680] Trial 99 finished with value: 12.574242760281647 and parameters: {'lasso_alpha': 0.8399262890379972, 'elastic_alpha': 0.9829050461849687, 'elastic_l1_ratio': 0.8089750486507405, 'rf_n_estimators': 184, 'rf_max_depth': 6, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 34}. Best is trial 71 with value: 12.563368705202555.
# Best parameters: {'lasso_alpha': 0.8972848387122385, 'elastic_alpha': 0.9927458081241716, 'elastic_l1_ratio': 0.7864933943439321, 'rf_n_estimators': 201, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 28}
# Optimized Voting Regressor - Train MAE: 12.187420114063967, Test MAE: 12.47436399418055

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
# {'lasso_alpha': 0.8972848387122385, 'elastic_alpha': 0.9927458081241716, 'elastic_l1_ratio': 0.7864933943439321, 'rf_n_estimators': 201, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 28}
lasso = Lasso(alpha=0.8972848387122385, random_state=28)
elastic = ElasticNet(alpha=0.9927458081241716, l1_ratio=0.7864933943439321, random_state=28)
rf = RandomForestRegressor(
    n_estimators=201,
    max_depth=8,
    min_samples_split=10,
    min_samples_leaf=1,
    max_features='sqrt',
    random_state=28
)

voting = VotingRegressor([('lasso', lasso), ('elastic', elastic), ('rf', rf)])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

voting.fit(X_train, y_train)
y_pred = model.predict(X_test)

train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'{scores.mean()} / {train_score} / {test_score}')
# Out:
# 12.544782819689578 / 12.187420114063967 / 12.807629368722674

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
lasso = Lasso(alpha=0.7000364112801918, random_state=31)
elastic = ElasticNet(alpha=0.9737082848325345, l1_ratio=0.8968219831995436, random_state=31)
rf = RandomForestRegressor(
    n_estimators=50,
    max_depth=8,
    min_samples_split=4,
    min_samples_leaf=10,
    max_features=None,
    random_state=31
)

voting = VotingRegressor([('lasso', lasso), ('elastic', elastic), ('rf', rf)])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

voting.fit(X_train, y_train)
y_pred = model.predict(X_test)

train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'{scores.mean()} / {train_score} / {test_score}')
# Out:
# 12.541153673973747 / 12.19373132878114 / 12.466226516010302

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
# {'lasso_alpha': 0.6779122520600722, 'elastic_alpha': 0.9971090599987921, 'elastic_l1_ratio': 0.44498452438450353, 'rf_n_estimators': 168, 'rf_max_depth': 6, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 30}
lasso = Lasso(alpha=0.6779122520600722, random_state=30)
elastic = ElasticNet(alpha=0.9971090599987921, l1_ratio=0.44498452438450353, random_state=30)
rf = RandomForestRegressor(
    n_estimators=168,
    max_depth=6,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features=None,
    random_state=30
)

voting = VotingRegressor([
    ('lasso', lasso),
    ('elastic', elastic),
    ('rf', rf)
])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

voting.fit(X_train, y_train)
y_pred = model.predict(X_test)

train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'{scores.mean()} / {train_score} / {test_score}')
# Out:
# 12.539876272275201 / 12.27021820379983 / 12.466226516010302

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
import pandas as pd

# 데이터 분할
X = train[['V7', 'V17', 'V20', 'V21', 'V24']]    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
lasso = Lasso(alpha=0.6779122520600722, random_state=30)
elastic = ElasticNet(alpha=0.9971090599987921, l1_ratio=0.44498452438450353, random_state=30)
rf = RandomForestRegressor(
    n_estimators=168,
    max_depth=6,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features=None,
    random_state=30
)

voting = VotingRegressor([
    ('lasso', lasso),
    ('elastic', elastic),
    ('rf', rf)
])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

# VotingRegressor 학습
voting.fit(X_train, y_train)

# 테스트 데이터에 대해 예측 수행
y_pred = voting.predict(X_test)

# 훈련 및 테스트 데이터의 MAE 계산
train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

# 결과 출력
print(f'Cross-validated MAE: {scores.mean()}, Train MAE: {train_score}, Test MAE: {test_score}')
# Out:
# Cross-validated MAE: 12.53065715635401, Train MAE: 12.306957102252456, Test MAE: 12.46857108565719

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
# {'lasso_alpha': 0.9858784552601979, 'elastic_alpha': 0.9755023294378308, 'elastic_l1_ratio': 0.8955218082984115, 'rf_n_estimators': 51, 'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 49}

lasso = Lasso(alpha=0.9858784552601979, random_state=49)
elastic = ElasticNet(alpha=0.9755023294378308, l1_ratio=0.8955218082984115, random_state=49)
rf = RandomForestRegressor(
    n_estimators=51,
    max_depth=7,
    min_samples_split=9,
    min_samples_leaf=3,
    max_features=None,
    random_state=49
)


voting = VotingRegressor([
    ('lasso', lasso),
    ('elastic', elastic),
    ('rf', rf)
])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

voting.fit(X_train, y_train)
y_pred = model.predict(X_test)

train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'{scores.mean()} / {train_score} / {test_score}')
# Out:
# 12.544548093688368 / 12.202605499643731 / 12.466226516010302

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
{'lasso_alpha': 0.87975180300022, 'elastic_alpha': 0.9583534291840334, 'elastic_l1_ratio': 0.7329161446530024, 'ridge_alpha': 0.583133995768023, 'gb_learning_rate': 0.05843394170060385, 'gb_n_estimators': 66, 'rf_n_estimators': 285, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 49}

lr = LinearRegression()
lasso = Lasso(alpha=0.87975180300022, random_state=49)
elastic = ElasticNet(alpha=0.9583534291840334, l1_ratio=0.7329161446530024, random_state=49)
ridge = Ridge(alpha=0.583133995768023, random_state=49)
rf = RandomForestRegressor(
    n_estimators=285,
    max_depth=6,
    min_samples_split=8,
    min_samples_leaf=10,
    max_features=None,
    random_state=49
)
gb = GradientBoostingRegressor(
    n_estimators=66,
    learning_rate=0.05843394170060385,
    random_state=49
)

voting_best = VotingRegressor([
    ('lr', lr),
    ('lasso', lasso), 
    ('elastic', elastic), 
    ('rf', rf),
    ('ridge', ridge),
    ('gb', gb)
])

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
scores = cross_val_score(voting, X, y, cv=5, scoring=mae_scorer)

voting.fit(X_train, y_train)
y_pred = model.predict(X_test)

train_score = mean_absolute_error(y_train, voting.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'{scores.mean()} / {train_score} / {test_score}')
# Out:
# 12.543629280213713 / 11.779678761381117 / 12.807629368722674

# %%
import optuna
from sklearn.ensemble import VotingRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Lasso, ElasticNet, Ridge, LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
from optuna.samplers import TPESampler
import pandas as pd
import numpy as np  

# 데이터 로드
train = pd.read_csv('./train.csv')

# yymm 컬럼을 날짜 형식으로 변환 (연도는 임의로 설정)
train['yymm'] = pd.to_datetime('2024' + train['yymm'], format='%Y%m%d %H:%M')

# day, hour, minute 컬럼 생성
train['day'] = train['yymm'].dt.day         # 일
train['hour'] = train['yymm'].dt.hour       # 시
train['minute'] = train['yymm'].dt.minute   # 분

# weekday 컬럼 생성
train['weekday'] = train['day'] % 7         # 요일 (0: 월요일, 1: 화요일, ..., 6: 일요일)

# yymm 컬럼 삭제
train.drop('yymm', axis=1, inplace=True)

# 데이터 분할
X = train.drop('Target', axis=1)  # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']               # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# Optuna 목적 함수 정의
def objective(trial):
    # 하이퍼파라미터 선택
    lasso_alpha = trial.suggest_float('lasso_alpha', 0.001, 1.0)
    elastic_alpha = trial.suggest_float('elastic_alpha', 0.001, 1.0)
    elastic_l1_ratio = trial.suggest_float('elastic_l1_ratio', 0.1, 0.9)
    gb_learning_rate = trial.suggest_float('gb_learning_rate', 0.01, 0.3)
    gb_n_estimators = trial.suggest_int('gb_n_estimators', 50, 300)

    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 300)
    rf_max_depth = trial.suggest_int('rf_max_depth', 3, 20)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 10)
    rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', None])
    rf_random_state = trial.suggest_int('rf_random_state', 1, 100)

    # 모델 정의
    lasso = Lasso(alpha=lasso_alpha, random_state=rf_random_state)
    elastic = ElasticNet(alpha=elastic_alpha, l1_ratio=elastic_l1_ratio, random_state=rf_random_state)
    rf = RandomForestRegressor(
        n_estimators=rf_n_estimators,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        max_features=rf_max_features,
        random_state=rf_random_state
    )
    gb = GradientBoostingRegressor(
        learning_rate=gb_learning_rate,
        n_estimators=gb_n_estimators,
        random_state=rf_random_state
    )

    # VotingRegressor 정의
    voting = VotingRegressor([
        ('lasso', lasso), 
        ('elastic', elastic), 
        ('rf', rf),
        ('gb', gb)
    ])

    # 5-fold 교차 검증으로 평가
    scores = cross_val_score(voting, X_train, y_train, cv=5, scoring=mae_scorer)
    return scores.mean()

# Optuna 최적화 실행
study = optuna.create_study(direction='minimize', sampler=TPESampler())
study.optimize(objective, n_trials=50)

# 최적 하이퍼파라미터 출력
print("Best parameters:", study.best_params)

# 최적 하이퍼파라미터로 VotingRegressor 학습
best_lasso = Lasso(alpha=study.best_params['lasso_alpha'], random_state=study.best_params['rf_random_state'])
best_elastic = ElasticNet(alpha=study.best_params['elastic_alpha'], l1_ratio=study.best_params['elastic_l1_ratio'], random_state=study.best_params['rf_random_state'])
best_rf = RandomForestRegressor(
    n_estimators=study.best_params['rf_n_estimators'],
    max_depth=study.best_params['rf_max_depth'],
    min_samples_split=study.best_params['rf_min_samples_split'],
    min_samples_leaf=study.best_params['rf_min_samples_leaf'],
    max_features=study.best_params['rf_max_features'],
    random_state=study.best_params['rf_random_state']
)
best_gb = GradientBoostingRegressor(
    learning_rate=study.best_params['gb_learning_rate'],
    n_estimators=study.best_params['gb_n_estimators'],
    random_state=study.best_params['rf_random_state']
)

voting_best = VotingRegressor([
    ('lasso', best_lasso), 
    ('elastic', best_elastic), 
    ('rf', best_rf),
    ('gb', best_gb)
])

# 최적화된 모델 학습 및 평가
voting_best.fit(X_train, y_train)
y_pred = voting_best.predict(X_test)

train_score = mean_absolute_error(y_train, voting_best.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'Optimized Voting Regressor - Train MAE: {train_score}, Test MAE: {test_score}')
# Out:
# [I 2024-10-28 22:52:58,442] A new study created in memory with name: no-name-9fff95a7-2366-4a48-830b-e9ee27d8a1dc
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.274e+04, tolerance: 5.203e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.888e+04, tolerance: 5.242e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.638e+04, tolerance: 5.323e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\cyeli\.conda\envs\DL\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.370e+03, tolerance: 5.276e+01
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-10-28 22:54:14,329] Trial 0 finished with value: 12.633878099651655 and parameters: {'lasso_alpha': 0.007675941735660297, 'elastic_alpha': 0.10412828008128282, 'elastic_l1_ratio': 0.2885626358797505, 'gb_learning_rate': 0.09807596150569996, 'gb_n_estimators': 123, 'rf_n_estimators': 300, 'rf_max_depth': 18, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 91}. Best is trial 0 with value: 12.633878099651655.
# [I 2024-10-28 22:54:27,310] Trial 1 finished with value: 12.593232421483597 and parameters: {'lasso_alpha': 0.8327691687821464, 'elastic_alpha': 0.3527374710046569, 'elastic_l1_ratio': 0.47849157781935536, 'gb_learning_rate': 0.118394272542097, 'gb_n_estimators': 56, 'rf_n_estimators': 287, 'rf_max_depth': 18, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 67}. Best is trial 1 with value: 12.593232421483597.
# [I 2024-10-28 22:54:37,891] Trial 2 finished with value: 12.637583401374345 and parameters: {'lasso_alpha': 0.10984058810386399, 'elastic_alpha': 0.826609448189226, 'elastic_l1_ratio': 0.8152736145317986, 'gb_learning_rate': 0.2596579026673662, 'gb_n_estimators': 122, 'rf_n_estimators': 102, 'rf_max_depth': 15, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 73}. Best is trial 1 with value: 12.593232421483597.
# [I 2024-10-28 22:54:59,672] Trial 3 finished with value: 12.65173344843824 and parameters: {'lasso_alpha': 0.9286777378996134, 'elastic_alpha': 0.02905697242224018, 'elastic_l1_ratio': 0.3649974988904966, 'gb_learning_rate': 0.28849628545637057, 'gb_n_estimators': 198, 'rf_n_estimators': 286, 'rf_max_depth': 19, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 28}. Best is trial 1 with value: 12.593232421483597.
# [I 2024-10-28 22:55:22,315] Trial 4 finished with value: 12.608089356042768 and parameters: {'lasso_alpha': 0.23937093978724094, 'elastic_alpha': 0.856633275373454, 'elastic_l1_ratio': 0.46288181757721747, 'gb_learning_rate': 0.1494654516160381, 'gb_n_estimators': 295, 'rf_n_estimators': 171, 'rf_max_depth': 8, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 52}. Best is trial 1 with value: 12.593232421483597.
# [I 2024-10-28 22:55:58,861] Trial 5 finished with value: 12.668626501675975 and parameters: {'lasso_alpha': 0.2832597149293729, 'elastic_alpha': 0.21249282519964877, 'elastic_l1_ratio': 0.853141562417133, 'gb_learning_rate': 0.26532280962822347, 'gb_n_estimators': 177, 'rf_n_estimators': 151, 'rf_max_depth': 12, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 45}. Best is trial 1 with value: 12.593232421483597.
# [I 2024-10-28 22:56:08,705] Trial 6 finished with value: 12.573954438572816 and parameters: {'lasso_alpha': 0.23784807248237913, 'elastic_alpha': 0.5639413024391204, 'elastic_l1_ratio': 0.13563059622150675, 'gb_learning_rate': 0.07621687566582319, 'gb_n_estimators': 90, 'rf_n_estimators': 273, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': 'log2', 'rf_random_state': 54}. Best is trial 6 with value: 12.573954438572816.
# [I 2024-10-28 22:56:21,853] Trial 7 finished with value: 12.581643715476527 and parameters: {'lasso_alpha': 0.1345047678682482, 'elastic_alpha': 0.06952003044221838, 'elastic_l1_ratio': 0.2892751236831968, 'gb_learning_rate': 0.04637042782299367, 'gb_n_estimators': 174, 'rf_n_estimators': 210, 'rf_max_depth': 3, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 9}. Best is trial 6 with value: 12.573954438572816.
# [I 2024-10-28 22:56:41,318] Trial 8 finished with value: 12.656954409909378 and parameters: {'lasso_alpha': 0.2864051027112936, 'elastic_alpha': 0.9093382826419074, 'elastic_l1_ratio': 0.755311950145227, 'gb_learning_rate': 0.2525015872514318, 'gb_n_estimators': 270, 'rf_n_estimators': 142, 'rf_max_depth': 17, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 10, 'rf_max_features': 'log2', 'rf_random_state': 47}. Best is trial 6 with value: 12.573954438572816.
# [I 2024-10-28 22:57:04,624] Trial 9 finished with value: 12.655084179167142 and parameters: {'lasso_alpha': 0.8847295239439293, 'elastic_alpha': 0.14712183854411562, 'elastic_l1_ratio': 0.1861931483776602, 'gb_learning_rate': 0.2335519825127313, 'gb_n_estimators': 242, 'rf_n_estimators': 299, 'rf_max_depth': 16, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 9}. Best is trial 6 with value: 12.573954438572816.
# [I 2024-10-28 22:57:11,825] Trial 10 finished with value: 12.563753551355896 and parameters: {'lasso_alpha': 0.5488493423964064, 'elastic_alpha': 0.6103296973888124, 'elastic_l1_ratio': 0.6571693465057841, 'gb_learning_rate': 0.015497933974657742, 'gb_n_estimators': 51, 'rf_n_estimators': 240, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 93}. Best is trial 10 with value: 12.563753551355896.
# [I 2024-10-28 22:57:19,272] Trial 11 finished with value: 12.563813659685692 and parameters: {'lasso_alpha': 0.5717189415887929, 'elastic_alpha': 0.6394945500366469, 'elastic_l1_ratio': 0.6444550357894899, 'gb_learning_rate': 0.015192559813220442, 'gb_n_estimators': 53, 'rf_n_estimators': 224, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 96}. Best is trial 10 with value: 12.563753551355896.
# [I 2024-10-28 22:57:25,286] Trial 12 finished with value: 12.566915610211383 and parameters: {'lasso_alpha': 0.6177882181553683, 'elastic_alpha': 0.6547371884522738, 'elastic_l1_ratio': 0.6535447645352946, 'gb_learning_rate': 0.012423812586212963, 'gb_n_estimators': 54, 'rf_n_estimators': 225, 'rf_max_depth': 3, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 94}. Best is trial 10 with value: 12.563753551355896.
# [I 2024-10-28 22:57:36,633] Trial 13 finished with value: 12.560684213292854 and parameters: {'lasso_alpha': 0.5700704851663753, 'elastic_alpha': 0.6834063311978362, 'elastic_l1_ratio': 0.6831418115803521, 'gb_learning_rate': 0.012599465769203276, 'gb_n_estimators': 98, 'rf_n_estimators': 232, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 100}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 22:57:50,224] Trial 14 finished with value: 12.598638562136548 and parameters: {'lasso_alpha': 0.4481868926461419, 'elastic_alpha': 0.4167354965104452, 'elastic_l1_ratio': 0.6366009237228241, 'gb_learning_rate': 0.193196927563788, 'gb_n_estimators': 103, 'rf_n_estimators': 249, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 80}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 22:58:02,136] Trial 15 finished with value: 12.565579230617429 and parameters: {'lasso_alpha': 0.7025921637620038, 'elastic_alpha': 0.7424851909667064, 'elastic_l1_ratio': 0.5504551765402649, 'gb_learning_rate': 0.0556342782140569, 'gb_n_estimators': 90, 'rf_n_estimators': 195, 'rf_max_depth': 11, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 100}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 22:58:19,589] Trial 16 finished with value: 12.567446615288741 and parameters: {'lasso_alpha': 0.46475883526563255, 'elastic_alpha': 0.44184408771055544, 'elastic_l1_ratio': 0.7533923120497557, 'gb_learning_rate': 0.04683499058378581, 'gb_n_estimators': 148, 'rf_n_estimators': 247, 'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 79}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 22:58:27,116] Trial 17 finished with value: 12.573372142684438 and parameters: {'lasso_alpha': 0.7157300652556526, 'elastic_alpha': 0.5353757681624992, 'elastic_l1_ratio': 0.5443079960585878, 'gb_learning_rate': 0.12029702716347218, 'gb_n_estimators': 82, 'rf_n_estimators': 50, 'rf_max_depth': 10, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 84}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 22:59:20,117] Trial 18 finished with value: 12.630426889151405 and parameters: {'lasso_alpha': 0.4195093982565352, 'elastic_alpha': 0.9770504056513611, 'elastic_l1_ratio': 0.7225764080684435, 'gb_learning_rate': 0.19494410450003752, 'gb_n_estimators': 138, 'rf_n_estimators': 257, 'rf_max_depth': 14, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 67}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 22:59:27,683] Trial 19 finished with value: 12.56764901033803 and parameters: {'lasso_alpha': 0.7507632972610274, 'elastic_alpha': 0.3041221891021646, 'elastic_l1_ratio': 0.5885869695691932, 'gb_learning_rate': 0.08026349350940043, 'gb_n_estimators': 74, 'rf_n_estimators': 195, 'rf_max_depth': 5, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 34}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 22:59:43,110] Trial 20 finished with value: 12.562972663381913 and parameters: {'lasso_alpha': 0.9962523254096209, 'elastic_alpha': 0.7510509506708777, 'elastic_l1_ratio': 0.8910591413213105, 'gb_learning_rate': 0.026930717897864324, 'gb_n_estimators': 225, 'rf_n_estimators': 115, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_random_state': 88}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 22:59:59,032] Trial 21 finished with value: 12.56108211334194 and parameters: {'lasso_alpha': 0.5954641028140937, 'elastic_alpha': 0.727641906627891, 'elastic_l1_ratio': 0.8490836941869985, 'gb_learning_rate': 0.012400015769906035, 'gb_n_estimators': 224, 'rf_n_estimators': 105, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_random_state': 88}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 23:00:16,124] Trial 22 finished with value: 12.578109205310573 and parameters: {'lasso_alpha': 0.997018096783635, 'elastic_alpha': 0.7454861974049654, 'elastic_l1_ratio': 0.8980811034574667, 'gb_learning_rate': 0.04582888636090161, 'gb_n_estimators': 217, 'rf_n_estimators': 103, 'rf_max_depth': 13, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_random_state': 83}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 23:00:33,226] Trial 23 finished with value: 12.566647191600195 and parameters: {'lasso_alpha': 0.6516967848005659, 'elastic_alpha': 0.7379360501007695, 'elastic_l1_ratio': 0.8210144463898317, 'gb_learning_rate': 0.030269704206042428, 'gb_n_estimators': 236, 'rf_n_estimators': 104, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_random_state': 67}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 23:00:50,460] Trial 24 finished with value: 12.582695910471495 and parameters: {'lasso_alpha': 0.3773188409839433, 'elastic_alpha': 0.7081840057897196, 'elastic_l1_ratio': 0.8540900522047515, 'gb_learning_rate': 0.0703563836706855, 'gb_n_estimators': 239, 'rf_n_estimators': 71, 'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 87}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 23:01:24,484] Trial 25 finished with value: 12.60020132541391 and parameters: {'lasso_alpha': 0.7926334408452325, 'elastic_alpha': 0.9717549644858046, 'elastic_l1_ratio': 0.8965371053652667, 'gb_learning_rate': 0.09326811706958274, 'gb_n_estimators': 209, 'rf_n_estimators': 117, 'rf_max_depth': 11, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 100}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 23:01:48,786] Trial 26 finished with value: 12.56521453619226 and parameters: {'lasso_alpha': 0.5629951709011876, 'elastic_alpha': 0.8115746500214345, 'elastic_l1_ratio': 0.7324804423004022, 'gb_learning_rate': 0.03207797505838417, 'gb_n_estimators': 270, 'rf_n_estimators': 134, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 75}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 23:02:03,176] Trial 27 finished with value: 12.576691350373462 and parameters: {'lasso_alpha': 0.9736156712946655, 'elastic_alpha': 0.4653393008378539, 'elastic_l1_ratio': 0.7863368923837211, 'gb_learning_rate': 0.06292327593600919, 'gb_n_estimators': 179, 'rf_n_estimators': 81, 'rf_max_depth': 10, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_random_state': 59}. Best is trial 13 with value: 12.560684213292854.
# [I 2024-10-28 23:02:22,123] Trial 28 finished with value: 12.559735508307607 and parameters: {'lasso_alpha': 0.8443043812985919, 'elastic_alpha': 0.8768768701980614, 'elastic_l1_ratio': 0.6911328790308706, 'gb_learning_rate': 0.03222645863913533, 'gb_n_estimators': 258, 'rf_n_estimators': 163, 'rf_max_depth': 7, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 89}. Best is trial 28 with value: 12.559735508307607.
# [I 2024-10-28 23:02:51,473] Trial 29 finished with value: 12.58965526811201 and parameters: {'lasso_alpha': 0.8584934739506904, 'elastic_alpha': 0.8976734291240903, 'elastic_l1_ratio': 0.7018019623620968, 'gb_learning_rate': 0.10966409303360104, 'gb_n_estimators': 275, 'rf_n_estimators': 169, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 87}. Best is trial 28 with value: 12.559735508307607.
# [I 2024-10-28 23:03:11,799] Trial 30 finished with value: 12.605013355648072 and parameters: {'lasso_alpha': 0.6407978079644774, 'elastic_alpha': 0.8181422561348457, 'elastic_l1_ratio': 0.6981079391696448, 'gb_learning_rate': 0.14858151537818015, 'gb_n_estimators': 259, 'rf_n_estimators': 156, 'rf_max_depth': 10, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_random_state': 92}. Best is trial 28 with value: 12.559735508307607.
# [I 2024-10-28 23:03:30,775] Trial 31 finished with value: 12.566955918541503 and parameters: {'lasso_alpha': 0.90158871662716, 'elastic_alpha': 0.6754771316233161, 'elastic_l1_ratio': 0.7982426037206948, 'gb_learning_rate': 0.029337263276450625, 'gb_n_estimators': 227, 'rf_n_estimators': 126, 'rf_max_depth': 8, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 87}. Best is trial 28 with value: 12.559735508307607.
# [I 2024-10-28 23:03:47,965] Trial 32 finished with value: 12.558787719357673 and parameters: {'lasso_alpha': 0.8047578403183432, 'elastic_alpha': 0.7797332527857485, 'elastic_l1_ratio': 0.4439560000993694, 'gb_learning_rate': 0.011161577541366336, 'gb_n_estimators': 194, 'rf_n_estimators': 187, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 73}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:04:05,100] Trial 33 finished with value: 12.562496894749573 and parameters: {'lasso_alpha': 0.7934137166265101, 'elastic_alpha': 0.5908173115014435, 'elastic_l1_ratio': 0.4178880752922606, 'gb_learning_rate': 0.01295748222624652, 'gb_n_estimators': 198, 'rf_n_estimators': 192, 'rf_max_depth': 4, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 73}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:04:19,601] Trial 34 finished with value: 12.561838900313697 and parameters: {'lasso_alpha': 0.8092306495280176, 'elastic_alpha': 0.9031748043015249, 'elastic_l1_ratio': 0.37770604802657076, 'gb_learning_rate': 0.036656142156589494, 'gb_n_estimators': 150, 'rf_n_estimators': 184, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 62}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:04:37,113] Trial 35 finished with value: 12.572551299280796 and parameters: {'lasso_alpha': 0.5119155939387776, 'elastic_alpha': 0.7839863205652897, 'elastic_l1_ratio': 0.4784570549647912, 'gb_learning_rate': 0.08657220434621865, 'gb_n_estimators': 195, 'rf_n_estimators': 160, 'rf_max_depth': 7, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 77}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:05:20,038] Trial 36 finished with value: 12.581747611829773 and parameters: {'lasso_alpha': 0.7273240146272515, 'elastic_alpha': 0.861389051129429, 'elastic_l1_ratio': 0.5788666649041188, 'gb_learning_rate': 0.05927252378142814, 'gb_n_estimators': 296, 'rf_n_estimators': 223, 'rf_max_depth': 9, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 69}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:05:38,831] Trial 37 finished with value: 12.605795529035868 and parameters: {'lasso_alpha': 0.6760950244477417, 'elastic_alpha': 0.6922526238463187, 'elastic_l1_ratio': 0.496566114852928, 'gb_learning_rate': 0.13158383181157243, 'gb_n_estimators': 251, 'rf_n_estimators': 211, 'rf_max_depth': 12, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_random_state': 100}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:05:57,706] Trial 38 finished with value: 12.602484949988883 and parameters: {'lasso_alpha': 0.3644347595869443, 'elastic_alpha': 0.8703775057802225, 'elastic_l1_ratio': 0.6019322551713707, 'gb_learning_rate': 0.048165365989075525, 'gb_n_estimators': 125, 'rf_n_estimators': 270, 'rf_max_depth': 20, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1, 'rf_max_features': 'sqrt', 'rf_random_state': 38}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:06:09,589] Trial 39 finished with value: 12.574323965713686 and parameters: {'lasso_alpha': 0.9293129908368948, 'elastic_alpha': 0.9483366264179967, 'elastic_l1_ratio': 0.33497426921819495, 'gb_learning_rate': 0.10074872756191777, 'gb_n_estimators': 163, 'rf_n_estimators': 182, 'rf_max_depth': 4, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 72}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:06:21,930] Trial 40 finished with value: 12.568253739347556 and parameters: {'lasso_alpha': 0.029040667785472762, 'elastic_alpha': 0.7892296665703249, 'elastic_l1_ratio': 0.5262006179563865, 'gb_learning_rate': 0.010253927625045813, 'gb_n_estimators': 182, 'rf_n_estimators': 82, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_random_state': 18}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:06:31,163] Trial 41 finished with value: 12.56161838242833 and parameters: {'lasso_alpha': 0.7834941376203971, 'elastic_alpha': 0.9161436006647773, 'elastic_l1_ratio': 0.37386637744235574, 'gb_learning_rate': 0.03640853867307351, 'gb_n_estimators': 109, 'rf_n_estimators': 146, 'rf_max_depth': 6, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 60}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:06:41,433] Trial 42 finished with value: 12.561725805202704 and parameters: {'lasso_alpha': 0.7660013741018503, 'elastic_alpha': 0.9305533600465364, 'elastic_l1_ratio': 0.4344774533223065, 'gb_learning_rate': 0.026921594873298683, 'gb_n_estimators': 125, 'rf_n_estimators': 145, 'rf_max_depth': 6, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 61}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:06:50,934] Trial 43 finished with value: 12.566252505136996 and parameters: {'lasso_alpha': 0.836945046036417, 'elastic_alpha': 0.8539472986870552, 'elastic_l1_ratio': 0.2594400617924763, 'gb_learning_rate': 0.0394456186758855, 'gb_n_estimators': 115, 'rf_n_estimators': 170, 'rf_max_depth': 4, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_random_state': 57}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:07:00,776] Trial 44 finished with value: 12.569419786180287 and parameters: {'lasso_alpha': 0.6021394921711692, 'elastic_alpha': 0.5119518619184406, 'elastic_l1_ratio': 0.32313494085236727, 'gb_learning_rate': 0.07109676370386665, 'gb_n_estimators': 106, 'rf_n_estimators': 139, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 82}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:07:22,868] Trial 45 finished with value: 12.565548750903751 and parameters: {'lasso_alpha': 0.5070824715686493, 'elastic_alpha': 0.8228388280016139, 'elastic_l1_ratio': 0.3747703899730233, 'gb_learning_rate': 0.025532711313885507, 'gb_n_estimators': 283, 'rf_n_estimators': 162, 'rf_max_depth': 6, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 49}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:07:30,108] Trial 46 finished with value: 12.585394624009021 and parameters: {'lasso_alpha': 0.8668440245196802, 'elastic_alpha': 0.6456030447099086, 'elastic_l1_ratio': 0.4293145634548423, 'gb_learning_rate': 0.1810506056405894, 'gb_n_estimators': 65, 'rf_n_estimators': 127, 'rf_max_depth': 9, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 9, 'rf_max_features': 'log2', 'rf_random_state': 94}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:07:46,794] Trial 47 finished with value: 12.563757198232485 and parameters: {'lasso_alpha': 0.9331222722257864, 'elastic_alpha': 0.9976572032684164, 'elastic_l1_ratio': 0.23064745183092217, 'gb_learning_rate': 0.054505899830386756, 'gb_n_estimators': 207, 'rf_n_estimators': 209, 'rf_max_depth': 5, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 64}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:08:15,237] Trial 48 finished with value: 12.559453729843488 and parameters: {'lasso_alpha': 0.6815822956213261, 'elastic_alpha': 0.7738985072239323, 'elastic_l1_ratio': 0.4589644882522867, 'gb_learning_rate': 0.017858107436868546, 'gb_n_estimators': 251, 'rf_n_estimators': 149, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 97}. Best is trial 32 with value: 12.558787719357673.
# [I 2024-10-28 23:08:46,871] Trial 49 finished with value: 12.562155332328688 and parameters: {'lasso_alpha': 0.6819117509919901, 'elastic_alpha': 0.601796022793493, 'elastic_l1_ratio': 0.5141396637355159, 'gb_learning_rate': 0.019286541143588617, 'gb_n_estimators': 252, 'rf_n_estimators': 181, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 97}. Best is trial 32 with value: 12.558787719357673.
# Best parameters: {'lasso_alpha': 0.8047578403183432, 'elastic_alpha': 0.7797332527857485, 'elastic_l1_ratio': 0.4439560000993694, 'gb_learning_rate': 0.011161577541366336, 'gb_n_estimators': 194, 'rf_n_estimators': 187, 'rf_max_depth': 7, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 73}
# Optimized Voting Regressor - Train MAE: 12.281636966341262, Test MAE: 12.478376207295785

# %%
import optuna
from sklearn.ensemble import VotingRegressor, RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import Lasso, ElasticNet, Ridge, LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
from optuna.samplers import TPESampler
import pandas as pd
import numpy as np

# 데이터 로드
train = pd.read_csv('./train.csv')

# yymm 컬럼을 날짜 형식으로 변환 (연도는 임의로 설정)
train['yymm'] = pd.to_datetime('2024' + train['yymm'], format='%Y%m%d %H:%M')

# day, hour, minute 컬럼 생성
train['day'] = train['yymm'].dt.day         # 일
train['hour'] = train['yymm'].dt.hour       # 시
train['minute'] = train['yymm'].dt.minute   # 분

# weekday 컬럼 생성
train['weekday'] = train['day'] % 7         # 요일 (0: 월요일, 1: 화요일, ..., 6: 일요일)

# yymm 컬럼 삭제
train.drop('yymm', axis=1, inplace=True)

# 데이터 분할
X = train.drop('Target', axis=1)  # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']               # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# Optuna 목적 함수 정의
def objective(trial):
    # 하이퍼파라미터 선택
    lasso_alpha = trial.suggest_float('lasso_alpha', 0.001, 1.0)
    elastic_alpha = trial.suggest_float('elastic_alpha', 0.001, 1.0)
    elastic_l1_ratio = trial.suggest_float('elastic_l1_ratio', 0.1, 0.9)
    ridge_alpha = trial.suggest_float('ridge_alpha', 0.001, 1.0)
    gb_learning_rate = trial.suggest_float('gb_learning_rate', 0.01, 0.3)
    gb_n_estimators = trial.suggest_int('gb_n_estimators', 50, 300)

    rf_n_estimators = trial.suggest_int('rf_n_estimators', 50, 300)
    rf_max_depth = trial.suggest_int('rf_max_depth', 3, 20)
    rf_min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
    rf_min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 10)
    rf_max_features = trial.suggest_categorical('rf_max_features', ['sqrt', 'log2', None])
    rf_random_state = trial.suggest_int('rf_random_state', 1, 100)

    # 모델 정의
    lasso = Lasso(alpha=lasso_alpha, random_state=rf_random_state)
    elastic = ElasticNet(alpha=elastic_alpha, l1_ratio=elastic_l1_ratio, random_state=rf_random_state)
    rf = RandomForestRegressor(
        n_estimators=rf_n_estimators,
        max_depth=rf_max_depth,
        min_samples_split=rf_min_samples_split,
        min_samples_leaf=rf_min_samples_leaf,
        max_features=rf_max_features,
        random_state=rf_random_state
    )
    ridge = Ridge(alpha=ridge_alpha, random_state=rf_random_state)
    linear = LinearRegression()
    gb = GradientBoostingRegressor(
        learning_rate=gb_learning_rate,
        n_estimators=gb_n_estimators,
        random_state=rf_random_state
    )

    # VotingRegressor 정의
    voting = VotingRegressor([
        ('lasso', lasso),
        ('elastic', elastic),
        ('rf', rf),
        ('ridge', ridge),
        ('linear', linear),
        ('gb', gb)
    ])

    # 5-fold 교차 검증으로 평가
    scores = cross_val_score(voting, X_train, y_train, cv=5, scoring=mae_scorer)
    return scores.mean()

# Optuna 최적화 실행
study = optuna.create_study(direction='minimize', sampler=TPESampler())
study.optimize(objective, n_trials=100)

# 최적 하이퍼파라미터 출력
print("Best parameters:", study.best_params)

# 최적 하이퍼파라미터로 VotingRegressor 학습
best_lasso = Lasso(alpha=study.best_params['lasso_alpha'], random_state=study.best_params['rf_random_state'])
best_elastic = ElasticNet(alpha=study.best_params['elastic_alpha'], l1_ratio=study.best_params['elastic_l1_ratio'], random_state=study.best_params['rf_random_state'])
best_rf = RandomForestRegressor(
    n_estimators=study.best_params['rf_n_estimators'],
    max_depth=study.best_params['rf_max_depth'],
    min_samples_split=study.best_params['rf_min_samples_split'],
    min_samples_leaf=study.best_params['rf_min_samples_leaf'],
    max_features=study.best_params['rf_max_features'],
    random_state=study.best_params['rf_random_state']
)
best_ridge = Ridge(alpha=study.best_params['ridge_alpha'], random_state=study.best_params['rf_random_state'])
best_linear = LinearRegression()
best_gb = GradientBoostingRegressor(
    learning_rate=study.best_params['gb_learning_rate'],
    n_estimators=study.best_params['gb_n_estimators'],
    random_state=study.best_params['rf_random_state']
)

voting_best = VotingRegressor([
    ('lasso', best_lasso),
    ('elastic', best_elastic),
    ('rf', best_rf),
    ('ridge', best_ridge),
    ('linear', best_linear),
    ('gb', best_gb)
])

# 최적화된 모델 학습 및 평가
voting_best.fit(X_train, y_train)
y_pred = voting_best.predict(X_test)

train_score = mean_absolute_error(y_train, voting_best.predict(X_train))
test_score = mean_absolute_error(y_test, y_pred)

print(f'Optimized Voting Regressor - Train MAE: {train_score}, Test MAE: {test_score}')
# Out:
# [I 2024-10-28 12:11:49,251] A new study created in memory with name: no-name-0546f345-4536-4881-b545-324ce11e5053
# [I 2024-10-28 12:12:20,382] Trial 0 finished with value: 12.626233293414014 and parameters: {'lasso_alpha': 0.3146695602448273, 'elastic_alpha': 0.5293019322114868, 'elastic_l1_ratio': 0.8176425539673525, 'ridge_alpha': 0.2962320642151984, 'gb_learning_rate': 0.29314543313780117, 'gb_n_estimators': 280, 'rf_n_estimators': 100, 'rf_max_depth': 8, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 2, 'rf_max_features': 'sqrt', 'rf_random_state': 21}. Best is trial 0 with value: 12.626233293414014.
# [I 2024-10-28 12:12:38,672] Trial 1 finished with value: 12.609652298942104 and parameters: {'lasso_alpha': 0.9912171900047738, 'elastic_alpha': 0.5178158367809479, 'elastic_l1_ratio': 0.3772104572016993, 'ridge_alpha': 0.8449731157994221, 'gb_learning_rate': 0.27506844882298337, 'gb_n_estimators': 70, 'rf_n_estimators': 250, 'rf_max_depth': 18, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5, 'rf_max_features': 'log2', 'rf_random_state': 59}. Best is trial 1 with value: 12.609652298942104.
# [I 2024-10-28 12:13:03,398] Trial 2 finished with value: 12.586659080618752 and parameters: {'lasso_alpha': 0.40842211100850023, 'elastic_alpha': 0.81334367135101, 'elastic_l1_ratio': 0.17116721732543105, 'ridge_alpha': 0.8735027562292729, 'gb_learning_rate': 0.012329952009322988, 'gb_n_estimators': 193, 'rf_n_estimators': 134, 'rf_max_depth': 17, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 4, 'rf_max_features': 'sqrt', 'rf_random_state': 98}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:13:55,498] Trial 3 finished with value: 12.589686456962655 and parameters: {'lasso_alpha': 0.6350775675352193, 'elastic_alpha': 0.39431170121091785, 'elastic_l1_ratio': 0.268821829233688, 'ridge_alpha': 0.43671409110675347, 'gb_learning_rate': 0.1280676307824232, 'gb_n_estimators': 208, 'rf_n_estimators': 188, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 61}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:14:42,142] Trial 4 finished with value: 12.598371942651534 and parameters: {'lasso_alpha': 0.5013906997176383, 'elastic_alpha': 0.364932461903613, 'elastic_l1_ratio': 0.18915025245906947, 'ridge_alpha': 0.6181336687344658, 'gb_learning_rate': 0.07065419652341125, 'gb_n_estimators': 88, 'rf_n_estimators': 155, 'rf_max_depth': 15, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': None, 'rf_random_state': 44}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:15:29,276] Trial 5 finished with value: 12.586877647466318 and parameters: {'lasso_alpha': 0.8119502509343965, 'elastic_alpha': 0.7900928852820227, 'elastic_l1_ratio': 0.2524955469238641, 'ridge_alpha': 0.8279030349902026, 'gb_learning_rate': 0.11074380403551737, 'gb_n_estimators': 111, 'rf_n_estimators': 227, 'rf_max_depth': 9, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 28}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:15:52,270] Trial 6 finished with value: 12.613149387638195 and parameters: {'lasso_alpha': 0.19158993826601947, 'elastic_alpha': 0.7800269583470474, 'elastic_l1_ratio': 0.8951110711806536, 'ridge_alpha': 0.26152777084367046, 'gb_learning_rate': 0.19348253455756814, 'gb_n_estimators': 139, 'rf_n_estimators': 237, 'rf_max_depth': 14, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 53}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:16:56,751] Trial 7 finished with value: 12.611083179916786 and parameters: {'lasso_alpha': 0.5575116426116289, 'elastic_alpha': 0.08353583551602213, 'elastic_l1_ratio': 0.5218980651208838, 'ridge_alpha': 0.7110424063274164, 'gb_learning_rate': 0.26040356233548545, 'gb_n_estimators': 129, 'rf_n_estimators': 256, 'rf_max_depth': 13, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 96}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:17:26,629] Trial 8 finished with value: 12.594423606832601 and parameters: {'lasso_alpha': 0.4045471954415992, 'elastic_alpha': 0.9812162986227301, 'elastic_l1_ratio': 0.13917167352737386, 'ridge_alpha': 0.06588714855159564, 'gb_learning_rate': 0.08424710125691517, 'gb_n_estimators': 264, 'rf_n_estimators': 268, 'rf_max_depth': 5, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 2}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:17:40,936] Trial 9 finished with value: 12.591664134472623 and parameters: {'lasso_alpha': 0.1572998082659024, 'elastic_alpha': 0.527170376147187, 'elastic_l1_ratio': 0.8476048212811141, 'ridge_alpha': 0.546586609713598, 'gb_learning_rate': 0.10692958812495822, 'gb_n_estimators': 131, 'rf_n_estimators': 79, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_random_state': 50}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:18:06,237] Trial 10 finished with value: 12.591038433873567 and parameters: {'lasso_alpha': 0.038829434076722735, 'elastic_alpha': 0.9997474486573135, 'elastic_l1_ratio': 0.5873025389979363, 'ridge_alpha': 0.9217746275015104, 'gb_learning_rate': 0.016528333602389693, 'gb_n_estimators': 203, 'rf_n_estimators': 136, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_random_state': 100}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:18:26,177] Trial 11 finished with value: 12.58737511015345 and parameters: {'lasso_alpha': 0.803176180256592, 'elastic_alpha': 0.7708602794659593, 'elastic_l1_ratio': 0.33915003439770053, 'ridge_alpha': 0.9934068754078476, 'gb_learning_rate': 0.039865830281566594, 'gb_n_estimators': 180, 'rf_n_estimators': 204, 'rf_max_depth': 3, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 82}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:19:10,390] Trial 12 finished with value: 12.634564772395922 and parameters: {'lasso_alpha': 0.7613930736706243, 'elastic_alpha': 0.7783469210782286, 'elastic_l1_ratio': 0.1129356443679862, 'ridge_alpha': 0.7712956828175841, 'gb_learning_rate': 0.21956743868083844, 'gb_n_estimators': 243, 'rf_n_estimators': 112, 'rf_max_depth': 11, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 24}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:19:25,426] Trial 13 finished with value: 12.597714146409292 and parameters: {'lasso_alpha': 0.9700805657604844, 'elastic_alpha': 0.6990830100365822, 'elastic_l1_ratio': 0.41573121591633033, 'ridge_alpha': 0.7137231570827548, 'gb_learning_rate': 0.17509263295982028, 'gb_n_estimators': 50, 'rf_n_estimators': 212, 'rf_max_depth': 17, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 8, 'rf_max_features': 'sqrt', 'rf_random_state': 29}. Best is trial 2 with value: 12.586659080618752.
# [I 2024-10-28 12:20:37,379] Trial 14 finished with value: 12.583567478839095 and parameters: {'lasso_alpha': 0.7056263045449633, 'elastic_alpha': 0.8937482885208956, 'elastic_l1_ratio': 0.25313451155596434, 'ridge_alpha': 0.8780351729555502, 'gb_learning_rate': 0.010770719674871369, 'gb_n_estimators': 159, 'rf_n_estimators': 298, 'rf_max_depth': 11, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 77}. Best is trial 14 with value: 12.583567478839095.
# [I 2024-10-28 12:21:09,212] Trial 15 finished with value: 12.59223437514034 and parameters: {'lasso_alpha': 0.3501613594783657, 'elastic_alpha': 0.895665421367744, 'elastic_l1_ratio': 0.5867815422637979, 'ridge_alpha': 0.9888756542628925, 'gb_learning_rate': 0.04212537227661173, 'gb_n_estimators': 171, 'rf_n_estimators': 294, 'rf_max_depth': 16, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3, 'rf_max_features': 'sqrt', 'rf_random_state': 78}. Best is trial 14 with value: 12.583567478839095.
# [I 2024-10-28 12:21:42,069] Trial 16 finished with value: 12.592754719316398 and parameters: {'lasso_alpha': 0.6881878456593221, 'elastic_alpha': 0.6391365072472308, 'elastic_l1_ratio': 0.23357290986369345, 'ridge_alpha': 0.6269593361265018, 'gb_learning_rate': 0.015356687990427172, 'gb_n_estimators': 231, 'rf_n_estimators': 56, 'rf_max_depth': 12, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 79}. Best is trial 14 with value: 12.583567478839095.
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.652e+03, tolerance: 5.203e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.511e+03, tolerance: 5.242e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.973e+03, tolerance: 5.323e+01
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.267e+01, tolerance: 5.276e+01
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-10-28 12:22:06,651] Trial 17 finished with value: 12.602551659544757 and parameters: {'lasso_alpha': 0.43269323663083276, 'elastic_alpha': 0.016526043565443904, 'elastic_l1_ratio': 0.6875155801700812, 'ridge_alpha': 0.44852331250352534, 'gb_learning_rate': 0.06271067355085228, 'gb_n_estimators': 173, 'rf_n_estimators': 148, 'rf_max_depth': 20, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 5, 'rf_max_features': 'sqrt', 'rf_random_state': 88}. Best is trial 14 with value: 12.583567478839095.
# [I 2024-10-28 12:22:57,635] Trial 18 finished with value: 12.58979380806269 and parameters: {'lasso_alpha': 0.6156920762949767, 'elastic_alpha': 0.8892518413623178, 'elastic_l1_ratio': 0.32225476240309664, 'ridge_alpha': 0.8857436910124783, 'gb_learning_rate': 0.04683579111829593, 'gb_n_estimators': 151, 'rf_n_estimators': 177, 'rf_max_depth': 11, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2, 'rf_max_features': None, 'rf_random_state': 72}. Best is trial 14 with value: 12.583567478839095.
# [I 2024-10-28 12:23:32,059] Trial 19 finished with value: 12.609158139788741 and parameters: {'lasso_alpha': 0.8737404120946068, 'elastic_alpha': 0.6419616624825462, 'elastic_l1_ratio': 0.4352124889668933, 'ridge_alpha': 0.7426107282731313, 'gb_learning_rate': 0.13921120212604923, 'gb_n_estimators': 214, 'rf_n_estimators': 300, 'rf_max_depth': 18, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 6, 'rf_max_features': 'sqrt', 'rf_random_state': 70}. Best is trial 14 with value: 12.583567478839095.
# [I 2024-10-28 12:24:28,583] Trial 20 finished with value: 12.61426109635588 and parameters: {'lasso_alpha': 0.23603461180841528, 'elastic_alpha': 0.26488210953376023, 'elastic_l1_ratio': 0.1758874799040903, 'ridge_alpha': 0.03075293051888983, 'gb_learning_rate': 0.08745484368411416, 'gb_n_estimators': 294, 'rf_n_estimators': 123, 'rf_max_depth': 14, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 92}. Best is trial 14 with value: 12.583567478839095.
# [I 2024-10-28 12:25:18,963] Trial 21 finished with value: 12.583561920814045 and parameters: {'lasso_alpha': 0.7644170711363534, 'elastic_alpha': 0.8929907613115193, 'elastic_l1_ratio': 0.25873715532367175, 'ridge_alpha': 0.830299774083072, 'gb_learning_rate': 0.018134330700846586, 'gb_n_estimators': 103, 'rf_n_estimators': 229, 'rf_max_depth': 10, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 34}. Best is trial 21 with value: 12.583561920814045.
# [I 2024-10-28 12:26:16,809] Trial 22 finished with value: 12.583257501566584 and parameters: {'lasso_alpha': 0.6704289242729609, 'elastic_alpha': 0.8744735416420788, 'elastic_l1_ratio': 0.2834963379642274, 'ridge_alpha': 0.809656023950018, 'gb_learning_rate': 0.014979419914757772, 'gb_n_estimators': 107, 'rf_n_estimators': 274, 'rf_max_depth': 10, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 39}. Best is trial 22 with value: 12.583257501566584.
# [I 2024-10-28 12:27:14,775] Trial 23 finished with value: 12.581565211337715 and parameters: {'lasso_alpha': 0.7141883680383985, 'elastic_alpha': 0.9121739467774579, 'elastic_l1_ratio': 0.303218725437165, 'ridge_alpha': 0.6447575938298022, 'gb_learning_rate': 0.03515876850885648, 'gb_n_estimators': 104, 'rf_n_estimators': 273, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 43}. Best is trial 23 with value: 12.581565211337715.
# [I 2024-10-28 12:27:55,509] Trial 24 finished with value: 12.580796804475446 and parameters: {'lasso_alpha': 0.8788893799579099, 'elastic_alpha': 0.9321387973388844, 'elastic_l1_ratio': 0.45937426944613285, 'ridge_alpha': 0.6525265230462438, 'gb_learning_rate': 0.04282328018443664, 'gb_n_estimators': 102, 'rf_n_estimators': 263, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 37}. Best is trial 24 with value: 12.580796804475446.
# [I 2024-10-28 12:28:35,611] Trial 25 finished with value: 12.57649274378048 and parameters: {'lasso_alpha': 0.8836602819002147, 'elastic_alpha': 0.963808942667083, 'elastic_l1_ratio': 0.493407353571564, 'ridge_alpha': 0.6155306109203728, 'gb_learning_rate': 0.05348593800988481, 'gb_n_estimators': 78, 'rf_n_estimators': 275, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 39}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:29:15,834] Trial 26 finished with value: 12.580461328918796 and parameters: {'lasso_alpha': 0.8952313469031484, 'elastic_alpha': 0.9971805074625228, 'elastic_l1_ratio': 0.5079634945395453, 'ridge_alpha': 0.6111843316644441, 'gb_learning_rate': 0.059716227686121726, 'gb_n_estimators': 76, 'rf_n_estimators': 276, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 14}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:29:55,719] Trial 27 finished with value: 12.579265794159443 and parameters: {'lasso_alpha': 0.8973842349061409, 'elastic_alpha': 0.9810596238434319, 'elastic_l1_ratio': 0.49453409097298673, 'ridge_alpha': 0.5367883913795962, 'gb_learning_rate': 0.06562732283600303, 'gb_n_estimators': 70, 'rf_n_estimators': 279, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 12}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:30:25,112] Trial 28 finished with value: 12.582392948832357 and parameters: {'lasso_alpha': 0.8991755518714735, 'elastic_alpha': 0.9869743696939611, 'elastic_l1_ratio': 0.53139892117543, 'ridge_alpha': 0.5421907317196113, 'gb_learning_rate': 0.09273264652860705, 'gb_n_estimators': 59, 'rf_n_estimators': 282, 'rf_max_depth': 4, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 11}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:31:04,762] Trial 29 finished with value: 12.577550213041977 and parameters: {'lasso_alpha': 0.9217533307608431, 'elastic_alpha': 0.6951116612575636, 'elastic_l1_ratio': 0.7202899049470578, 'ridge_alpha': 0.29330732647900704, 'gb_learning_rate': 0.06460038372993455, 'gb_n_estimators': 69, 'rf_n_estimators': 245, 'rf_max_depth': 7, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 15}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:31:45,538] Trial 30 finished with value: 12.58344631038598 and parameters: {'lasso_alpha': 0.9414692346251086, 'elastic_alpha': 0.6845800685418909, 'elastic_l1_ratio': 0.7039390878972865, 'ridge_alpha': 0.34391345591519995, 'gb_learning_rate': 0.15508969557125307, 'gb_n_estimators': 81, 'rf_n_estimators': 245, 'rf_max_depth': 7, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 17}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:32:20,572] Trial 31 finished with value: 12.581220135926674 and parameters: {'lasso_alpha': 0.8505686139786883, 'elastic_alpha': 0.8505914433094097, 'elastic_l1_ratio': 0.699301327497457, 'ridge_alpha': 0.20069472863568721, 'gb_learning_rate': 0.06629201294334694, 'gb_n_estimators': 73, 'rf_n_estimators': 282, 'rf_max_depth': 5, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 8}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:33:00,572] Trial 32 finished with value: 12.58072100623016 and parameters: {'lasso_alpha': 0.9936884115123065, 'elastic_alpha': 0.9538739636261566, 'elastic_l1_ratio': 0.6192184654113277, 'ridge_alpha': 0.38943395293282035, 'gb_learning_rate': 0.06576203369931857, 'gb_n_estimators': 64, 'rf_n_estimators': 251, 'rf_max_depth': 7, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 18}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:33:23,194] Trial 33 finished with value: 12.587406467691457 and parameters: {'lasso_alpha': 0.9257208041117655, 'elastic_alpha': 0.7095711186335998, 'elastic_l1_ratio': 0.46842765816039833, 'ridge_alpha': 0.5166886429054403, 'gb_learning_rate': 0.11833690831254151, 'gb_n_estimators': 85, 'rf_n_estimators': 217, 'rf_max_depth': 3, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 11}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:33:36,704] Trial 34 finished with value: 12.58216197597175 and parameters: {'lasso_alpha': 0.8222062944636741, 'elastic_alpha': 0.6111901135909932, 'elastic_l1_ratio': 0.7710339358681142, 'ridge_alpha': 0.1649923622049942, 'gb_learning_rate': 0.09403387906205628, 'gb_n_estimators': 50, 'rf_n_estimators': 283, 'rf_max_depth': 8, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 10, 'rf_max_features': 'log2', 'rf_random_state': 4}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:34:04,937] Trial 35 finished with value: 12.582482183129326 and parameters: {'lasso_alpha': 0.9141615339815387, 'elastic_alpha': 0.44652215458170097, 'elastic_l1_ratio': 0.3751793689120745, 'ridge_alpha': 0.46458631649731025, 'gb_learning_rate': 0.05688912041651252, 'gb_n_estimators': 88, 'rf_n_estimators': 196, 'rf_max_depth': 5, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 16}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:34:48,094] Trial 36 finished with value: 12.579467332840867 and parameters: {'lasso_alpha': 0.9988643483560011, 'elastic_alpha': 0.8418204532942659, 'elastic_l1_ratio': 0.6397431543067441, 'ridge_alpha': 0.5931810389265272, 'gb_learning_rate': 0.07795006010004374, 'gb_n_estimators': 70, 'rf_n_estimators': 245, 'rf_max_depth': 8, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 22}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:35:35,350] Trial 37 finished with value: 12.580751653014321 and parameters: {'lasso_alpha': 0.9833984020766245, 'elastic_alpha': 0.8307282241297675, 'elastic_l1_ratio': 0.757181948665225, 'ridge_alpha': 0.39108549954469596, 'gb_learning_rate': 0.07973146392850033, 'gb_n_estimators': 118, 'rf_n_estimators': 238, 'rf_max_depth': 8, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 24}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:35:49,532] Trial 38 finished with value: 12.586732104067618 and parameters: {'lasso_alpha': 0.7870896180130522, 'elastic_alpha': 0.5863868623439992, 'elastic_l1_ratio': 0.6276291695209544, 'ridge_alpha': 0.5677227923476377, 'gb_learning_rate': 0.12963261626364664, 'gb_n_estimators': 67, 'rf_n_estimators': 260, 'rf_max_depth': 8, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_random_state': 30}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:36:24,969] Trial 39 finished with value: 12.583133893546478 and parameters: {'lasso_alpha': 0.6085870880010112, 'elastic_alpha': 0.8225587109018819, 'elastic_l1_ratio': 0.6587547693656245, 'ridge_alpha': 0.25943642153731494, 'gb_learning_rate': 0.1094618942589622, 'gb_n_estimators': 94, 'rf_n_estimators': 225, 'rf_max_depth': 6, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 22}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:37:05,597] Trial 40 finished with value: 12.596677042334111 and parameters: {'lasso_alpha': 0.9948292312423638, 'elastic_alpha': 0.7469890588255034, 'elastic_l1_ratio': 0.5501339938318793, 'ridge_alpha': 0.4842997852706221, 'gb_learning_rate': 0.1455156121250179, 'gb_n_estimators': 120, 'rf_n_estimators': 181, 'rf_max_depth': 9, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 49}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:37:42,101] Trial 41 finished with value: 12.581651832437068 and parameters: {'lasso_alpha': 0.9329528703639295, 'elastic_alpha': 0.935956994272353, 'elastic_l1_ratio': 0.49193143682110463, 'ridge_alpha': 0.5962546884368635, 'gb_learning_rate': 0.07409642625719029, 'gb_n_estimators': 75, 'rf_n_estimators': 248, 'rf_max_depth': 6, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 13}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:38:12,630] Trial 42 finished with value: 12.57824044762514 and parameters: {'lasso_alpha': 0.8454243798135292, 'elastic_alpha': 0.9556514063404984, 'elastic_l1_ratio': 0.749632012522159, 'ridge_alpha': 0.6784669306062815, 'gb_learning_rate': 0.03055334510432752, 'gb_n_estimators': 64, 'rf_n_estimators': 286, 'rf_max_depth': 4, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 1}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:38:43,262] Trial 43 finished with value: 12.57915734979198 and parameters: {'lasso_alpha': 0.8285242855957491, 'elastic_alpha': 0.8425929199654226, 'elastic_l1_ratio': 0.8202158509110948, 'ridge_alpha': 0.6818590135964065, 'gb_learning_rate': 0.03377586212789564, 'gb_n_estimators': 62, 'rf_n_estimators': 288, 'rf_max_depth': 4, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 6}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:39:12,656] Trial 44 finished with value: 12.577284926107655 and parameters: {'lasso_alpha': 0.8410014270541142, 'elastic_alpha': 0.9533431991148056, 'elastic_l1_ratio': 0.8393883057461817, 'ridge_alpha': 0.7099305032912522, 'gb_learning_rate': 0.028851314432476547, 'gb_n_estimators': 58, 'rf_n_estimators': 287, 'rf_max_depth': 4, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 1}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:39:24,026] Trial 45 finished with value: 12.580852529315463 and parameters: {'lasso_alpha': 0.8340399343324418, 'elastic_alpha': 0.7404345662149334, 'elastic_l1_ratio': 0.8937292196445581, 'ridge_alpha': 0.6923319036674177, 'gb_learning_rate': 0.02835105864341357, 'gb_n_estimators': 56, 'rf_n_estimators': 290, 'rf_max_depth': 4, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 7, 'rf_max_features': 'log2', 'rf_random_state': 4}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:39:54,544] Trial 46 finished with value: 12.5786911596703 and parameters: {'lasso_alpha': 0.7304428737871823, 'elastic_alpha': 0.7966216031630493, 'elastic_l1_ratio': 0.802909581531805, 'ridge_alpha': 0.7729905132290865, 'gb_learning_rate': 0.028351461312424935, 'gb_n_estimators': 93, 'rf_n_estimators': 264, 'rf_max_depth': 4, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 1}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:40:20,968] Trial 47 finished with value: 12.582658872398547 and parameters: {'lasso_alpha': 0.7412351077563281, 'elastic_alpha': 0.2839537491471016, 'elastic_l1_ratio': 0.7567371051332764, 'ridge_alpha': 0.7514586111522563, 'gb_learning_rate': 0.04943818061025111, 'gb_n_estimators': 92, 'rf_n_estimators': 265, 'rf_max_depth': 3, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 2}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:40:55,481] Trial 48 finished with value: 12.578733365515745 and parameters: {'lasso_alpha': 0.5275332805306666, 'elastic_alpha': 0.7905334931636623, 'elastic_l1_ratio': 0.859223362136407, 'ridge_alpha': 0.7846304748944951, 'gb_learning_rate': 0.027021734220613568, 'gb_n_estimators': 136, 'rf_n_estimators': 257, 'rf_max_depth': 4, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 8}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:41:12,789] Trial 49 finished with value: 12.598604458796114 and parameters: {'lasso_alpha': 0.784463083068205, 'elastic_alpha': 0.947738807267057, 'elastic_l1_ratio': 0.8184013589551749, 'ridge_alpha': 0.7314227282205754, 'gb_learning_rate': 0.28064575856688234, 'gb_n_estimators': 121, 'rf_n_estimators': 269, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': 'log2', 'rf_random_state': 59}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:41:28,414] Trial 50 finished with value: 12.593267875051154 and parameters: {'lasso_alpha': 0.641430679902407, 'elastic_alpha': 0.5766526203363933, 'elastic_l1_ratio': 0.7757415965709822, 'ridge_alpha': 0.9115959751591244, 'gb_learning_rate': 0.24740648401190649, 'gb_n_estimators': 53, 'rf_n_estimators': 158, 'rf_max_depth': 3, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 1}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:42:01,702] Trial 51 finished with value: 12.578356402850961 and parameters: {'lasso_alpha': 0.5222772271874001, 'elastic_alpha': 0.7894079223453047, 'elastic_l1_ratio': 0.8548001151435163, 'ridge_alpha': 0.7770371000505777, 'gb_learning_rate': 0.02731540803285838, 'gb_n_estimators': 132, 'rf_n_estimators': 253, 'rf_max_depth': 4, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 8}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:42:35,343] Trial 52 finished with value: 12.578988478255333 and parameters: {'lasso_alpha': 0.5641206308205915, 'elastic_alpha': 0.8005529069026395, 'elastic_l1_ratio': 0.8624891885654671, 'ridge_alpha': 0.7873944790052364, 'gb_learning_rate': 0.02548036965708514, 'gb_n_estimators': 95, 'rf_n_estimators': 239, 'rf_max_depth': 5, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 7}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:43:14,322] Trial 53 finished with value: 12.581380687772999 and parameters: {'lasso_alpha': 0.48028487826520905, 'elastic_alpha': 0.7254885391852682, 'elastic_l1_ratio': 0.7336533439666448, 'ridge_alpha': 0.6710873949811966, 'gb_learning_rate': 0.05055115139794615, 'gb_n_estimators': 149, 'rf_n_estimators': 299, 'rf_max_depth': 4, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 6, 'rf_max_features': None, 'rf_random_state': 9}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:43:26,933] Trial 54 finished with value: 12.581853436243696 and parameters: {'lasso_alpha': 0.8553932280107488, 'elastic_alpha': 0.6643096697667138, 'elastic_l1_ratio': 0.7916467106723845, 'ridge_alpha': 0.83931739346585, 'gb_learning_rate': 0.036005757686954756, 'gb_n_estimators': 81, 'rf_n_estimators': 256, 'rf_max_depth': 3, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 7, 'rf_max_features': 'sqrt', 'rf_random_state': 1}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:44:00,377] Trial 55 finished with value: 12.578681277242776 and parameters: {'lasso_alpha': 0.7439992530669892, 'elastic_alpha': 0.8625452176362579, 'elastic_l1_ratio': 0.8917756793856587, 'ridge_alpha': 0.6972848113969226, 'gb_learning_rate': 0.010429848507715528, 'gb_n_estimators': 113, 'rf_n_estimators': 228, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 18}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:44:42,592] Trial 56 finished with value: 12.57995812410355 and parameters: {'lasso_alpha': 0.26720014511357293, 'elastic_alpha': 0.8704806087846743, 'elastic_l1_ratio': 0.8838687047704306, 'ridge_alpha': 0.7207886049845639, 'gb_learning_rate': 0.01797503420373199, 'gb_n_estimators': 112, 'rf_n_estimators': 231, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 26}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:45:22,516] Trial 57 finished with value: 12.585919778174327 and parameters: {'lasso_alpha': 0.051677721429263856, 'elastic_alpha': 0.9197901367439506, 'elastic_l1_ratio': 0.8332493508085348, 'ridge_alpha': 0.6395391292278864, 'gb_learning_rate': 0.051342516610044374, 'gb_n_estimators': 191, 'rf_n_estimators': 218, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5, 'rf_max_features': None, 'rf_random_state': 64}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:45:40,207] Trial 58 finished with value: 12.580418931309708 and parameters: {'lasso_alpha': 0.9590661590656089, 'elastic_alpha': 0.939847201031189, 'elastic_l1_ratio': 0.719609720063156, 'ridge_alpha': 0.13410188290141736, 'gb_learning_rate': 0.011887938103390096, 'gb_n_estimators': 126, 'rf_n_estimators': 205, 'rf_max_depth': 5, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 20}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:46:29,776] Trial 59 finished with value: 12.580247599457593 and parameters: {'lasso_alpha': 0.6579687103812372, 'elastic_alpha': 0.7614773033452664, 'elastic_l1_ratio': 0.8469879250315456, 'ridge_alpha': 0.6993278032059754, 'gb_learning_rate': 0.04257473150174404, 'gb_n_estimators': 164, 'rf_n_estimators': 289, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 7, 'rf_max_features': None, 'rf_random_state': 33}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:46:44,196] Trial 60 finished with value: 12.581406176126945 and parameters: {'lasso_alpha': 0.3980226919077158, 'elastic_alpha': 0.9680194376856301, 'elastic_l1_ratio': 0.8991152398596032, 'ridge_alpha': 0.9399631237419149, 'gb_learning_rate': 0.19860066280181476, 'gb_n_estimators': 82, 'rf_n_estimators': 93, 'rf_max_depth': 3, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1, 'rf_max_features': None, 'rf_random_state': 16}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:47:16,283] Trial 61 finished with value: 12.578822143207875 and parameters: {'lasso_alpha': 0.7216001017680794, 'elastic_alpha': 0.8700767466046953, 'elastic_l1_ratio': 0.8201604628197745, 'ridge_alpha': 0.7610475201580472, 'gb_learning_rate': 0.027167768337972895, 'gb_n_estimators': 94, 'rf_n_estimators': 267, 'rf_max_depth': 4, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 5}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:47:51,159] Trial 62 finished with value: 12.578735643282036 and parameters: {'lasso_alpha': 0.740932664914096, 'elastic_alpha': 0.7954506687921113, 'elastic_l1_ratio': 0.7967855735546903, 'ridge_alpha': 0.8056292753401587, 'gb_learning_rate': 0.022319860847909018, 'gb_n_estimators': 143, 'rf_n_estimators': 253, 'rf_max_depth': 4, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 10}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:48:29,605] Trial 63 finished with value: 12.579111711277864 and parameters: {'lasso_alpha': 0.7985264394238275, 'elastic_alpha': 0.9087617923494344, 'elastic_l1_ratio': 0.7973283632406036, 'ridge_alpha': 0.8504717328115909, 'gb_learning_rate': 0.010703509503565946, 'gb_n_estimators': 100, 'rf_n_estimators': 275, 'rf_max_depth': 5, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 8, 'rf_max_features': None, 'rf_random_state': 14}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:49:03,156] Trial 64 finished with value: 12.578068475332806 and parameters: {'lasso_alpha': 0.8588958764357159, 'elastic_alpha': 0.862861118561725, 'elastic_l1_ratio': 0.8691120034055868, 'ridge_alpha': 0.5710659539394483, 'gb_learning_rate': 0.03950484115683425, 'gb_n_estimators': 112, 'rf_n_estimators': 262, 'rf_max_depth': 4, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 6}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:49:41,795] Trial 65 finished with value: 12.57689519948126 and parameters: {'lasso_alpha': 0.8697778014736695, 'elastic_alpha': 0.867256142532048, 'elastic_l1_ratio': 0.8493488472111304, 'ridge_alpha': 0.5693555955974161, 'gb_learning_rate': 0.05416638814043283, 'gb_n_estimators': 111, 'rf_n_estimators': 237, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 19}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:50:26,671] Trial 66 finished with value: 12.585231603986491 and parameters: {'lasso_alpha': 0.8676344105494794, 'elastic_alpha': 0.9026540290330706, 'elastic_l1_ratio': 0.8611422209865518, 'ridge_alpha': 0.555980323880358, 'gb_learning_rate': 0.09769821798796219, 'gb_n_estimators': 131, 'rf_n_estimators': 242, 'rf_max_depth': 7, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 5}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:51:07,420] Trial 67 finished with value: 12.578005474198969 and parameters: {'lasso_alpha': 0.9467431990639277, 'elastic_alpha': 0.958154409450264, 'elastic_l1_ratio': 0.738485051578701, 'ridge_alpha': 0.5840942626504836, 'gb_learning_rate': 0.05589807473303411, 'gb_n_estimators': 61, 'rf_n_estimators': 292, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 45}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:52:00,190] Trial 68 finished with value: 12.576952527509592 and parameters: {'lasso_alpha': 0.953840494734367, 'elastic_alpha': 0.9985075228148117, 'elastic_l1_ratio': 0.7411014107067557, 'ridge_alpha': 0.4107660182694111, 'gb_learning_rate': 0.057270367022943955, 'gb_n_estimators': 55, 'rf_n_estimators': 293, 'rf_max_depth': 9, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 49}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:52:14,896] Trial 69 finished with value: 12.579841212863306 and parameters: {'lasso_alpha': 0.9513786309264458, 'elastic_alpha': 0.9927999427998133, 'elastic_l1_ratio': 0.6745837206319133, 'ridge_alpha': 0.4152278284017765, 'gb_learning_rate': 0.08671167567756308, 'gb_n_estimators': 58, 'rf_n_estimators': 294, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': 'sqrt', 'rf_random_state': 53}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:52:30,793] Trial 70 finished with value: 12.582928118249 and parameters: {'lasso_alpha': 0.9110494862623352, 'elastic_alpha': 0.9627391642679289, 'elastic_l1_ratio': 0.5901113197163869, 'ridge_alpha': 0.28587298723470045, 'gb_learning_rate': 0.07163061952196974, 'gb_n_estimators': 78, 'rf_n_estimators': 276, 'rf_max_depth': 9, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': 'log2', 'rf_random_state': 45}. Best is trial 25 with value: 12.57649274378048.
# [I 2024-10-28 12:53:10,811] Trial 71 finished with value: 12.57543219565836 and parameters: {'lasso_alpha': 0.87975180300022, 'elastic_alpha': 0.9583534291840334, 'elastic_l1_ratio': 0.7329161446530024, 'ridge_alpha': 0.583133995768023, 'gb_learning_rate': 0.05843394170060385, 'gb_n_estimators': 66, 'rf_n_estimators': 285, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 49}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 12:54:00,545] Trial 72 finished with value: 12.578007693981236 and parameters: {'lasso_alpha': 0.8820055303760961, 'elastic_alpha': 0.913645723610227, 'elastic_l1_ratio': 0.718582752374095, 'ridge_alpha': 0.35444388099117413, 'gb_learning_rate': 0.0580309661878207, 'gb_n_estimators': 70, 'rf_n_estimators': 300, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 46}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 12:54:53,553] Trial 73 finished with value: 12.581375631762214 and parameters: {'lasso_alpha': 0.9596569597423841, 'elastic_alpha': 0.9295068911752457, 'elastic_l1_ratio': 0.7162950334293621, 'ridge_alpha': 0.31267871895426874, 'gb_learning_rate': 0.0589939790506848, 'gb_n_estimators': 50, 'rf_n_estimators': 299, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 42}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 12:55:33,623] Trial 74 finished with value: 12.57748959980022 and parameters: {'lasso_alpha': 0.8969532465085357, 'elastic_alpha': 0.974888313941841, 'elastic_l1_ratio': 0.67520131329682, 'ridge_alpha': 0.5033097289384103, 'gb_learning_rate': 0.05612740205242288, 'gb_n_estimators': 62, 'rf_n_estimators': 292, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 46}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 12:56:12,620] Trial 75 finished with value: 12.577256433265589 and parameters: {'lasso_alpha': 0.9279487227596566, 'elastic_alpha': 0.9765501650726016, 'elastic_l1_ratio': 0.6756450399668344, 'ridge_alpha': 0.5164335276543365, 'gb_learning_rate': 0.0815299297058033, 'gb_n_estimators': 61, 'rf_n_estimators': 281, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 58}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 12:56:56,287] Trial 76 finished with value: 12.58111444906957 and parameters: {'lasso_alpha': 0.9203722635019431, 'elastic_alpha': 0.9955503750744962, 'elastic_l1_ratio': 0.6610216054764751, 'ridge_alpha': 0.5094921990071027, 'gb_learning_rate': 0.10119904914863215, 'gb_n_estimators': 67, 'rf_n_estimators': 282, 'rf_max_depth': 7, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 58}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 12:57:35,590] Trial 77 finished with value: 12.581688755420847 and parameters: {'lasso_alpha': 0.8139501489755288, 'elastic_alpha': 0.49739312153836635, 'elastic_l1_ratio': 0.5649900316108011, 'ridge_alpha': 0.47962351683036286, 'gb_learning_rate': 0.08024046788721191, 'gb_n_estimators': 77, 'rf_n_estimators': 272, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 55}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 12:58:22,361] Trial 78 finished with value: 12.578498227822758 and parameters: {'lasso_alpha': 0.8899088386563233, 'elastic_alpha': 0.9731414171117867, 'elastic_l1_ratio': 0.6838583745944441, 'ridge_alpha': 0.43837831917574577, 'gb_learning_rate': 0.06915020477455937, 'gb_n_estimators': 56, 'rf_n_estimators': 280, 'rf_max_depth': 8, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 66}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 12:59:16,154] Trial 79 finished with value: 12.578511186309523 and parameters: {'lasso_alpha': 0.9679000065172584, 'elastic_alpha': 0.998805722246267, 'elastic_l1_ratio': 0.5968035729773851, 'ridge_alpha': 0.5334139582439409, 'gb_learning_rate': 0.04593726427287734, 'gb_n_estimators': 86, 'rf_n_estimators': 287, 'rf_max_depth': 9, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 49}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:00:05,999] Trial 80 finished with value: 12.580336178875543 and parameters: {'lasso_alpha': 0.7697471342648854, 'elastic_alpha': 0.8949824510001394, 'elastic_l1_ratio': 0.40852911015285664, 'ridge_alpha': 0.6208519715530352, 'gb_learning_rate': 0.08639788910838826, 'gb_n_estimators': 71, 'rf_n_estimators': 293, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 39}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:00:45,691] Trial 81 finished with value: 12.57722254692867 and parameters: {'lasso_alpha': 0.9405714366809282, 'elastic_alpha': 0.9571953419021318, 'elastic_l1_ratio': 0.7393246193544831, 'ridge_alpha': 0.5955639732855631, 'gb_learning_rate': 0.055192021003828605, 'gb_n_estimators': 63, 'rf_n_estimators': 290, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 53}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:01:22,876] Trial 82 finished with value: 12.578827206181257 and parameters: {'lasso_alpha': 0.925510182821002, 'elastic_alpha': 0.93742251727878, 'elastic_l1_ratio': 0.7774844987143483, 'ridge_alpha': 0.49365489663421613, 'gb_learning_rate': 0.06434284905063227, 'gb_n_estimators': 62, 'rf_n_estimators': 269, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 56}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:02:00,832] Trial 83 finished with value: 12.578317478536329 and parameters: {'lasso_alpha': 0.8884414041211532, 'elastic_alpha': 0.9750233975548191, 'elastic_l1_ratio': 0.6563071035909501, 'ridge_alpha': 0.4611368923173044, 'gb_learning_rate': 0.07440536193651573, 'gb_n_estimators': 54, 'rf_n_estimators': 279, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 48}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:03:02,513] Trial 84 finished with value: 12.5887550845346 and parameters: {'lasso_alpha': 0.9794393775337699, 'elastic_alpha': 0.12895212556684083, 'elastic_l1_ratio': 0.7007368269140206, 'ridge_alpha': 0.4134642863851542, 'gb_learning_rate': 0.05192470019709623, 'gb_n_estimators': 74, 'rf_n_estimators': 286, 'rf_max_depth': 12, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 52}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:03:17,420] Trial 85 finished with value: 12.58158459570691 and parameters: {'lasso_alpha': 0.8362624000016642, 'elastic_alpha': 0.8884216905862303, 'elastic_l1_ratio': 0.6153415412017965, 'ridge_alpha': 0.5225899348899075, 'gb_learning_rate': 0.039922744926650836, 'gb_n_estimators': 63, 'rf_n_estimators': 50, 'rf_max_depth': 10, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 62}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:04:04,794] Trial 86 finished with value: 12.578589495297562 and parameters: {'lasso_alpha': 0.9354773736198919, 'elastic_alpha': 0.8211371982184718, 'elastic_l1_ratio': 0.7436066689299076, 'ridge_alpha': 0.6054813581996836, 'gb_learning_rate': 0.06334155240260707, 'gb_n_estimators': 85, 'rf_n_estimators': 294, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 40}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:04:36,805] Trial 87 finished with value: 12.581730071458848 and parameters: {'lasso_alpha': 0.9063316476308936, 'elastic_alpha': 0.9231739470140418, 'elastic_l1_ratio': 0.6418229486429854, 'ridge_alpha': 0.6551689004273887, 'gb_learning_rate': 0.046531766698175665, 'gb_n_estimators': 266, 'rf_n_estimators': 276, 'rf_max_depth': 8, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 4, 'rf_max_features': 'log2', 'rf_random_state': 36}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:05:12,805] Trial 88 finished with value: 12.578952304691224 and parameters: {'lasso_alpha': 0.8615741849274778, 'elastic_alpha': 0.9521871037380111, 'elastic_l1_ratio': 0.7657335824282133, 'ridge_alpha': 0.23727019644071973, 'gb_learning_rate': 0.07317077210244045, 'gb_n_estimators': 50, 'rf_n_estimators': 260, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 55}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:05:27,752] Trial 89 finished with value: 12.58051689650667 and parameters: {'lasso_alpha': 0.8116777790762313, 'elastic_alpha': 0.9779112527665448, 'elastic_l1_ratio': 0.46785587835252523, 'ridge_alpha': 0.5545350126991632, 'gb_learning_rate': 0.03613622416601894, 'gb_n_estimators': 66, 'rf_n_estimators': 271, 'rf_max_depth': 7, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 9, 'rf_max_features': 'sqrt', 'rf_random_state': 67}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:06:06,361] Trial 90 finished with value: 12.578579316014503 and parameters: {'lasso_alpha': 0.99886847478018, 'elastic_alpha': 0.885422901493292, 'elastic_l1_ratio': 0.8338408233263408, 'ridge_alpha': 0.6186119582654634, 'gb_learning_rate': 0.09163195536358129, 'gb_n_estimators': 56, 'rf_n_estimators': 282, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 51}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:06:46,180] Trial 91 finished with value: 12.577136077068214 and parameters: {'lasso_alpha': 0.9507797678618228, 'elastic_alpha': 0.9494463874508764, 'elastic_l1_ratio': 0.734038225136016, 'ridge_alpha': 0.5865643485553047, 'gb_learning_rate': 0.058286439547036384, 'gb_n_estimators': 60, 'rf_n_estimators': 293, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 43}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:07:23,315] Trial 92 finished with value: 12.578309202731333 and parameters: {'lasso_alpha': 0.9692557872978992, 'elastic_alpha': 0.9407715124109063, 'elastic_l1_ratio': 0.6920894484757828, 'ridge_alpha': 0.5731280095824379, 'gb_learning_rate': 0.056673956922991334, 'gb_n_estimators': 76, 'rf_n_estimators': 295, 'rf_max_depth': 5, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 31}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:08:07,931] Trial 93 finished with value: 12.580911872264283 and parameters: {'lasso_alpha': 0.9052575921946603, 'elastic_alpha': 0.9979473134373694, 'elastic_l1_ratio': 0.6723346164562944, 'ridge_alpha': 0.5319596273992361, 'gb_learning_rate': 0.11779058331354361, 'gb_n_estimators': 69, 'rf_n_estimators': 289, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 42}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:08:42,670] Trial 94 finished with value: 12.580101822394417 and parameters: {'lasso_alpha': 0.9333926920932258, 'elastic_alpha': 0.9162933348837992, 'elastic_l1_ratio': 0.7269609175009925, 'ridge_alpha': 0.5092939155109897, 'gb_learning_rate': 0.07996655171772733, 'gb_n_estimators': 63, 'rf_n_estimators': 284, 'rf_max_depth': 5, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 60}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:09:34,704] Trial 95 finished with value: 12.582746206434669 and parameters: {'lasso_alpha': 0.9471873967367306, 'elastic_alpha': 0.8431007447313408, 'elastic_l1_ratio': 0.7744408836853256, 'ridge_alpha': 0.6542669446124164, 'gb_learning_rate': 0.06648543164761621, 'gb_n_estimators': 88, 'rf_n_estimators': 300, 'rf_max_depth': 8, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 48}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:10:11,251] Trial 96 finished with value: 12.577616806395081 and parameters: {'lasso_alpha': 0.8751092643014081, 'elastic_alpha': 0.97569133454181, 'elastic_l1_ratio': 0.5356198798750462, 'ridge_alpha': 0.5924376621837827, 'gb_learning_rate': 0.05279718500960374, 'gb_n_estimators': 57, 'rf_n_estimators': 268, 'rf_max_depth': 6, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 36}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:10:35,630] Trial 97 finished with value: 12.579581384432405 and parameters: {'lasso_alpha': 0.8326508527044891, 'elastic_alpha': 0.9535330111695379, 'elastic_l1_ratio': 0.7059297032917043, 'ridge_alpha': 0.36833183028040906, 'gb_learning_rate': 0.0473964880432691, 'gb_n_estimators': 82, 'rf_n_estimators': 168, 'rf_max_depth': 5, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 57}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:11:19,925] Trial 98 finished with value: 12.581266092200362 and parameters: {'lasso_alpha': 0.9164260186305478, 'elastic_alpha': 0.9130040043786556, 'elastic_l1_ratio': 0.7432427339088671, 'ridge_alpha': 0.4712717022095795, 'gb_learning_rate': 0.17225317422196426, 'gb_n_estimators': 73, 'rf_n_estimators': 277, 'rf_max_depth': 7, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 9, 'rf_max_features': None, 'rf_random_state': 28}. Best is trial 71 with value: 12.57543219565836.
# [I 2024-10-28 13:12:37,424] Trial 99 finished with value: 12.594053478807277 and parameters: {'lasso_alpha': 0.8870587929510196, 'elastic_alpha': 0.8825728408235411, 'elastic_l1_ratio': 0.7843599065747989, 'ridge_alpha': 0.6330253372951299, 'gb_learning_rate': 0.06147418962048247, 'gb_n_estimators': 222, 'rf_n_estimators': 233, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 3, 'rf_max_features': None, 'rf_random_state': 53}. Best is trial 71 with value: 12.57543219565836.
# Best parameters: {'lasso_alpha': 0.87975180300022, 'elastic_alpha': 0.9583534291840334, 'elastic_l1_ratio': 0.7329161446530024, 'ridge_alpha': 0.583133995768023, 'gb_learning_rate': 0.05843394170060385, 'gb_n_estimators': 66, 'rf_n_estimators': 285, 'rf_max_depth': 6, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 10, 'rf_max_features': None, 'rf_random_state': 49}
# Optimized Voting Regressor - Train MAE: 12.32637182447851, Test MAE: 12.471958708717917

# %% [markdown]
# ## One-Hot + PCA Data

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 데이터 로드
train = pd.read_csv('./train.csv')

# yymm 컬럼을 날짜 형식으로 변환 (연도는 임의로 설정)
train['yymm'] = pd.to_datetime('2024' + train['yymm'], format='%Y%m%d %H:%M')

# day, hour, minute, weekday 컬럼 생성
day = train['yymm'].dt.day
day_dummies = pd.get_dummies(day, prefix='day')

hour = train['yymm'].dt.hour
hour_dummies = pd.get_dummies(hour, prefix='hour')

minute = train['yymm'].dt.minute
minute_dummies = pd.get_dummies(minute, prefix='minute')

# weekday 컬럼 생성
weekday = day % 7
weekday = weekday.map({0:'Mon', 1:'Tue', 2:'Wed', 3:'Thu', 4:'Fri', 5:'Sat', 6:'Sun'})
weekday_dummies = pd.get_dummies(weekday)

# PCA 피처 생성
features = train.loc[:, 'V1':'V26'] # V1 ~ V26 컬럼 선택

scaler = StandardScaler()
features = scaler.fit_transform(features) # 피처 표준화

pca = PCA(n_components=3)
pca_features = pca.fit_transform(features) # PCA 피처 생성

# 생성된 주성분을 DataFrame으로 변환
pca_columns = ['PCA1', 'PCA2', 'PCA3']
pca_df = pd.DataFrame(pca_features, columns=pca_columns)

# 원본 데이터와 PCA 피처 결합
train = pd.concat([train, day_dummies, hour_dummies, minute_dummies, weekday_dummies, pca_df], axis=1)

# yymm 컬럼 삭제
train.drop('yymm', axis=1, inplace=True)

# 결과 출력
train.head(10)
# Out:
#       V1      V2     V3     V4  ...    Wed      PCA1      PCA2      PCA3
# 0 -5.327  12.250 -3.294 -7.855  ...  False -2.616525 -2.341176 -3.016174
# 1 -5.267  12.916 -3.220 -7.788  ...  False -2.691167 -2.187795 -3.000616
# 2 -5.127  13.583 -3.130 -7.658  ...  False -2.724164 -2.076864 -2.954282
# 3 -5.060  14.250 -3.130 -7.532  ...  False -2.744811 -2.076954 -2.864929
# 4 -4.967  14.916 -3.094 -7.462  ...  False -2.827777 -1.960836 -2.942832
# 5 -4.967  15.583 -3.020 -7.388  ...  False -2.914471 -1.906830 -2.889545
# 6 -4.827  16.250 -2.920 -7.288  ...  False -3.008483 -1.854571 -2.893859
# 7 -4.797  16.250 -2.920 -7.222  ...  False -3.088857 -1.917965 -2.752764
# 8 -4.737  16.250 -2.830 -7.188  ...  False -3.212438 -1.820224 -2.834904
# 9 -4.900  16.250 -2.890 -7.188  ...  False -3.306377 -1.653918 -2.872736
#
# [10 rows x 98 columns]

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error

# 데이터 분할
X = train.drop('Target', axis=1)    # Target을 제외한 모든 컬럼을 X로 지정
y = train['Target']                 # Target 컬럼을 y로 지정

# train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 생성
lr = LinearRegression()
ridge = Ridge(random_state=42)
lasso = Lasso(random_state=42)
elastic = ElasticNet(random_state=42)
svr = SVR()
gb = GradientBoostingRegressor(random_state=42)
rf = RandomForestRegressor(random_state=42)
xgb = XGBRegressor(random_state=42)
lgbm = LGBMRegressor(random_state=42)
dt = DecisionTreeRegressor(random_state=42)

voting1 = VotingRegressor([
    ('lasso', lasso),
    ('svr', svr),
    ('random_forest', rf)
])

voting2 = VotingRegressor([
    ('lasso', lasso),
    ('elastic', elastic),
    ('svr', svr),
])

voting3 = VotingRegressor([
    ('svr', svr),
    ('random_forest', rf),
    ('xgb', xgb),
])

models = {
    'Voting1': voting1,
    'Voting2': voting2,
    'Voiting3': voting3
}

# MAE를 평가 기준으로 사용하기 위해 scorer 정의
mae_scorer = make_scorer(mean_absolute_error)

# 각 모델에 대해 학습 및 5-fold 교차검증 수행
for model_name, model in models.items():
    scores = cross_val_score(model, X, y, cv=5, scoring=mae_scorer)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    train_score = mean_absolute_error(y_train, model.predict(X_train))
    test_score = mean_absolute_error(y_test, y_pred)

    print(f'{model_name}: {scores.mean()} / {train_score} / {test_score}')
# Out:
# Voting1: 12.539015789720931 / 9.88133180297008 / 12.490045280103026
# Voting2: 12.537690856924806 / 12.513861512090774 / 12.457365725409833
# Voiting3: 12.686431825484089 / 7.133621336898445 / 12.708426967205904
